# %% [markdown]
# # Optimise a synapse
#
# This example is based on ```optimiseFullOnlyOne.sh``` which uses ```optimise_synapses_full.py``` which runs in parallel, this example runs in serial.
#
# The code uses ```neuron_set.json``` to define which neurons we use, and their properties and ```model_bounds.json``` to specify parameter ranges.
#
# Before running, make sure the NEURON mod files are compiled.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from optimise_synapses_full import OptimiseSynapsesFull

compile_mod = True

data_file = "../data/synapses/example_data/10_MSN12_GBZ_CC_H20.json"
synapse_parameters = "../data/synapses/example_data/M1LH-contra_dSPN.json"
d_view = None  # Set this to run in Parallel
opt_method = "sobol"

log_file_name = os.path.join("logs", f"{os.path.basename(data_file)}-log.txt")

if not os.path.exists("logs/"):
    os.makedirs("logs/")

ly = OptimiseSynapsesFull(snudda_data="/home/hjorth/HBP/BasalGangliaData/data",
                          data_file=data_file,
                          synapse_parameter_file=synapse_parameters,
                          synapse_type="glut", d_view=d_view,
                          role="master",
                          log_file_name=log_file_name, 
                          opt_method=opt_method)
# Out:
# Init optMethod = sobol
# Log file: logs/10_MSN12_GBZ_CC_H20.json-log.txt
# Loading ../data/synapses/example_data/10_MSN12_GBZ_CC_H20.json
# Reading synapse parameters from ../data/synapses/example_data/M1LH-contra_dSPN.json
# Loading model bounds from model_bounds.json
# No dView, no parallel
# OptimiseSynapseFull: Init done

# %%
ly.parallel_optimise_single_cell(n_trials=2)
# Out:
# setup_model: synapse_position-override: None
# Holding voltage: -0.08 V
# Stim times: [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 1.  ] s
# Synapse type: glut
# Using morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology
# Setting resting voltage to -80.000 mV
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Stimulation times (s): [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 1.  ]
# Updating holding current, might take a bit of time
# Setting resting voltage to -80.000 mV
# Setting resting voltage to -80.000 mV
# Holding voltage -80.0 mV, IClamp amp = 0.4569500333673204 nA
# RunSynapseRun: Init done.
# sobol_worker_setup: synapse_position_override = (array([15, 28, 48,  3, 26, 37, 35,  4, 26,  5, 46, 26, 14, 26, 24, 34, 14,
#        53,  8, 56], dtype=int32), array([0.85885939, 0.9874343 , 0.57204273, 0.71458165, 0.96966543,
#        0.69800676, 0.30886046, 0.95363174, 0.79059688, 0.61279956,
#        0.6522849 , 0.61343978, 0.6932588 , 0.99754531, 0.46700473,
#        0.99246178, 0.72591104, 0.15992329, 0.88833733, 0.60141687]))
# setup_model: synapse_position-override: (array([15, 28, 48,  3, 26, 37, 35,  4, 26,  5, 46, 26, 14, 26, 24, 34, 14,
#        53,  8, 56], dtype=int32), array([0.85885939, 0.9874343 , 0.57204273, 0.71458165, 0.96966543,
#        0.69800676, 0.30886046, 0.95363174, 0.79059688, 0.61279956,
#        0.6522849 , 0.61343978, 0.6932588 , 0.99754531, 0.46700473,
#        0.99246178, 0.72591104, 0.15992329, 0.88833733, 0.60141687]))
# Holding voltage: -0.08 V
# Stim times: [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 1.  ] s
# Synapse type: glut
# Using morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology
# Setting resting voltage to -80.000 mV
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Setting parameters: tau1_ampa = 1.0925303972077076 (neuron natural units)
# Setting parameters: tau2_ampa = 4.437072205337933 (neuron natural units)
# Setting parameters: tau3_ampa = 119.98882942221262 (neuron natural units)
# Setting parameters: I2_ampa = -1.9886844552485996 (neuron natural units)
# Setting parameters: I3_ampa = -0.048026349597992034 (neuron natural units)
# Setting parameters: tpeak_ampa = 2.063918378264594 (neuron natural units)
# Setting parameters: factor_ampa = -1.0119232390299844 (neuron natural units)
# Setting parameters: tau1_nmda = 1.8208839953461793 (neuron natural units)
# Setting parameters: tau2_nmda = 33.567312186770074 (neuron natural units)
# Setting parameters: tau3_nmda = 204.30443150344257 (neuron natural units)
# Setting parameters: I2_nmda = 0.8477113681722652 (neuron natural units)
# Setting parameters: I3_nmda = 0.2970225501393719 (neuron natural units)
# Setting parameters: tpeak_nmda = 6.064414326277802 (neuron natural units)
# Setting parameters: factor_nmda = 1.0471430189533268 (neuron natural units)
# Setting parameters: nmda_ratio = 0.299937 (neuron natural units)
# Stimulation times (s): [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 1.  ]
# Updating holding current, might take a bit of time
# Setting resting voltage to -80.000 mV
# Setting resting voltage to -80.000 mV
# Holding voltage -80.0 mV, IClamp amp = 0.4569500333673204 nA
# RunSynapseRun: Init done.
# sobol_worker_setup: setup_model done
# sobol_worker_setup: done.
# parameter_sets=[(0.5005, 1.00005, 1.00005, 0.49999995, 5.05e-10), (0.75025, 0.500075, 1.5000250000000002, 0.249999975, 7.525e-10)]
# Running with pars: OrderedDict([('tau1_ampa', 1.0925303972077076), ('tau2_ampa', 4.437072205337933), ('tau3_ampa', 119.98882942221262), ('I2_ampa', -1.9886844552485996), ('I3_ampa', -0.048026349597992034), ('tpeak_ampa', 2.063918378264594), ('factor_ampa', -1.0119232390299844), ('tau1_nmda', 1.8208839953461793), ('tau2_nmda', 33.567312186770074), ('tau3_nmda', 204.30443150344257), ('I2_nmda', 0.8477113681722652), ('I3_nmda', 0.2970225501393719), ('tpeak_nmda', 6.064414326277802), ('factor_nmda', 1.0471430189533268), ('nmda_ratio', 0.299937), ('U', 0.5005), ('tauR', 1.00005), ('tauF', 1.00005), ('cond', 5.05e-10), ('tau', 0.5000249499975001)])
# Setting resting voltage to -80.000 mV
# Traceback (most recent call last):
#   File "/home/hjorth/HBP/Snudda/snudda/synaptic_fitting/optimise_synapses_full.py", line 917, in sobol_scan
#     error, peaks, t, v = self.neuron_synapse_helper_glut(t_stim, u, tau_r, tau_f, tau_ratio, cond,
#   File "/home/hjorth/HBP/Snudda/snudda/synaptic_fitting/optimise_synapses_full.py", line 729, in neuron_synapse_helper_glut
#     peak_h, t_sim, v_sim = self.run_model(t_spike, u,
#   File "/home/hjorth/HBP/Snudda/snudda/synaptic_fitting/optimise_synapses_full.py", line 825, in run_model
#     (t_sim, v_sim, i_sim) = self.rsr_synapse_model.run2(pars=params)
#   File "/home/hjorth/HBP/Snudda/snudda/synaptic_fitting/run_synapse_run.py", line 556, in run2
#     neuron.h.v_hold = self.holding_voltage * 1e3
# LookupError: 'v_hold' is not a defined hoc variable name.
#
# Traceback (most recent call last):
#   File "/home/hjorth/HBP/Snudda/snudda/synaptic_fitting/optimise_synapses_full.py", line 917, in sobol_scan
#     error, peaks, t, v = self.neuron_synapse_helper_glut(t_stim, u, tau_r, tau_f, tau_ratio, cond,
#   File "/home/hjorth/HBP/Snudda/snudda/synaptic_fitting/optimise_synapses_full.py", line 729, in neuron_synapse_helper_glut
#     peak_h, t_sim, v_sim = self.run_model(t_spike, u,
#   File "/home/hjorth/HBP/Snudda/snudda/synaptic_fitting/optimise_synapses_full.py", line 825, in run_model
#     (t_sim, v_sim, i_sim) = self.rsr_synapse_model.run2(pars=params)
#   File "/home/hjorth/HBP/Snudda/snudda/synaptic_fitting/run_synapse_run.py", line 556, in run2
#     neuron.h.v_hold = self.holding_voltage * 1e3
# LookupError: 'v_hold' is not a defined hoc variable name.
#
# > /home/hjorth/HBP/Snudda/snudda/synaptic_fitting/optimise_synapses_full.py(944)sobol_scan()
#     942             pdb.set_trace()
#     943
# --> 944         return self.synapse_parameter_data.book
#     945
#     946     ############################################################################
# ipdb>  neuron.h.vhold
# *** AttributeError: 'hoc.HocObject' object has no attribute 'vhold'
# ipdb>  neuron.h.v_hold
# *** AttributeError: 'hoc.HocObject' object has no attribute 'v_hold'

# %%
ly.plot_data(show=True, pretty_plot=True, skip_time=0)
