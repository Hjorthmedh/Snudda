# %% [markdown]
# # Cuts a network
#
# Here we use x > 0.0047, anything not fullfiling this equation is removed. Entire neurons can be removed, or synapses that are outside the kept region.

# %%
import os

network_path = os.path.join("networks", "PD-example-2k", "PD0", "network-synapses.hdf5")

# %%
from snudda.utils.cut import SnuddaCut
san = SnuddaCut(network_file=network_path, cut_equation="x>0.0047", show_plot=True)
# Out:
# Writing to networks/PD-example-2k/PD0/network-cut-slice.hdf5
# Copying 'config' and 'meta'
# Keeping 1355 out of 1996 neurons (the others have soma outside of cut plane)
# filtering synapses
# filtering of synapses done
# filtering gap_junctions
# filtering of gap_junctions done
# Copying synapses and gap junctions
# Keeping 398057 synapses (out of 696768)
# Keeping 50  gap junctions (out of 150)
# Plotting verification figure
# Writing to figure networks/PD-example-2k/PD0/network-cut-slice.hdf5.pdf
# close figure to exit program!
