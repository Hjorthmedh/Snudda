# %% [markdown]
# # Input density example
#
# This code uses the ```simple_example``` network created by ```simple_network_creation.ipynb```.

# %%
import os
from snudda.input import SnuddaInput
network_path = os.path.join("networks","simple_example")
si = SnuddaInput(network_path=network_path, 
                 input_config_file=os.path.join("input_config","simple-input-4.json"),
                 verbose=False)
si.generate()
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/Snudda/snudda/data from networks/simple_example/network-config.json
# Writing spikes to networks/simple_example/input-spikes.hdf5

# %%
from snudda.plotting import PlotInput
input_file = os.path.join(network_path, "input-spikes.hdf5")
spi = PlotInput(input_file)

# %%
spi.plot_input("dSPN", 10, fig_size=(15,5))

# %%
from snudda.plotting.plot_input_locations import SnuddaPlotInputLocations
spil = SnuddaPlotInputLocations(network_path=network_path)
spil.plot_input_location("dSPN", "Cortical_input")
spil.plot_input_location("dSPN", "Thalamic_input")
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/Snudda/snudda/data from networks/simple_example/network-config.json

# %%
from snudda.plotting.plot_input_locations import SnuddaPlotInputLocations
spil2 = SnuddaPlotInputLocations(network_path=network_path)
spil2.plot_input_location("iSPN", "Cortical_input")
spil2.plot_input_location("iSPN", "Thalamic_input")
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/Snudda/snudda/data from networks/simple_example/network-config.json
