# %% [markdown]
# # Optimise pruning parameters
#
# This Notebook shows how to optimise the pruning parameters of your network based on pairwise connectivity data.
#
# First we need to create a small network that we can use for the optimisation of the pruning parameters.
#
# In this example we do not need to have realistic neuron densities, so we will place the neurons in a cube of diameter 150 micrometers.

# %%
import os
import numpy as np

n_neurons = 150

pop_size = 15
# epochs = 10

pre_type = "ChIN"     # "iSPN"
post_type = "FS"  # "iSPN"
con_type = "GABA"

avg_num_synapses_per_pair = 3  # Expected mean, error weight

# param_names = ["f1", "softMax", "mu2", "a3"]
param_names = ["f1", "mu2", "a3"]

SPN2SPNdistDepPruning = "1-exp(-(0.4*d/60e-6)**2)"
FS_dist_dep_pruning = "exp(-(0.5*d/60e-6)**2)" 
LTS_dist_dep_pruning = "1-exp(-(0.4*d/60e-6)**2)"


extra_pruning_parameters = { }
# extra_pruning_parameters = { 'distPruning': SPN2SPNdistDepPruning }
    
        
par_str = "_".join(param_names)
network_path = os.path.join("networks", f"{pre_type}_to_{post_type}_{par_str}")

        
all_experimental_data = {}
all_experimental_data["dSPN", "iSPN"] = [(0, 50e-6, 3/47.0), (0, 100e-6, 3/66.0)]
all_experimental_data["dSPN", "dSPN"] = [(0, 50e-6, 5/19.0), (0, 100e-6, 3/43.0)]
all_experimental_data["iSPN", "iSPN"] = [(0, 50e-6, 14/39.0), (0, 100e-6, 7/31.0)]
all_experimental_data["iSPN", "dSPN"] = [(0, 50e-6, 13/47.0), (0, 100e-6, 10/80.0)]

all_experimental_data["FS", "FS"] = [(0, 250e-6, 7/12.0)]
all_experimental_data["FS", "iSPN"] = [(0, 100e-6, 6/9.0), (0, 150e-6, 21/54.0), (0, 250e-6, 27/77.0)]
all_experimental_data["FS", "dSPN"] = [(0, 100e-6, 8/9.0), (0, 150e-6, 29/48.0), (0, 250e-6, 48/90.0)]
all_experimental_data["FS", "LTS"] = [(0, 250e-6, 2/12.0)]

all_experimental_data["LTS", "dSPN"] = [(0, 250e-6, 2/60.0)]
all_experimental_data["LTS", "iSPN"] = [(0, 250e-6, 2/60.0)]

all_experimental_data["ChIN", "dSPN"] = [(0, 250e-6, 0.05)]
all_experimental_data["ChIN", "iSPN"] = [(0, 250e-6, 0.05)]
all_experimental_data["ChIN", "LTS"] = [(0, 250e-6, 53/72.0)]  # Lou ea 2013
all_experimental_data["ChIN", "FS"] = [(0, 250e-6, 19/26.0)]   # Lou ea 2013



all_experimental_data["NGF", "dSPN"] = [(0, 100e-6, 25/29.0),  # Ibanez-Sandoval 2011
                                        (0, 250e-6, 11/14.0),  # English 2012
                                        (0, 250e-6, 30/50.0)]  # Luo 2013
all_experimental_data["NGF", "iSPN"] = [(0, 100e-6, 25/29.0),  # Ibanez-Sandoval 2011
                                        (0, 250e-6, 11/14.0),  # English 2012
                                        (0, 250e-6, 30/50.0)]  # Luo 2013
all_experimental_data["NGF", "ChIN"] = [(0, 250e-6, 3/14.0)]  # English 2012

# NGF to FS??   Kocaturk 2022 -- no probability given?
# NGF to NGF??


experimental_data = all_experimental_data[pre_type, post_type]

cube_side = np.max([x[1] for x in experimental_data])

axon_cloud = dict()
LTS_density_str = ("12*3000*1e12*( 0.25*exp(-(((x-200e-6)/100e-6)**2 "
                           "+ ((y-0)/50e-6)**2 + ((z-0)/30e-6)**2)) "
                           "+ 1*exp(-(((x-300e-6)/300e-6)**2 + ((y-0)/15e-6)**2 + ((z-0)/10e-6)**2)) "
                           "+ 1*exp(-(((x-700e-6)/100e-6)**2 + ((y-0)/15e-6)**2 + ((z-0)/15e-6)**2)) )")

axon_cloud["LTS"] = ("xyz", LTS_density_str, [-200e-6, 900e-6, -100e-6, 100e-6, -30e-6, 30e-6])
# axon_cloud["CHIN"] = ("r", "5000*1e12/3*exp(-r/120e-6)", 350e-6)

# %%
from snudda.place.create_cube_mesh import create_cube_mesh

mesh_file = os.path.join(network_path, "cube-mesh.obj")
create_cube_mesh(mesh_file, [0,0,0], cube_side)

from snudda.init import SnuddaInit
si = SnuddaInit(network_path=network_path, random_seed=123, snudda_data="../../../../../BasalGangliaData/data/")

si.define_structure(struct_name="Cube", struct_mesh=mesh_file, d_min=12e-6, mesh_bin_width=25e-6)

if pre_type in axon_cloud:
    pre_ac = axon_cloud[pre_type]
else:
    pre_ac = None
    
if post_type in axon_cloud:
    post_ac = axon_cloud[post_type]
else:
    post_ac = None

if pre_type == post_type:
    
    si.add_neurons(name=pre_type, num_neurons=n_neurons, volume_id="Cube", axon_density=pre_ac,
                    neuron_dir=os.path.join("$DATA","neurons","striatum",pre_type.lower()))
else:
    si.add_neurons(name=pre_type, num_neurons=int(n_neurons/2), volume_id="Cube", axon_density=pre_ac,
                    neuron_dir=os.path.join("$DATA","neurons","striatum", pre_type.lower()))
    si.add_neurons(name=post_type, num_neurons=int(n_neurons/2), volume_id="Cube", axon_density=post_ac,
                    neuron_dir=os.path.join("$DATA","neurons","striatum", post_type.lower()))
    

# The parameters here does not matter, they will be set during optimisation
si.add_neuron_target(neuron_name=pre_type,
                     target_name=post_type,
                     region_name="Cube",
                     connection_type=con_type,
                     dist_pruning=None,
                     f1=None, soft_max=None, mu2=None,
                     a3=None,
                     conductance=[0.24e-9, 0.1e-9],
                     mod_file="tmGabaA")

si.write_json()
# Out:
# Adding neurons: ChIN from dir /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/chin
# Adding neurons: FS from dir /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/fs
# Writing networks/ChIN_to_FS_f1_mu2_a3/network-config.json

# %%
from snudda import SnuddaPlace
sp = SnuddaPlace(network_path=network_path, verbose=False)
sp.place()
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/BasalGangliaData/data from networks/ChIN_to_FS_f1_mu2_a3/network-config.json
# No n_putative_points and putative_density, setting n_putative_points = 6172
# (this must be larger than the number of neurons you want to place)
# Generating 6172 points for networks/ChIN_to_FS_f1_mu2_a3/cube-mesh.obj
# Filtering, keeping inside points: 2413 / 3257
# neuron_name = 'ChIN_0', num = 75, neuron_path = '/home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/chin/str-chin-e170614_cell6-m17JUL301751_170614_no6_MD_cell_1_x63-v20190710'
# neuron_name = 'FS_0', num = 15, neuron_path = '/home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/fs/str-fs-e160628_FS2-mMTC180800A-IDB-v20220614'
# neuron_name = 'FS_1', num = 15, neuron_path = '/home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20220614'
# neuron_name = 'FS_2', num = 15, neuron_path = '/home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20220614'
# neuron_name = 'FS_3', num = 15, neuron_path = '/home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20220614'
# neuron_name = 'FS_4', num = 15, neuron_path = '/home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/fs/str-fs-e180418_FS5-mMTC251001A-IDB-v20220614'

# %%
from snudda.plotting import PlotNetwork
network_file = os.path.join(network_path, "network-neuron-positions.hdf5")
pn = PlotNetwork(network_file)
pn.plot(plot_axon=False, plot_dendrite=False, plot_synapses=False)
pn.close()
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/BasalGangliaData/data from networks/ChIN_to_FS_f1_mu2_a3/network-config.json

# %%
from snudda import SnuddaDetect

sd = SnuddaDetect(network_path=network_path, hyper_voxel_size=100)
sd.detect()
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/BasalGangliaData/data from networks/ChIN_to_FS_f1_mu2_a3/network-config.json
# No d_view specified, running distribute neurons in serial
# Processing hyper voxel : 114/343 (150 neurons)
# Processing hyper voxel : 115/343 (145 neurons)
# Processing hyper voxel : 121/343 (138 neurons)
# Processing hyper voxel : 163/343 (134 neurons)
# Processing hyper voxel : 122/343 (133 neurons)
# Processing hyper voxel : 164/343 (126 neurons)
# Processing hyper voxel : 171/343 (119 neurons)
# Processing hyper voxel : 170/343 (117 neurons)
# Processing hyper voxel : 65/343 (102 neurons)
# Processing hyper voxel : 107/343 (89 neurons)
# Processing hyper voxel : 66/343 (88 neurons)
# Processing hyper voxel : 113/343 (85 neurons)
# Processing hyper voxel : 108/343 (82 neurons)
# Processing hyper voxel : 72/343 (72 neurons)
# Processing hyper voxel : 73/343 (67 neurons)
# Processing hyper voxel : 156/343 (66 neurons)
# Processing hyper voxel : 120/343 (60 neurons)
# Processing hyper voxel : 157/343 (60 neurons)
# Processing hyper voxel : 116/343 (53 neurons)
# Processing hyper voxel : 162/343 (52 neurons)
# Processing hyper voxel : 123/343 (50 neurons)
# Processing hyper voxel : 58/343 (49 neurons)
# Processing hyper voxel : 59/343 (46 neurons)
# Processing hyper voxel : 129/343 (45 neurons)
# Processing hyper voxel : 169/343 (43 neurons)
# Processing hyper voxel : 165/343 (43 neurons)
# Processing hyper voxel : 128/343 (42 neurons)
# Processing hyper voxel : 172/343 (41 neurons)
# Processing hyper voxel : 212/343 (39 neurons)
# Processing hyper voxel : 64/343 (37 neurons)
# Processing hyper voxel : 219/343 (37 neurons)
# Processing hyper voxel : 213/343 (35 neurons)
# Processing hyper voxel : 106/343 (34 neurons)
# Processing hyper voxel : 178/343 (33 neurons)
# Processing hyper voxel : 177/343 (32 neurons)
# Processing hyper voxel : 67/343 (32 neurons)
# Processing hyper voxel : 220/343 (31 neurons)
# Processing hyper voxel : 109/343 (28 neurons)
# Processing hyper voxel : 71/343 (27 neurons)
# Processing hyper voxel : 74/343 (27 neurons)
# Processing hyper voxel : 80/343 (25 neurons)
# Processing hyper voxel : 155/343 (24 neurons)
# Processing hyper voxel : 158/343 (21 neurons)
# Processing hyper voxel : 57/343 (20 neurons)
# Processing hyper voxel : 130/343 (20 neurons)
# Processing hyper voxel : 16/343 (19 neurons)
# Processing hyper voxel : 17/343 (18 neurons)
# Processing hyper voxel : 211/343 (18 neurons)
# Processing hyper voxel : 79/343 (17 neurons)
# Processing hyper voxel : 206/343 (17 neurons)
# Processing hyper voxel : 60/343 (16 neurons)
# Processing hyper voxel : 127/343 (15 neurons)
# Processing hyper voxel : 24/343 (15 neurons)
# Processing hyper voxel : 205/343 (15 neurons)
# Processing hyper voxel : 23/343 (14 neurons)
# Processing hyper voxel : 176/343 (13 neurons)
# Processing hyper voxel : 112/343 (13 neurons)
# Processing hyper voxel : 226/343 (13 neurons)
# Processing hyper voxel : 10/343 (12 neurons)
# Processing hyper voxel : 227/343 (12 neurons)
# Processing hyper voxel : 100/343 (12 neurons)
# Processing hyper voxel : 179/343 (11 neurons)
# Processing hyper voxel : 149/343 (11 neurons)
# Processing hyper voxel : 81/343 (10 neurons)
# Processing hyper voxel : 161/343 (10 neurons)
# Processing hyper voxel : 214/343 (10 neurons)
# Processing hyper voxel : 218/343 (10 neurons)
# Processing hyper voxel : 204/343 (10 neurons)
# Processing hyper voxel : 101/343 (10 neurons)
# Processing hyper voxel : 51/343 (9 neurons)
# Processing hyper voxel : 119/343 (8 neurons)
# Processing hyper voxel : 150/343 (8 neurons)
# Processing hyper voxel : 99/343 (8 neurons)
# Processing hyper voxel : 105/343 (8 neurons)
# Processing hyper voxel : 78/343 (7 neurons)
# Processing hyper voxel : 184/343 (7 neurons)
# Processing hyper voxel : 185/343 (7 neurons)
# Processing hyper voxel : 117/343 (6 neurons)
# Processing hyper voxel : 9/343 (6 neurons)
# Processing hyper voxel : 154/343 (6 neurons)
# Processing hyper voxel : 22/343 (6 neurons)
# Processing hyper voxel : 18/343 (6 neurons)
# Processing hyper voxel : 207/343 (6 neurons)
# Processing hyper voxel : 136/343 (6 neurons)
# Processing hyper voxel : 31/343 (5 neurons)
# Processing hyper voxel : 63/343 (5 neurons)
# Processing hyper voxel : 168/343 (5 neurons)
# Processing hyper voxel : 221/343 (5 neurons)
# Processing hyper voxel : 68/343 (5 neurons)
# Processing hyper voxel : 75/343 (5 neurons)
# Processing hyper voxel : 15/343 (5 neurons)
# Processing hyper voxel : 135/343 (5 neurons)
# Processing hyper voxel : 261/343 (4 neurons)
# Processing hyper voxel : 173/343 (4 neurons)
# Processing hyper voxel : 11/343 (4 neurons)
# Processing hyper voxel : 225/343 (4 neurons)
# Processing hyper voxel : 52/343 (4 neurons)
# Processing hyper voxel : 148/343 (4 neurons)
# Processing hyper voxel : 50/343 (4 neurons)
# Processing hyper voxel : 124/343 (4 neurons)
# Processing hyper voxel : 151/343 (3 neurons)
# Processing hyper voxel : 25/343 (3 neurons)
# Processing hyper voxel : 260/343 (3 neurons)
# Processing hyper voxel : 166/343 (3 neurons)
# Processing hyper voxel : 199/343 (3 neurons)
# Processing hyper voxel : 70/343 (3 neurons)
# Processing hyper voxel : 126/343 (3 neurons)
# Processing hyper voxel : 268/343 (2 neurons)
# Processing hyper voxel : 267/343 (2 neurons)
# Processing hyper voxel : 210/343 (2 neurons)
# Processing hyper voxel : 198/343 (2 neurons)
# Processing hyper voxel : 234/343 (2 neurons)
# Processing hyper voxel : 233/343 (2 neurons)
# Processing hyper voxel : 186/343 (2 neurons)
# Processing hyper voxel : 262/343 (2 neurons)
# Processing hyper voxel : 203/343 (2 neurons)
# Processing hyper voxel : 2/343 (2 neurons)
# Processing hyper voxel : 82/343 (2 neurons)
# Processing hyper voxel : 3/343 (2 neurons)
# Processing hyper voxel : 134/343 (2 neurons)
# Processing hyper voxel : 269/343 (2 neurons)
# Processing hyper voxel : 110/343 (2 neurons)
# Processing hyper voxel : 102/343 (2 neurons)
# Processing hyper voxel : 8/343 (2 neurons)
# Processing hyper voxel : 32/343 (2 neurons)
# Processing hyper voxel : 87/343 (2 neurons)
# Processing hyper voxel : 30/343 (2 neurons)
# Processing hyper voxel : 53/343 (2 neurons)
# Processing hyper voxel : 56/343 (2 neurons)
# Processing hyper voxel : 232/343 (1 neurons)
# Processing hyper voxel : 26/343 (1 neurons)
# Processing hyper voxel : 21/343 (1 neurons)
# Processing hyper voxel : 159/343 (1 neurons)
# Processing hyper voxel : 254/343 (1 neurons)
# Processing hyper voxel : 259/343 (1 neurons)
# Processing hyper voxel : 19/343 (1 neurons)
# Processing hyper voxel : 14/343 (1 neurons)
# Processing hyper voxel : 12/343 (1 neurons)
# Processing hyper voxel : 252/343 (1 neurons)
# Processing hyper voxel : 228/343 (1 neurons)
# Processing hyper voxel : 38/343 (1 neurons)
# Processing hyper voxel : 224/343 (1 neurons)
# Processing hyper voxel : 183/343 (1 neurons)
# Processing hyper voxel : 39/343 (1 neurons)
# Processing hyper voxel : 217/343 (1 neurons)
# Processing hyper voxel : 215/343 (1 neurons)
# Processing hyper voxel : 61/343 (1 neurons)
# Processing hyper voxel : 86/343 (1 neurons)
# Processing hyper voxel : 88/343 (1 neurons)
# Processing hyper voxel : 89/343 (1 neurons)
# Processing hyper voxel : 98/343 (1 neurons)
# Processing hyper voxel : 137/343 (1 neurons)
# Processing hyper voxel : 29/343 (1 neurons)
# Processing hyper voxel : 275/343 (1 neurons)

# %%
from snudda.optimise.optimise_pruning import OptimisePruning
op = OptimisePruning(network_path=network_path)

# %%
op.merge_putative_synapses(force_merge=True)
# Out:
# Read 60785 out of total 60785 synapses

# %%
op.prune.connectivity_distributions
# Out:
# {(2,
#   1,
#   10): ({'f1': 1.0,
#    'soft_max': None,
#    'mu2': None,
#    'a3': None,
#    'dist_pruning': None,
#    'cluster_pruning': False}, None)}

# %%
op.prune.type_id_lookup
# Out:
# {'FS': 1, 'ChIN': 2}

# %%
op.prune.hist_file["meta/connectivity_distributions"][()]
# Out:
# b'{"ChIN$$FS": {"GABA": {"conductance": [2.4e-10, 1e-10], "channel_parameters": {"mod_file": "tmGabaA"}, "cluster_size": 1, "cluster_spread": null, "pruning": {"f1": null, "soft_max": null, "mu2": null, "a3": null, "dist_pruning": null, "cluster_pruning": false}, "channel_model_id": 10, "lognormal_mu_sigma": [-22.230424900260093, 0.40010675493807013]}}}'

# %%
res = op.optimize(pre_type=pre_type, post_type=post_type, con_type=con_type, 
                  experimental_data=experimental_data, 
                  avg_num_synapses_per_pair=avg_num_synapses_per_pair,
                  extra_pruning_parameters=extra_pruning_parameters, 
                  workers=8, maxiter=1000, pop_size=pop_size, tol=0.00001, 
                  param_names=param_names, param_bounds="default")
# Out:
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py:487: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# Worker iter: 100, fitness 36.631210324998406
# Worker iter: 100, fitness 36.762900485624584Worker iter: 100, fitness 36.75808566614563
#
# Worker iter: 100, fitness 36.704136182523726
# Worker iter: 100, fitness 36.7942804288162
# Worker iter: 100, fitness 36.548834160327054
# Worker iter: 100, fitness 36.80542107212716
# Worker iter: 100, fitness 36.589248824063006
# Worker iter: 200, fitness 36.378394846781674
# Worker iter: 200, fitness 36.38325708341053
# Worker iter: 200, fitness 36.389971825888566
# Worker iter: 200, fitness 36.35845471117448
# Worker iter: 200, fitness 36.36979625362425
# Worker iter: 200, fitness 36.3786229283529
# Worker iter: 200, fitness 36.374656914674155
# Worker iter: 200, fitness 36.35845471117448
# Worker iter: 300, fitness 36.35845471117448
# Worker iter: 300, fitness 36.35845471117448
# Worker iter: 300, fitness 36.35845471117448
# Worker iter: 300, fitness 36.35845471117448
# Duration: 264.27808912599994 s

# %%
op.export_json("network-config-opt.json", res=res, append=True)

# %% [markdown]
# # Best parameter set

# %%
param_str = ""
for p_name, p_val in zip(param_names, res.x):
    param_str += f"{p_name} = {p_val:.4f}, "
    
if "distPruning" in extra_pruning_parameters:
   param_str += f" ({extra_pruning_parameters['distPruning']})"                                                  
                                                 
print(param_str)
# Out:
# f1 = 0.1307, mu2 = 0.3907, a3 = 1.0000,

# %%
res
# Out:
#              message: Optimization terminated successfully.
#              success: True
#                  fun: 36.35845471117448
#                    x: [ 1.307e-01  3.907e-01  1.000e+00]
#                  nit: 52
#                 nfev: 2389
#           population: [[ 1.307e-01  3.907e-01  1.000e+00]
#                        [ 1.307e-01  4.366e-01  9.998e-01]
#                        ...
#                        [ 1.307e-01  2.448e-01  9.999e-01]
#                        [ 1.307e-01  2.676e-01  9.999e-01]]
#  population_energies: [ 3.636e+01  3.636e+01 ...  3.636e+01  3.636e+01]

# %%
import os
from snudda.analyse.analyse import SnuddaAnalyse
import glob

# Get the last file
# list_of_files = glob.glob(os.path.join(network_path, "temp", "network-synapses-*hdf5"))
# network_file = max(list_of_files, key=os.path.getctime)

network_file = os.path.join(network_path, "network-synapses.hdf5")

dist3D = False
y_max_H = None

sa = SnuddaAnalyse(network_file)
# Out:
# Assuming volume type: cube [cube or full]
# Only using 20000 neurons of the connection data
# Creating figures directory networks/ChIN_to_FS_f1_mu2_a3/figures
# Number of neurons: 150
# Synapse row 0 - 0.0 % time: 0.0008553329998903791 seconds
# Created connection matrix 0.009549750000132917 seconds
# Created gap junction connection matrix 0.0001922920000652084 seconds
# Creating population dictionary
# Done.
# Warning: the analysis cube specified by sideLen is too large.
# !!! Setting sideLen to None
# Calculating synapse distance histogram
# Creating dist histogram
# n_synapses = 7940, at 0
# Created distance histogram (optimised) in 0.007041374999971595 seconds
# Saving cache to networks/ChIN_to_FS_f1_mu2_a3/network-synapses.hdf5-cache

# %%
if pre_type == "dSPN" and post_type == "iSPN":
    sa.plot_connection_probability("dSPN", "iSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(3, 47), (3, 66)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("dSPN", "iSPN", sub_title=param_str)
elif pre_type == "dSPN" and post_type == "dSPN":
    sa.plot_connection_probability("dSPN", "dSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(5, 19), (3, 43)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("dSPN", "dSPN", sub_title=param_str)
elif pre_type == "iSPN" and post_type == "iSPN":
    sa.plot_connection_probability("iSPN", "iSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(14, 39), (7, 31)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("iSPN", "iSPN", sub_title=param_str)
elif pre_type == "iSPN" and post_type == "dSPN":
    sa.plot_connection_probability("iSPN", "dSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(13, 47), (10, 80)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("iSPN", "dSPN", sub_title=param_str)

elif pre_type == "FS" and post_type == "FS":
    sa.plot_connection_probability("FS", "FS", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(7, 12)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "FS", sub_title=param_str)
elif pre_type == "FS" and post_type == "iSPN":
    sa.plot_connection_probability("FS", "iSPN", dist_3d=True, exp_max_dist=[100e-6, 150e-6, 250e-6], exp_data_detailed=[(6, 9), (21, 54), (27,77)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "iSPN", sub_title=param_str)
elif pre_type == "FS" and post_type == "dSPN":
    sa.plot_connection_probability("FS", "dSPN", dist_3d=True, exp_max_dist=[100e-6, 150e-6, 250e-6], exp_data_detailed=[(8, 9), (29, 48), (48,90)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "dSPN", sub_title=param_str)    
elif pre_type == "FS" and post_type == "LTS":
    sa.plot_connection_probability("FS", "LTS", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(2, 12)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "LTS", sub_title=param_str)
    
elif pre_type == 'LTS' and post_type == "dSPN":
    sa.plot_connection_probability("LTS", "dSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(2, 60)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("LTS", "dSPN", sub_title=param_str)
elif pre_type == 'LTS' and post_type == "iSPN":
    sa.plot_connection_probability("LTS", "iSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(2, 60)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("LTS", "iSPN", sub_title=param_str)
elif pre_type == 'ChIN' and post_type == "dSPN":
    sa.plot_connection_probability("ChIN", "dSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data=[0.05], sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "dSPN", sub_title=param_str)
elif pre_type == 'ChIN' and post_type == "iSPN":
    sa.plot_connection_probability("ChIN", "iSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data=[0.05], sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "iSPN", sub_title=param_str)

# Missing pairwise experimental data...
    
elif pre_type == 'ChIN' and post_type == "FS":
    sa.plot_connection_probability("ChIN", "FS", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(19, 26)],
                                   sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "FS", sub_title=param_str)
elif pre_type == 'ChIN' and post_type == "LTS":
    sa.plot_connection_probability("ChIN", "LTS", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(53,72)],
                                   sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "LTS", sub_title=param_str)

elif pre_type == 'LTS' and post_type == "ChIN":
    sa.plot_connection_probability("LTS", "ChIN", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("LTS", "ChIN", sub_title=param_str)

    
elif pre_type == 'dSPN' and post_type == "ChIN":
    sa.plot_connection_probability("dSPN", "ChIN", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("dSPN", "ChIN", sub_title=param_str)
elif pre_type == 'iSPN' and post_type == "ChIN":
    sa.plot_connection_probability("iSPN", "ChIN", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("iSPN", "ChIN", sub_title=param_str)

elif pre_type == 'NGF' and post_type == "dSPN":
    sa.plot_connection_probability("NGF", "dSPN", dist_3d=True, 
                                   exp_max_dist=[100e-6, 250e-6, 250e-6],
                                   exp_data_detailed=[(25,29), (11,14), (30,50)],
                                   sub_title=param_str)
    sa.plot_num_synapses_per_pair("NGF", "dSPN", sub_title=param_str)
elif pre_type == 'NGF' and post_type == "iSPN":
    sa.plot_connection_probability("NGF", "iSPN", dist_3d=True, 
                                   exp_max_dist=[100e-6, 250e-6, 250e-6],
                                   exp_data_detailed=[(25,29), (11,14), (30,50)],
                                   sub_title=param_str)
    sa.plot_num_synapses_per_pair("NGF", "iSPN", sub_title=param_str)
elif pre_type == 'NGF' and post_type == "ChIN":
    sa.plot_connection_probability("NGF", "ChIN", dist_3d=True, 
                                   exp_max_dist=[250e-6],
                                   exp_data_detailed=[(3,14)],
                                   sub_title=param_str)
    sa.plot_num_synapses_per_pair("NGF", "ChIN", sub_title=param_str)
# Out:
# Plotting connection probability ChIN to FS (synapses)
# Centering in None : Keeping 75/75
# Counting connections
# Requested: 10000000.0 calculated [5625.]
# P(d<0.00025) = 0.5684432515337423
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1439: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/ChIN_to_FS_f1_mu2_a3/figures/Network-distance-dependent-connection-probability-ChIN-to-FS-synapses-3D-dist.png
# Plotting number of connections
# Only analysing centre post synaptic neurons, sideLen = 0.00025
# Centering in None : Keeping 75/75
# Calculating max synapses
# Calculating mean synapses
# Plotting 3086 connections
# Wrote networks/ChIN_to_FS_f1_mu2_a3/figures/Network-number-of-synapses-from-ChIN-to-FS-per-cell.png
