# %%
import os
import numpy as np

from snudda import SnuddaPlace
from snudda import SnuddaDetect
from snudda.optimise.optimise_pruning import OptimisePruning
from snudda.analyse.analyse import SnuddaAnalyse

con_types = [('FS', 'FS', 4),
             ('FS', 'dSPN', 4),
             ('FS', 'iSPN', 4),
             ('dSPN', 'dSPN', 3),
             ('dSPN', 'iSPN', 3),
             ('iSPN', 'iSPN', 3)]


n_neurons = 150
con_type = "GABA"

SPN2SPNdistDepPruning = "1-exp(-(0.4*d/60e-6)**2)"
FS_dist_dep_pruning = "exp(-(0.5*d/60e-6)**2)"

all_experimental_data = dict()
all_experimental_data["dSPN", "iSPN"] = [(0, 50e-6, 3 / 47.0), (0, 100e-6, 3 / 66.0)]
all_experimental_data["dSPN", "dSPN"] = [(0, 50e-6, 5 / 19.0), (0, 100e-6, 3 / 43.0)]
all_experimental_data["iSPN", "iSPN"] = [(0, 50e-6, 14 / 39.0), (0, 100e-6, 7 / 31.0)]
all_experimental_data["iSPN", "dSPN"] = [(0, 50e-6, 13 / 47.0), (0, 100e-6, 10 / 80.0)]
all_experimental_data["FS", "FS"] = [(0, 250e-6, 7 / 12.0)]
all_experimental_data["FS", "iSPN"] = [(0, 100e-6, 6 / 9.0), (0, 150e-6, 21 / 54.0), (0, 250e-6, 27 / 77.0)]
all_experimental_data["FS", "dSPN"] = [(0, 100e-6, 8 / 9.0), (0, 150e-6, 29 / 48.0), (0, 250e-6, 48 / 90.0)]

# %%
for ct in con_types:
    
    OptimisePruning.op = None
    
    for dist_dep in [True, False]:
        for num_params in [1, 2, 3, 4]:

            pre_type = ct[0]
            post_type = ct[1]
            avg_num_synapses_per_pair = ct[2]

            distance_dependent_pruning = dist_dep

            extra_pruning_parameters = {}

            if distance_dependent_pruning:
                if pre_type == "FS" and (post_type == "dSPN" or post_type == "iSPN"):
                    extra_pruning_parameters = {'distPruning': FS_dist_dep_pruning}
                elif "SPN" in pre_type and "SPN" in post_type:
                    extra_pruning_parameters = {'distPruning': SPN2SPNdistDepPruning}
                else:
                    # No distance dependent pruning available for this neuron type, set it to False
                    distance_dependent_pruning = False

            dd_str = "_dd" if distance_dependent_pruning else ""
            network_path = os.path.join("networks", f"{pre_type}_to_{post_type}_np{num_params}{dd_str}")

            experimental_data = all_experimental_data[pre_type, post_type]

            cube_side = 1.5 * np.max([x[1] for x in experimental_data])

            # Place cube mesh and setup network config
            from snudda.place.create_cube_mesh import create_cube_mesh

            mesh_file = os.path.join(network_path, "cube-mesh.obj")
            create_cube_mesh(mesh_file, [0, 0, 0], cube_side)

            from snudda.init import SnuddaInit

            si = SnuddaInit(network_path=network_path, random_seed=123,
                            snudda_data="../../../../BasalGangliaData/data/")

            si.define_structure(struct_name="Cube", struct_mesh=mesh_file, d_min=12e-6, mesh_bin_width=25e-6)

            if pre_type == post_type:
                si.add_neurons(name=pre_type, num_neurons=n_neurons, volume_id="Cube",
                               neuron_dir=os.path.join("$DATA", "neurons", "striatum", "dspn"))
            else:
                si.add_neurons(name=pre_type, num_neurons=int(n_neurons / 2), volume_id="Cube",
                               neuron_dir=os.path.join("$DATA", "neurons", "striatum", "dspn"))
                si.add_neurons(name=post_type, num_neurons=int(n_neurons / 2), volume_id="Cube",
                               neuron_dir=os.path.join("$DATA", "neurons", "striatum", "dspn"))

            # The parameters here does not matter, they will be set during optimisation
            si.add_neuron_target(neuron_name=pre_type,
                                 target_name=post_type,
                                 connection_type=con_type,
                                 dist_pruning=None,
                                 f1=None, soft_max=None, mu2=None,
                                 a3=None,
                                 conductance=[0.24e-9, 0.1e-9],
                                 mod_file="tmGabaA")

            si.write_json()

            # Place neurons
            sp = SnuddaPlace(network_path=network_path, verbose=False)
            sp.place()

            sd = SnuddaDetect(network_path=network_path, hyper_voxel_size=100)
            sd.detect()

            op = OptimisePruning(network_path=network_path)
            op.merge_putative_synapses(force_merge=True)

            print(f"connectivity_distributions = {op.prune.connectivity_distributions}")
            print(f"type_id_lookup = {op.prune.type_id_lookup}")
            print(f"From hist_file: {op.prune.hist_file['meta/connectivityDistributions'][()]}")

            res = op.optimize(pre_type=pre_type, post_type=post_type, con_type=con_type,
                              experimental_data=experimental_data,
                              avg_num_synapses_per_pair=avg_num_synapses_per_pair,
                              extra_pruning_parameters=extra_pruning_parameters,
                              workers=8, maxiter=1000, tol=0.00001, num_params=num_params)

            if num_params == 1:
                param_str = f"f1 = %.4f" % (res.x[0])
            elif num_params == 2:
                param_str = f"f1 = %.4f, mu2 = %.4f" % (res.x[0], res.x[1])
            elif num_params == 3:
                param_str = f"f1 = %.4f, mu2 = %.4f, a3 = %.4f" % (res.x[0], res.x[1], res.x[2])
            elif num_params == 4:
                param_str = f"f1 = %.4f, softMax = %.4f, mu2 = %.4f, a3 = %.4f" % (res.x[0], res.x[1], res.x[2], res.x[3])
            else:
                param_str = res.x

            if "distPruning" in extra_pruning_parameters:
                param_str += f" ({extra_pruning_parameters['distPruning']})"

            print(param_str)
            print(res)

            # Get the last file
            # list_of_files = glob.glob(os.path.join(network_path, "temp", "network-synapses-*hdf5"))
            # network_file = max(list_of_files, key=os.path.getctime)

            network_file = os.path.join(network_path, "network-synapses.hdf5")

            dist3D = False
            y_max_H = None

            sa = SnuddaAnalyse(network_file)

            if pre_type == "dSPN" and post_type == "iSPN":
                sa.plot_connection_probability("dSPN", "iSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6],
                                               exp_data_detailed=[(3, 47), (3, 66)], sub_title=param_str)
                sa.plot_num_synapses_per_pair("dSPN", "iSPN", sub_title=param_str)
            elif pre_type == "dSPN" and post_type == "dSPN":
                sa.plot_connection_probability("dSPN", "dSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6],
                                               exp_data_detailed=[(5, 19), (3, 43)], sub_title=param_str)
                sa.plot_num_synapses_per_pair("dSPN", "dSPN", sub_title=param_str)
            elif pre_type == "iSPN" and post_type == "iSPN":
                sa.plot_connection_probability("iSPN", "iSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6],
                                               exp_data_detailed=[(14, 39), (7, 31)], sub_title=param_str)
                sa.plot_num_synapses_per_pair("iSPN", "iSPN", sub_title=param_str)
            elif pre_type == "iSPN" and post_type == "dSPN":
                sa.plot_connection_probability("iSPN", "dSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6],
                                               exp_data_detailed=[(13, 47), (10, 80)], sub_title=param_str)
                sa.plot_num_synapses_per_pair("iSPN", "dSPN", sub_title=param_str)
            elif pre_type == "FS" and post_type == "FS":
                sa.plot_connection_probability("FS", "FS", dist_3d=True, exp_max_dist=[250e-6],
                                               exp_data_detailed=[(7, 12)], sub_title=param_str)
                sa.plot_num_synapses_per_pair("FS", "FS", sub_title=param_str)
            elif pre_type == "FS" and post_type == "iSPN":
                sa.plot_connection_probability("FS", "iSPN", dist_3d=True, exp_max_dist=[100e-6, 150e-6, 250e-6],
                                               exp_data_detailed=[(6, 9), (21, 54), (27, 77)], sub_title=param_str)
                sa.plot_num_synapses_per_pair
synapses
# connectivity_distributions = {(1, 1, 10): (OrderedDict([('f1', 1.0), ('softMax', None), ('mu2', None), ('a3', None), ('distPruning', None), ('cluster', False)]), None)}
# type_id_lookup = {'FS': 1}
# From hist_file: b'{"FS$$FS": {"GABA": {"conductance": [2.4e-10, 1e-10], "channelParameters": {"modFile": "tmGabaA"}, "clusterSize": 1, "clusterSpread": null, "pruning": {"f1": null, "softMax": null, "mu2": null, "a3": null, "distPruning": null, "cluster": false}, "channelModelID": 10, "lognormal_mu_sigma": [-22.230424900260093, 0.40010675493807013]}}}'
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py:377: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# Duration: 20.397720424007275 s
# f1 = 0.6584
#      fun: 7.191659793305009
#  message: 'Optimization terminated successfully.'
#     nfev: 407
#      nit: 26
#  success: True
#        x: array([0.65837269])
# Assuming volume type: cube [cube or full]
# Only using 20000 neurons of the connection data
# Number of neurons: 150
# Synapse row 0 - 0.0 % time: 0.0030814289930276573 seconds
# Created connection matrix 0.03388009600166697 seconds
# Created gap junction connection matrix 0.0002064180007437244 seconds
# Creating population dictionary
# Done.
# Taking corner neurons: Keeping 150/150
# Calculating synapse distance histogram
# Creating dist histogram
# n_synapses = 40993, at 0
# Created distance histogram (optimised) in 0.043248382993624546 seconds
# Saving cache to networks/FS_to_FS_np1/network-synapses.hdf5-cache
# Plotting connection probability FS to FS (synapses)
# Centering in None : Keeping 150/150
# Counting connections
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1394: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Requested: 10000000.0 calculated [22350.]
# P(d<0.00025) = 0.5658516020236087
# Wrote networks/FS_to_FS_np1/figures/Network-distance-dependent-connection-probability-FS-to-FS-synapses-3D-dist.pdf
# Plotting number of connections
# Only analysing centre post synaptic neurons, sideLen = 0.00025
# Centering in None : Keeping 150/150
# Calculating max synapses
# Calculating mean synapses
# Plotting 7570 connections
# Wrote networks/FS_to_FS_np1/figures/Network-number-of-synapses-from-FS-to-FS-per-cell.pdf
# Adding neurons: FS from dir /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn
# Writing networks/FS_to_FS_np2/network-config.json
# Reading SNUDDA_DATA=../../../../BasalGangliaData/data/ from networks/FS_to_FS_np2/network-config.json
# Reading SNUDDA_DATA=../../../../BasalGangliaData/data/ from networks/FS_to_FS_np2/network-config.json
# No d_view specified, running distribute neurons in serial
# Processing hyper voxel : 72/180 (139 neurons)
# Processing hyper voxel : 71/180 (131 neurons)
# Processing hyper voxel : 67/180 (105 neurons)
# Processing hyper voxel : 66/180 (100 neurons)
# Processing hyper voxel : 42/180 (81 neurons)
# Processing hyper voxel : 41/180 (74 neurons)
# Processing hyper voxel : 101/180 (73 neurons)
# Processing hyper voxel : 102/180 (71 neurons)
# Processing hyper voxel : 77/180 (60 neurons)
# Processing hyper voxel : 37/180 (59 neurons)
# Processing hyper voxel : 36/180 (56 neurons)
# Processing hyper voxel : 96/180 (53 neurons)
# Processing hyper voxel : 76/180 (50 neurons)
# Processing hyper voxel : 97/180 (43 neurons)
# Processing hyper voxel : 73/180 (36 neurons)
# Processing hyper voxel : 70/180 (32 neurons)
# Processing hyper voxel : 107/180 (28 neurons)
# Processing hyper voxel : 47/180 (26 neurons)
# Processing hyper voxel : 106/180 (25 neurons)
# Processing hyper voxel : 46/180 (24 neurons)
# Processing hyper voxel : 65/180 (23 neurons)
# Processing hyper voxel : 68/180 (21 neurons)
# Processing hyper voxel : 40/180 (17 neurons)
# Processing hyper voxel : 100/180 (16 neurons)
# Processing hyper voxel : 103/180 (15 neurons)
# Processing hyper voxel : 38/180 (12 neurons)
# Processing hyper voxel : 43/180 (12 neurons)
# Processing hyper voxel : 62/180 (11 neurons)
# Processing hyper voxel : 75/180 (11 neurons)
# Processing hyper voxel : 95/180 (9 neurons)
# Processing hyper voxel : 98/180 (9 neurons)
# Processing hyper voxel : 12/180 (8 neurons)
# Processing hyper voxel : 61/180 (7 neurons)
# Processing hyper voxel : 35/180 (7 neurons)
# Processing hyper voxel : 78/180 (7 neurons)
# Processing hyper voxel : 11/180 (6 neurons)
# Processing hyper voxel : 32/180 (6 neurons)
# Processing hyper voxel : 31/180 (5 neurons)
# Processing hyper voxel : 68/180 (21 neurons)
# Processing hyper voxel : 40/180 (17 neurons)
# Processing hyper voxel : 100/180 (16 neurons)
# Processing hyper voxel : 103/180 (15 neurons)
# Processing hyper voxel : 38/180 (12 neurons)
# Processing hyper voxel : 43/180 (12 neurons)
# Processing hyper voxel : 62/180 (11 neurons)
# Processing hyper voxel : 75/180 (11 neurons)
# Processing hyper voxel : 95/180 (9 neurons)
# Processing hyper voxel : 98/180 (9 neurons)
# Processing hyper voxel : 12/180 (8 neurons)
# Processing hyper voxel : 61/180 (7 neurons)
# Processing hyper voxel : 35/180 (7 neurons)
# Processing hyper voxel : 78/180 (7 neurons)
# Processing hyper voxel : 11/180 (6 neurons)
# Processing hyper voxel : 32/180 (6 neurons)
# Processing hyper voxel : 31/180 (5 neurons)
# Processing hyper voxel : 7/180 (5 neurons)
# Processing hyper voxel : 45/180 (5 neurons)
# Processing hyper voxel : 132/180 (4 neurons)
# Processing hyper voxel : 105/180 (3 neurons)
# Processing hyper voxel : 127/180 (3 neurons)
# Processing hyper voxel : 91/180 (3 neurons)
# Processing hyper voxel : 131/180 (3 neurons)
# Processing hyper voxel : 6/180 (3 neurons)
# Processing hyper voxel : 16/180 (3 neurons)
# Processing hyper voxel : 126/180 (2 neurons)
# Processing hyper voxel : 137/180 (2 neurons)
# Processing hyper voxel : 33/180 (2 neurons)
# Processing hyper voxel : 82/180 (1 neurons)
# Processing hyper voxel : 81/180 (1 neurons)
# Processing hyper voxel : 63/180 (1 neurons)
# Processing hyper voxel : 48/180 (1 neurons)
# Processing hyper voxel : 108/180 (1 neurons)
# Processing hyper voxel : 111/180 (1 neurons)
# Processing hyper voxel : 17/180 (1 neurons)
# Processing hyper voxel : 10/180 (1 neurons)
# Processing hyper voxel : 8/180 (1 neurons)
# Processing hyper voxel : 92/180 (1 neurons)
# Processing hyper voxel : 1/180 (1 neurons)
# Read 61886 out of total 61886 synapses
# connectivity_distributions = {(1, 1, 10): (OrderedDict([('f1', 1.0), ('softMax', None), ('mu2', None), ('a3', None), ('distPruning', None), ('cluster', False)]), None)}
# type_id_lookup = {'FS': 1}
# From hist_file: b'{"FS$$FS": {"GABA": {"conductance": [2.4e-10, 1e-10], "channelParameters": {"modFile": "tmGabaA"}, "clusterSize": 1, "clusterSpread": null, "pruning": {"f1": null, "softMax": null, "mu2": null, "a3": null, "distPruning": null, "cluster": false}, "channelModelID": 10, "lognormal_mu_sigma": [-22.230424900260093, 0.40010675493807013]}}}'
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py:377: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# Worker iter: 100, fitness 7.191659793305009
# Worker iter: 100, fitness 7.191659793305009
# Worker iter: 100, fitness 7.191659793305009
# Worker iter: 100, fitness 7.191659793305009
# Worker iter: 100, fitness 7.191659793305009
# Worker iter: 100, fitness 7.191659793305009
# Worker iter: 100, fitness 7.191659793305009
# Worker iter: 100, fitness 7.191659793305009
# Worker iter: 200, fitness 7.191659793305009
# Worker iter: 200, fitness 7.191659793305009
# Worker iter: 200, fitness 7.191659793305009
# Worker iter: 200, fitness 7.191659793305009
# Worker iter: 200, fitness 7.191659793305009
# Worker iter: 200, fitness 7.191659793305009
# Worker iter: 200, fitness 7.191659793305009
# Worker iter: 200, fitness 7.191659793305009
# Worker iter: 300, fitness 7.191659793305009
# Worker iter: 300, fitness 7.191659793305009
# Worker iter: 300, fitness 7.191659793305009
# Worker iter: 300, fitness 7.191659793305009
# Worker iter: 300, fitness 7.191659793305009
# Worker iter: 300, fitness 7.191659793305009
# Worker iter: 300, fitness 7.191659793305009
# Worker iter: 300, fitness 7.191659793305009
# Duration: 163.77091402900987 s
# f1 = 0.6584, mu2 = 0.3548, a3 = 1.0000
#      fun: 7.191659793305009
#  message: 'Optimization terminated successfully.'
#     nfev: 3064
#      nit: 67
#  success: True
#        x: array([0.65837262, 0.35475964, 0.99998975])
# Assuming volume type: cube [cube or full]
# Only using 20000 neurons of the connection data
# Number of neurons: 150
# Synapse row 0 - 0.0 % time: 0.00312921499426011 seconds
# Created connection matrix 0.03254194700275548 seconds
# Created gap junction connection matrix 0.0002727090031839907 seconds
# Creating population dictionary
# Done.
# Taking corner neurons: Keeping 150/150
# Calculating synapse distance histogram
# Creating dist histogram
# n_synapses = 40993, at 0
# Created distance histogram (optimised) in 0.042107760993530974 seconds
# Saving cache to networks/FS_to_FS_np3/network-synapses.hdf5-cache
# Plotting connection probability FS to FS (synapses)
# Centering in None : Keeping 150/150
# Counting connections
# Requested: 10000000.0 calculated [22350.]
# P(d<0.00025) = 0.5658516020236087
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1394: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/FS_to_FS_np3/figures/Network-distance-dependent-connection-probability-FS-to-FS-synapses-3D-dist.pdf
# Plotting number of connections
# Only analysing centre post synaptic neurons, sideLen = 0.00025
# Centering in None : Keeping 150/150
# Calculating max synapses
# Calculating mean synapses
# Plotting 7570 connections
# Wrote networks/FS_to_FS_np3/figures/Network-number-of-synapses-from-FS-to-FS-per-cell.pdf
# Adding neurons: FS from dir /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn
# Writing networks/FS_to_FS_np4/network-config.json
# Reading SNUDDA_DATA=../../../../BasalGangliaData/data/ from networks/FS_to_FS_np4/network-config.json
# Reading SNUDDA_DATA=../../../../BasalGangliaData/data/ from networks/FS_to_FS_np4/network-config.json
# No d_view specified, running distribute neurons in serial
# Processing hyper voxel :
UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# Worker iter: 100, fitness 2.9863074219258525
# Worker iter: 100, fitness 2.9230760600747465
# Worker iter: 100, fitness 2.917703344861139Worker iter: 100, fitness 3.1117240147300294
#
# Worker iter: 100, fitness 2.9213791893132353
# Worker iter: 100, fitness 2.936619807523078Worker iter: 100, fitness 3.6823761641738257
#
# Worker iter: 100, fitness 2.928414927802902
# Worker iter: 200, fitness 2.6663370990508732
# Worker iter: 200, fitness 2.7569238622487577
# Worker iter: 200, fitness 2.6718248706635337
# Worker iter: 200, fitness 2.6360462121938815
# Worker iter: 200, fitness 2.6900437100349563
# Worker iter: 200, fitness 2.61195296815846
# Worker iter: 200, fitness 2.6812576586527523
# Worker iter: 200, fitness 2.664594379666849
# Worker iter: 300, fitness 2.556486160000885
# Worker iter: 300, fitness 2.585039357604256
# Worker iter: 300, fitness 2.581036633074025
# Worker iter: 300, fitness 2.542404097171272
# Worker iter: 300, fitness 2.5194801961641997
# Worker iter: 300, fitness 2.593428864473695
# Worker iter: 300, fitness 2.61195296815846
# Worker iter: 300, fitness 2.587541576301357
# Worker iter: 400, fitness 2.3556394491322283
# Worker iter: 400, fitness 2.4069975879890584
# Worker iter: 400, fitness 2.4767153343611517
# Worker iter: 400, fitness 2.4165845733237323
# Worker iter: 400, fitness 2.372096866617701
# Worker iter: 400, fitness 2.3828385696804837
# Worker iter: 400, fitness 2.4153917669510316
# Worker iter: 400, fitness 2.3634557595966674
# Worker iter: 500, fitness 2.3171331623676177
# Worker iter: 500, fitness 2.3447434193556154
# Worker iter: 500, fitness 2.3056510089850284
# Worker iter: 500, fitness 2.303043294679268
# Worker iter: 500, fitness 2.3060886254170367
# Worker iter: 500, fitness 2.2922995138430298
# Worker iter: 500, fitness 2.3145503465596766
# Worker iter: 500, fitness 2.262546649309316
# Worker iter: 600, fitness 2.2866363169267485
# Worker iter: 600, fitness 2.2638312533637364
# Worker iter: 600, fitness 2.2698553709185854
# Worker iter: 600, fitness 2.303043294679268
# Worker iter: 600, fitness 2.2526888539422742
# Worker iter: 600, fitness 2.2913664533280715
# Worker iter: 600, fitness 2.2692088354677056
# Worker iter: 600, fitness 2.262546649309316
# Worker iter: 700, fitness 2.2777099290738736
# Worker iter: 700, fitness 2.2654776765426043
# Worker iter: 700, fitness 2.2526888539422742
# Worker iter: 700, fitness 2.260457230266627
# Worker iter: 700, fitness 2.26399256443651
# Worker iter: 700, fitness 2.2703137274107856
# Worker iter: 700, fitness 2.2632391123439595
# Worker iter: 700, fitness 2.255878454089177
# Worker iter: 800, fitness 2.263860605330649
# Worker iter: 800, fitness 2.2532636617391155
# Worker iter: 800, fitness 2.2557141793897113
# Worker iter: 800, fitness 2.252287596449593
# Worker iter: 800, fitness 2.252287596449593
# Worker iter: 800, fitness 2.259709445319327
# Worker iter: 800, fitness 2.246908170586725
# Worker iter: 800, fitness 2.247541474897267
# Worker iter: 900, fitness 2.2468797542907946
# Worker iter: 900, fitness 2.2481539481418307
# Worker iter: 900, fitness 2.250890440931275
# Worker iter: 900, fitness 2.2507717964356986
# Worker iter: 900, fitness 2.2450104919776748
# Worker iter: 900, fitness 2.247835068109042
# Worker iter: 900, fitness 2.246908170586725
# Worker iter: 900, fitness 2.247541474897267
# Worker iter: 1000, fitness 2.2455621635168557
# Worker iter: 1000, fitness 2.244929822992258
# Worker iter: 1000, fitness 2.24622286925141
# Worker iter: 1000, fitness 2.244842143518337
# Worker iter: 1000, fitness 2.2448576359434713
# Worker iter: 1000, fitness 2.2457138394256067
# Worker iter: 1000, fitness 2.2453250424429916
# Worker iter: 1000, fitness 2.245459093525154
# Worker iter: 1100, fitness 2.24491942834718
# Worker iter: 1100, fitness 2.244842143518337
# Worker iter: 1100, fitness 2.244842143518337
# Worker iter: 1100, fitness 2.24482663335647
# Worker iter: 1100, fitness 2.244710538495028
# Worker iter: 1100, fitness 2.2448576359434713
# Worker iter: 1100, fitness 2.244842143518337
# Worker iter: 1100, fitness 2.244813765241372
# Worker iter: 1200, fitness 2.2436597084006853
# Worker iter: 1200, fitness 2.2436597084006853
# Worker iter: 1200, fitness 2.243527989664021
# Worker iter: 1200, fitness 2.2441763663226717
# Worker iter: 1200, fitness 2.2443411378267806
# Worker iter: 1200, fitness 2.2440571507519773
# Worker iter: 1200, fitness 2.244400121211454
# Worker iter: 1200, fitness 2.244044722077393
# Worker iter: 1300, fitness 2.243512540732447
# Worker iter: 1300, fitness 2.243512540732447
# Worker iter: 1300, fitness 2.243512540732447
# Worker iter: 1300, fitness 2.243512540732447
# Worker iter: 1300, fitness 2.243512540732447
# Worker iter: 1300, fitness 2.243512540732447
# Worker iter: 1300, fitness 2.243512540732447
# Worker iter: 1300, fitness 2.243512540732447
# Worker iter: 1400, fitness 2.243512540732447
# Worker iter: 1400, fitness 2.243512540732447
# Worker iter: 1400, fitness 2.243512540732447
# Duration: 740.2870886760065 s
# f1 = 0.9999, softMax = 3.4777, mu2 = 0.9899, a3 = 0.9999
#      fun: 2.243512540732447
#  message: 'Optimization terminated successfully.'
#     nfev: 11045
#      nit: 183
#  success: True
#        x: array([0.99991987, 3.47773969, 0.98986983, 0.99994908])
# Assuming volume type: cube [cube or full]
# Only using 20000 neurons of the connection data
# Number of neurons: 150
# Synapse row 0 - 0.0 % time: 0.0026105919969268143 seconds
# Created connection matrix 0.02727642199897673 seconds
# Created gap junction connection matrix 0.00023783399956300855 seconds
# Creating population dictionary
# Done.
# Taking corner neurons: Keeping 150/150
# Calculating synapse distance histogram
# Creating dist histogram
# n_synapses = 30059, at 0
# Created distance histogram (optimised) in 0.03316523200192023 seconds
# Saving cache to networks/FS_to_FS_np4/network-synapses.hdf5-cache
# Plotting connection probability FS to FS (synapses)
# Centering in None : Keeping 150/150
# Counting connections
# Requested: 10000000.0 calculated [22350.]
# P(d<0.00025) = 0.5644182124789208
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1394: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/FS_to_FS_np4/figures/Network-distance-dependent-connection-probability-FS-to-FS-synapses-3D-dist.pdf
# Plotting number of connections
# Only analysing centre post synaptic neurons, sideLen = 0.00025
# Centering in None : Keeping 150/150
# Calculating max synapses
# Calculating mean synapses
# Plotting 7517 connections
# Wrote networks/FS_to_FS_np4/figures/Network-number-of-synapses-from-FS-to-FS-per-cell.pdf
# Adding neurons: FS from dir /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn
# Writing networks/FS_to_FS_np1/network-config.json
# Reading SNUDDA_DATA=../../../../BasalGangliaData/data/ from networks/FS_to_FS_np1/network-config.json
# Reading SNUDDA_DATA=../../../../BasalGangliaData/data/ from networks/FS_to_FS_np1/network-config.json
# No d_view specified, running distribute neurons in serial
# Processing hyper voxel : 72/180 (139 neurons)
# Processing hyper voxel : 71/180 (131 neurons)
# Processing hyper voxel : 67/180 (105 neurons)
# Processing hyper voxel : 66/180 (100 neurons)
# Processing hyper voxel : 42/180 (81 neurons)
# Processing hyper voxel : 41/180 (74 neurons)
# Processing hyper voxel : 101/180 (73 neurons)
# Processing hyper voxel : 102/180 (71 neurons)
# Processing hyper voxel : 77/180 (60 neurons)
# Processing hyper voxel : 37/180 (59 neurons)
# Processing hyper voxel : 36/180 (56 neurons)
# Processing hyper voxel : 96/180 (53 neurons)
# Processing hyper voxel : 76/180 (50 neurons)
# Processing hyper voxel : 97/180 (43 neurons)
# Processing hyper voxel : 73/180 (36 neurons)
# Processing hyper voxel : 70/180 (32 neurons)
# Processing hyper voxel : 107/180 (28 neurons)
# Processing hyper voxel : 47/180 (26 neurons)
# Processing hyper voxel : 106/180 (25 neurons)
# Processing hyper voxel : 46/180 (24 neurons)
# Processing hyper voxel : 65/180 (23 neurons)
# Processing hyper voxel : 68/180 (21 neurons)
# Processing hyper voxel : 40/180 (17 neurons)
# Processing hyper voxel : 100/180 (16 neurons)
# Processing hyper voxel : 103/180 (15 neurons)
# Processing hyper voxel : 38/180 (12 neurons)
# Processing hyper voxel : 43/180 (12 neurons)
# Processing hyper voxel : 62/180 (11 neurons)
# Processing hyper voxel : 75/180 (11 neurons)
# Processing hyper voxel : 95/180 (9 neurons)
# Processing hyper voxel : 98/180 (9 neurons)
# Processing hyper voxel : 12/180 (8 neurons)
# Processing hyper voxel : 61/180 (7 neurons)
# Processing hyper voxel : 35/180 (7 neurons)
# Processing hyper voxel : 78/180 (7 neurons)
# Processing hyper voxel : 11/180 (6 neurons)
# Processing hyper voxel : 32/180 (6 neurons)
# Processing hyper voxel : 31/180 (5 neurons)
# Processing hyper voxel : 7/180 (5 neurons)
# Processing hyper voxel : 45/180 (5 neurons)
# Processing hyper voxel : 132/180 (4 neurons)
# Processing hyper voxel : 105/180 (3 neurons)
# Processing hyper voxel : 127/180 (3 neurons)
# Processing hyper voxel : 91/180 (3 neurons)
# Processing hyper voxel : 131/180 (3 neurons)
# Processing hyper voxel : 6/180 (3 neurons)
# Processing hyper voxel : 16/180 (3 neurons)
# Processing hyper voxel : 126/180 (2 neurons)
# Processing hyper voxel : 137/180 (2 neurons)
# Processing hyper voxel : 33/180 (2 neurons)
# Processing hyper voxel : 82/180 (1 neurons)
# Processing hyper voxel : 81/180 (1 neurons)
# Processing hyper voxel : 63/180 (1 neurons)
# Processing hyper voxel : 48/180 (1 neurons)
# Processing hyper voxel : 108/180 (1 neurons)
# Processing hyper voxel : 111/180 (1 neurons)
# Processing hyper voxel : 17/180 (1 neurons)
# Processing hyper voxel : 10/180 (1 neurons)
# Processing hyper voxel : 8/180 (1 neurons)
# Processing hyper voxel : 92/180 (1 neurons)
# Processing hyper voxel : 1/180 (1 neurons)
# Read 61886 out of total 61886 synapses
# connectivity_distributions = {(1, 1, 10): (OrderedDict([('f1', 1.0), ('softMax', None), ('mu2', None), ('a3', None), ('distPruning', None), ('cluster', False)]), None)}
# type_id_lookup = {'FS': 1}
# From hist_file: b'{"FS$$FS": {"GABA": {"conductance": [2.4e-10, 1e-10], "channelParameters": {"modFile": "tmGabaA"}, "clusterSize": 1, "clusterSpread": null, "pruning": {"f1": null, "softMax": null, "mu2": null, "a3": null, "distPruning": null, "cluster": false}, "channelModelID": 10, "lognormal_mu_sigma": [-22.230424900260093, 0.40010675493807013]}}}'
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/scipy/optimize/_differentialevolution.py:377: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# Duration: 15.307236198990722 s
# f1 = 0.6584
#      fun: 7.191659793305009
#  message: 'Optimization terminated successfully.'
#     nfev: 302
#      nit: 19
#  success: True
#        x: array([0.65837278])
# Assuming volume type: cube [cube or full]
# Only using 20000 neurons of the connection data
# Number of neurons: 150
# Synapse row 0 - 0.0 % time: 0.0028968840051675215 seconds
# Created connection matrix 0.03261406499950681 seconds
# Created gap junction connection matrix 0.0001950430014403537 seconds
# Creating population dictionary
# Done.
# Taking corner neurons: Keeping 150/150
# Calculating synapse distance histogram
# Creating dist histogram
# n_synapses = 40993, at 0
# Created distance histogram (optimised) in 0.04245838799397461 seconds
# Saving cache to networks/FS_to_FS_np1/network-synapses.hdf5-cache
# Plotting connection probability FS to FS (synapses)
# Centering in None : Keeping 150/150
# Counting connections
# Requested: 10000000.0 calculated [22350.]
# P(d<0.00025) = 0.5658516020236087
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1394: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/FS_to_FS_np1/figures/Network-distance-dependent-connection-probability-FS-to-FS-synapses-3D-dist.pdf
# Plotting number of connections
# Only analysing centre post synaptic neurons, sideLen = 0.00025
# Centering in None : Keeping 150/150
# Calculating max synapses
# Calculating mean synapses
# Plotting 7570 connections
# Wrote networks/FS_to_FS_np1/figures/Network-number-of-synapses-from-FS-to-FS-per-cell.pdf
# Adding neurons: FS from dir /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn
# Writing networks/FS_to_FS_np2/network-config.json
# Reading SNUDDA_DATA=../../../../BasalGangliaData/data/ from networks/FS_to_FS_np2/network-config.json
# Reading SNUDDA_DATA=../../../../BasalGangliaData/data/ from networks/FS_to_FS_np2/network-config.json
# No d_view specified, running distribute neurons in serial
# Processing hyper voxel :
UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# Worker iter: 100, fitness 2.243512540732447
# Worker iter: 100, fitness 2.243512540732447
# Worker iter: 100, fitness 2.243512540732447
# Worker iter: 100, fitness 2.243512540732447
# Worker iter: 100, fitness 2.243512540732447
# Worker iter: 100, fitness 2.243512540732447
# Worker iter: 100, fitness 2.243512540732447
# Worker iter: 100, fitness 2.243512540732447
# Traceback (most recent call last):
#   File "/home/hjorth/HBP/Snudda/snudda/detect/prune.py", line 1906, in prune_synapses
#     num_syn_kept += self.prune_synapses_helper(synapses=synapses, output_file=self.out_file,
#   File "/home/hjorth/HBP/Snudda/snudda/detect/prune.py", line 2145, in prune_synapses_helper
#     output_file[h5_syn_mat][write_start_pos:write_end_pos] = \
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "/home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/h5py/_hl/dataset.py", line 982, in __setitem__
#     self.id.write(mspace, fspace, val, mtype, dxpl=self._dxpl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5d.pyx", line 232, in h5py.h5d.DatasetID.write
#   File "h5py/_proxy.pyx", line 114, in h5py._proxy.dset_rw
# OSError: [Errno 28] Can't write data (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-cffa45f4-c206-458a-a64e-87f0ef546ec0.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x24e4e170, total write size = 234759, bytes this sub-write = 234759, bytes actually written = 18446744073709551615, offset = 0)
# Traceback (most recent call last):
#   File "/home/hjorth/HBP/Snudda/snudda/detect/prune.py", line 1906, in prune_synapses
#     num_syn_kept += self.prune_synapses_helper(synapses=synapses, output_file=self.out_file,
#   File "/home/hjorth/HBP/Snudda/snudda/detect/prune.py", line 2145, in prune_synapses_helper
#     output_file[h5_syn_mat][write_start_pos:write_end_pos] = \
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "/home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/h5py/_hl/dataset.py", line 982, in __setitem__
#     self.id.write(mspace, fspace, val, mtype, dxpl=self._dxpl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5d.pyx", line 232, in h5py.h5d.DatasetID.write
#   File "h5py/_proxy.pyx", line 114, in h5py._proxy.dset_rw
# OSError: [Errno 28] Can't write data (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-cfcf3d34-b70a-495a-ae5c-732959595b2a.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x24e4e170, total write size = 234759, bytes this sub-write = 234759, bytes actually written = 18446744073709551615, offset = 0)
#
#
# Unable to write to log file. Is log file closed?Unable to write to log file. Is log file closed?
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File h5py/_objects.pyx:201, in h5py._objects.ObjectID.__dealloc__()
#
# RuntimeError: Can't close dataset (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-4c2505ab-172e-4a1f-9f85-c332f9bc76d5.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x24e78fb0, total write size = 57786, bytes this sub-write = 57786, bytes actually written = 18446744073709551615, offset = 0)
# Exception ignored in: 'h5py._objects.ObjectID.__dealloc__'
# Traceback (most recent call last):
#   File "h5py/_objects.pyx", line 201, in h5py._objects.ObjectID.__dealloc__
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File h5py/_objects.pyx:201, in h5py._objects.ObjectID.__dealloc__()
#
# RuntimeError: Can't decrement id ref count (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-cffa45f4-c206-458a-a64e-87f0ef546ec0.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x201c6190, total write size = 234118, bytes this sub-write = 234118, bytes actually written = 18446744073709551615, offset = 0)
# RuntimeErrorException ignored in: : 'h5py._objects.ObjectID.__dealloc__'
# Traceback (most recent call last):
#   File "h5py/_objects.pyx", line 201, in h5py._objects.ObjectID.__dealloc__
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File h5py/_objects.pyx:201, in h5py._objects.ObjectID.__dealloc__()
#
# RuntimeError: Can't decrement id ref count (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-cfcf3d34-b70a-495a-ae5c-732959595b2a.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x201c6190, total write size = 234114, bytes this sub-write = 234114, bytes actually written = 18446744073709551615, offset = 0)
# Can't close dataset (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-4c2505ab-172e-4a1f-9f85-c332f9bc76d5.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x24e78fb0, total write size = 57786, bytes this sub-write = 57786, bytes actually written = 18446744073709551615, offset = 0)Exception ignored in: 'h5py._objects.ObjectID.__dealloc__'
# RuntimeError
# prune_synapses: No synapse_file specified for gapJunctions -- none detected?
# Traceback (most recent call last):
# Unable to write to log file. Is log file closed?
#   File "h5py/_objects.pyx", line 201, in h5py._objects.ObjectID.__dealloc__
# Traceback (most recent call last):
#   File "/home/hjorth/HBP/Snudda/snudda/detect/prune.py", line 1906, in prune_synapses
#     num_syn_kept += self.prune_synapses_helper(synapses=synapses, output_file=self.out_file,
#   File "/home/hjorth/HBP/Snudda/snudda/detect/prune.py", line 2145, in prune_synapses_helper
#     output_file[h5_syn_mat][write_start_pos:write_end_pos] = \
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "/home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/h5py/_hl/dataset.py", line 982, in __setitem__
#     self.id.write(mspace, fspace, val, mtype, dxpl=self._dxpl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5d.pyx", line 232, in h5py.h5d.DatasetID.write
#   File "h5py/_proxy.pyx", line 114, in h5py._proxy.dset_rw
# OSError: [Errno 28] Can't write data (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-e4ad4b72-afb5-4609-bb80-11d2e7b7ec62.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x24e4e170, total write size = 234759, bytes this sub-write = 234759, bytes actually written = 18446744073709551615, offset = 0)
# : RuntimeErrorCan't decrement id ref count (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-cffa45f4-c206-458a-a64e-87f0ef546ec0.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x201c6190, total write size = 234118, bytes this sub-write = 234118, bytes actually written = 18446744073709551615, offset = 0)
# Unable to write to log file. Is log file closed?
# : Can't decrement id ref count (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-cfcf3d34-b70a-495a-ae5c-732959595b2a.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x201c6190, total write size = 234114, bytes this sub-write = 234114, bytes actually written = 18446744073709551615, offset = 0)
# Traceback (most recent call last):
#   File "/home/hjorth/HBP/Snudda/snudda/detect/prune.py", line 1906, in prune_synapses
#     num_syn_kept += self.prune_synapses_helper(synapses=synapses, output_file=self.out_file,
#   File "/home/hjorth/HBP/Snudda/snudda/detect/prune.py", line 2145, in prune_synapses_helper
#     output_file[h5_syn_mat][write_start_pos:write_end_pos] = \
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "/home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/h5py/_hl/dataset.py", line 982, in __setitem__
#     self.id.write(mspace, fspace, val, mtype, dxpl=self._dxpl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5d.pyx", line 232, in h5py.h5d.DatasetID.write
#   File "h5py/_proxy.pyx", line 114, in h5py._proxy.dset_rw
# OSError: [Errno 28] Can't write data (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-4557a94d-8191-41b4-87a2-7011b46e6354.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x24e4e170, total write size = 234745, bytes this sub-write = 234745, bytes actually written = 18446744073709551615, offset = 0)
# Unable to write to log file. Is log file closed?
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File h5py/_objects.pyx:201, in h5py._objects.ObjectID.__dealloc__()
#
# RuntimeError: Can't decrement id ref count (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-e4ad4b72-afb5-4609-bb80-11d2e7b7ec62.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x201c6190, total write size = 234115, bytes this sub-write = 234115, bytes actually written = 18446744073709551615, offset = 0)
# Exception ignored in: 'h5py._objects.ObjectID.__dealloc__'Exception ignored in:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File h5py/_objects.pyx:201, in h5py._objects.ObjectID.__dealloc__()
#
# RuntimeError: Can't decrement id ref count (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-4557a94d-8191-41b4-87a2-7011b46e6354.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x201c6190, total write size = 234126, bytes this sub-write = 234126, bytes actually written = 18446744073709551615, offset = 0)
# 'h5py._objects.ObjectID.__dealloc__'Traceback (most recent call last):
#
#   File "h5py/_objects.pyx", line 201, in h5py._objects.ObjectID.__dealloc__
# Traceback (most recent call last):
#   File "h5py/_objects.pyx", line 201, in h5py._objects.ObjectID.__dealloc__
# RuntimeErrorRuntimeError: : Can't decrement id ref count (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-4557a94d-8191-41b4-87a2-7011b46e6354.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x201c6190, total write size = 234126, bytes this sub-write = 234126, bytes actually written = 18446744073709551615, offset = 0)Can't decrement id ref count (file write failed: time = Thu Mar  2 18:01:43 2023
# , filename = 'networks/FS_to_FS_np2/temp/network-synapses-e4ad4b72-afb5-4609-bb80-11d2e7b7ec62.hdf5', file descriptor = 66, errno = 28, error message = 'No space left on device', buf = 0x201c6190, total write size = 234115, bytes this sub-write = 234115, bytes actually written = 18446744073709551615, offset = 0)
