# %% [markdown]
# # Optimise pruning parameters
#
# This Notebook shows how to optimise the pruning parameters of your network based on pairwise connectivity data.
#
# First we need to create a small network that we can use for the optimisation of the pruning parameters.
#
# In this example we do not need to have realistic neuron densities, so we will place the neurons in a cube of diameter 150 micrometers.

# %%
import os
import numpy as np

n_neurons = 300

pop_size = 15
# epochs = 10

pre_type = "iSPN"     # "iSPN"
post_type = "dSPN"  # "iSPN"
con_type = "GABA"

avg_num_synapses_per_pair = 3  # Expected mean, error weight

# param_names = ["f1", "softMax", "mu2", "a3"]
param_names = ["f1", "mu2", "a3"]

distance_dependent_pruning = True

SPN2SPNdistDepPruning = "1-exp(-(0.4*d/60e-6)**2)"
FS_dist_dep_pruning = "exp(-(0.5*d/60e-6)**2)" 
LTS_dist_dep_pruning = "1-exp(-(0.4*d/60e-6)**2)"


extra_pruning_parameters = { }

if distance_dependent_pruning:
    if pre_type == "FS" and (post_type == "dSPN" or post_type == "iSPN"):
        extra_pruning_parameters = { 'distPruning': FS_dist_dep_pruning }
    elif "SPN" in pre_type and "SPN" in post_type:
        extra_pruning_parameters = { 'distPruning': SPN2SPNdistDepPruning }
    elif "LTS" in pre_type and "SPN" in post_type:
        extra_pruning_parameters = { 'distPruning': LTS_dist_dep_pruning }
    else:
        # No distance dependent pruning available for this neuron type, set it to False
        distance_dependent_pruning = False
        
dd_str = "_distdep" if distance_dependent_pruning else ""
par_str = "_".join(param_names) + dd_str
network_path = os.path.join("networks", f"{pre_type}_to_{post_type}_{par_str}")

        
all_experimental_data = {}
all_experimental_data["dSPN", "iSPN"] = [(0, 50e-6, 3/47.0), (0, 100e-6, 3/66.0)]
all_experimental_data["dSPN", "dSPN"] = [(0, 50e-6, 5/19.0), (0, 100e-6, 3/43.0)]
all_experimental_data["iSPN", "iSPN"] = [(0, 50e-6, 14/39.0), (0, 100e-6, 7/31.0)]
all_experimental_data["iSPN", "dSPN"] = [(0, 50e-6, 13/47.0), (0, 100e-6, 10/80.0)]

all_experimental_data["FS", "FS"] = [(0, 250e-6, 7/12.0)]
all_experimental_data["FS", "iSPN"] = [(0, 100e-6, 6/9.0), (0, 150e-6, 21/54.0), (0, 250e-6, 27/77.0)]
all_experimental_data["FS", "dSPN"] = [(0, 100e-6, 8/9.0), (0, 150e-6, 29/48.0), (0, 250e-6, 48/90.0)]
all_experimental_data["FS", "LTS"] = [(0, 250e-6, 2/12.0)]

all_experimental_data["LTS", "dSPN"] = [(0, 250e-6, 2/60.0)]
all_experimental_data["LTS", "iSPN"] = [(0, 250e-6, 2/60.0)]

all_experimental_data["ChIN", "dSPN"] = [(0, 250e-6, 0.05)]
all_experimental_data["ChIN", "iSPN"] = [(0, 250e-6, 0.05)]


experimental_data = all_experimental_data[pre_type, post_type]

cube_side = np.max([max(x[1], 250e-6) for x in experimental_data])

axon_cloud = dict()
LTS_density_str = ("12*3000*1e12*( 0.25*exp(-(((x-200e-6)/100e-6)**2 "
                           "+ ((y-0)/50e-6)**2 + ((z-0)/30e-6)**2)) "
                           "+ 1*exp(-(((x-300e-6)/300e-6)**2 + ((y-0)/15e-6)**2 + ((z-0)/10e-6)**2)) "
                           "+ 1*exp(-(((x-700e-6)/100e-6)**2 + ((y-0)/15e-6)**2 + ((z-0)/15e-6)**2)) )")

axon_cloud["LTS"] = ("xyz", LTS_density_str, [-200e-6, 900e-6, -100e-6, 100e-6, -30e-6, 30e-6])
axon_cloud["CHIN"] = ("r", "5000*1e12/3*exp(-r/120e-6)", 350e-6)

# %%
from snudda.place.create_cube_mesh import create_cube_mesh

mesh_file = os.path.join(network_path, "cube-mesh.obj")
create_cube_mesh(mesh_file, [0,0,0], cube_side)

from snudda.init import SnuddaInit
si = SnuddaInit(network_path=network_path, random_seed=123, snudda_data="../../../../../BasalGangliaData/data/")

si.define_structure(struct_name="Cube", struct_mesh=mesh_file, d_min=12e-6, mesh_bin_width=25e-6)

if pre_type in axon_cloud:
    pre_ac = axon_cloud[pre_type]
else:
    pre_ac = None
    
if post_type in axon_cloud:
    post_ac = axon_cloud[post_type]
else:
    post_ac = None

if pre_type == post_type:
    
    si.add_neurons(name=pre_type, num_neurons=n_neurons, volume_id="Cube", axon_density=pre_ac,
                    neuron_dir=os.path.join("$DATA","neurons","striatum",pre_type.lower()))
else:
    si.add_neurons(name=pre_type, num_neurons=int(n_neurons/2), volume_id="Cube", axon_density=pre_ac,
                    neuron_dir=os.path.join("$DATA","neurons","striatum", pre_type.lower()))
    si.add_neurons(name=post_type, num_neurons=int(n_neurons/2), volume_id="Cube", axon_density=post_ac,
                    neuron_dir=os.path.join("$DATA","neurons","striatum", post_type.lower()))
    

# The parameters here does not matter, they will be set during optimisation
si.add_neuron_target(neuron_name=pre_type,
                     target_name=post_type,
                     region_name="Cube",
                     connection_type=con_type,
                     dist_pruning=None,
                     f1=None, soft_max=None, mu2=None,
                     a3=None,
                     conductance=[0.24e-9, 0.1e-9],
                     mod_file="tmGabaA")

si.write_json()
# Out:
# Adding neurons: iSPN from dir /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn
# Adding neurons: dSPN from dir /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn
# Writing networks/iSPN_to_dSPN_f1_mu2_a3_distdep/network-config.json

# %%
from snudda import SnuddaPlace
sp = SnuddaPlace(network_path=network_path, verbose=False)
sp.place()
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/BasalGangliaData/data from networks/iSPN_to_dSPN_f1_mu2_a3_distdep/network-config.json
# No n_putative_points and putative_density, setting n_putative_points = 6172
# (this must be larger than the number of neurons you want to place)
# Generating 6172 points for networks/iSPN_to_dSPN_f1_mu2_a3_distdep/cube-mesh.obj
# Filtering, keeping inside points: 2413 / 3257
# neuron_name = 'iSPN_0', num = np.int64(37), neuron_path = '$SNUDDA_DATA/neurons/striatum/ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20220622'
# neuron_name = 'iSPN_1', num = np.int64(38), neuron_path = '$SNUDDA_DATA/neurons/striatum/ispn/str-ispn-e150917_c11_D2-mWT-MSN1-v20220623'
# neuron_name = 'iSPN_2', num = np.int64(38), neuron_path = '$SNUDDA_DATA/neurons/striatum/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20220623'
# neuron_name = 'iSPN_3', num = np.int64(37), neuron_path = '$SNUDDA_DATA/neurons/striatum/ispn/str-ispn-e160118_c10_D2-m46-3-DE-v20220622'
# neuron_name = 'dSPN_0', num = np.int64(38), neuron_path = '$SNUDDA_DATA/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20220620'
# neuron_name = 'dSPN_1', num = np.int64(37), neuron_path = '$SNUDDA_DATA/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20220620'
# neuron_name = 'dSPN_2', num = np.int64(37), neuron_path = '$SNUDDA_DATA/neurons/striatum/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20220623'
# neuron_name = 'dSPN_3', num = np.int64(38), neuron_path = '$SNUDDA_DATA/neurons/striatum/dspn/str-dspn-e150917_c9_d1-mWT-1215MSN03-v20220620'

# %%
from snudda.plotting import PlotNetwork
network_file = os.path.join(network_path, "network-neuron-positions.hdf5")
pn = PlotNetwork(network_file)
pn.plot(plot_axon=False, plot_dendrite=False, plot_synapses=False)
pn.close()
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/BasalGangliaData/data from networks/iSPN_to_dSPN_f1_mu2_a3_distdep/network-config.json

# %%
from snudda import SnuddaDetect

sd = SnuddaDetect(network_path=network_path, hyper_voxel_size=100)
sd.detect()
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/BasalGangliaData/data from networks/iSPN_to_dSPN_f1_mu2_a3_distdep/network-config.json
# No d_view specified, running distribute neurons in serial
# Processing hyper voxel : 488/1100 (299 neurons)
# Processing hyper voxel : 477/1100 (262 neurons)
# Processing hyper voxel : 378/1100 (182 neurons)
# Processing hyper voxel : 487/1100 (172 neurons)
# Processing hyper voxel : 489/1100 (163 neurons)
# Processing hyper voxel : 367/1100 (154 neurons)
# Processing hyper voxel : 598/1100 (151 neurons)
# Processing hyper voxel : 478/1100 (150 neurons)
# Processing hyper voxel : 476/1100 (134 neurons)
# Processing hyper voxel : 587/1100 (122 neurons)
# Processing hyper voxel : 377/1100 (97 neurons)
# Processing hyper voxel : 368/1100 (90 neurons)
# Processing hyper voxel : 379/1100 (84 neurons)
# Processing hyper voxel : 499/1100 (82 neurons)
# Processing hyper voxel : 366/1100 (80 neurons)
# Processing hyper voxel : 597/1100 (75 neurons)
# Processing hyper voxel : 599/1100 (69 neurons)
# Processing hyper voxel : 588/1100 (57 neurons)
# Processing hyper voxel : 586/1100 (56 neurons)
# Processing hyper voxel : 500/1100 (49 neurons)
# Processing hyper voxel : 466/1100 (45 neurons)
# Processing hyper voxel : 389/1100 (42 neurons)
# Processing hyper voxel : 609/1100 (34 neurons)
# Processing hyper voxel : 498/1100 (34 neurons)
# Processing hyper voxel : 390/1100 (32 neurons)
# Processing hyper voxel : 465/1100 (31 neurons)
# Processing hyper voxel : 356/1100 (29 neurons)
# Processing hyper voxel : 257/1100 (28 neurons)
# Processing hyper voxel : 467/1100 (28 neurons)
# Processing hyper voxel : 268/1100 (27 neurons)
# Processing hyper voxel : 608/1100 (27 neurons)
# Processing hyper voxel : 388/1100 (26 neurons)
# Processing hyper voxel : 576/1100 (26 neurons)
# Processing hyper voxel : 475/1100 (25 neurons)
# Processing hyper voxel : 610/1100 (21 neurons)
# Processing hyper voxel : 256/1100 (20 neurons)
# Processing hyper voxel : 380/1100 (20 neurons)
# Processing hyper voxel : 486/1100 (20 neurons)
# Processing hyper voxel : 355/1100 (20 neurons)
# Processing hyper voxel : 267/1100 (18 neurons)
# Processing hyper voxel : 490/1100 (18 neurons)
# Processing hyper voxel : 575/1100 (17 neurons)
# Processing hyper voxel : 365/1100 (17 neurons)
# Processing hyper voxel : 697/1100 (17 neurons)
# Processing hyper voxel : 376/1100 (17 neurons)
# Processing hyper voxel : 258/1100 (16 neurons)
# Processing hyper voxel : 585/1100 (15 neurons)
# Processing hyper voxel : 708/1100 (15 neurons)
# Processing hyper voxel : 269/1100 (14 neurons)
# Processing hyper voxel : 479/1100 (14 neurons)
# Processing hyper voxel : 464/1100 (13 neurons)
# Processing hyper voxel : 577/1100 (13 neurons)
# Processing hyper voxel : 696/1100 (12 neurons)
# Processing hyper voxel : 600/1100 (12 neurons)
# Processing hyper voxel : 246/1100 (12 neurons)
# Processing hyper voxel : 369/1100 (12 neurons)
# Processing hyper voxel : 596/1100 (12 neurons)
# Processing hyper voxel : 698/1100 (11 neurons)
# Processing hyper voxel : 707/1100 (11 neurons)
# Processing hyper voxel : 611/1100 (10 neurons)
# Processing hyper voxel : 497/1100 (10 neurons)
# Processing hyper voxel : 501/1100 (10 neurons)
# Processing hyper voxel : 357/1100 (10 neurons)
# Processing hyper voxel : 510/1100 (9 neurons)
# Processing hyper voxel : 279/1100 (9 neurons)
# Processing hyper voxel : 354/1100 (8 neurons)
# Processing hyper voxel : 400/1100 (8 neurons)
# Processing hyper voxel : 391/1100 (8 neurons)
# Processing hyper voxel : 509/1100 (7 neurons)
# Processing hyper voxel : 147/1100 (7 neurons)
# Processing hyper voxel : 158/1100 (7 neurons)
# Processing hyper voxel : 706/1100 (7 neurons)
# Processing hyper voxel : 574/1100 (6 neurons)
# Processing hyper voxel : 280/1100 (6 neurons)
# Processing hyper voxel : 157/1100 (6 neurons)
# Processing hyper voxel : 146/1100 (6 neurons)
# Processing hyper voxel : 607/1100 (6 neurons)
# Processing hyper voxel : 255/1100 (6 neurons)
# Processing hyper voxel : 485/1100 (6 neurons)
# Processing hyper voxel : 474/1100 (6 neurons)
# Processing hyper voxel : 278/1100 (5 neurons)
# Processing hyper voxel : 468/1100 (5 neurons)
# Processing hyper voxel : 244/1100 (5 neurons)
# Processing hyper voxel : 245/1100 (5 neurons)
# Processing hyper voxel : 709/1100 (5 neurons)
# Processing hyper voxel : 620/1100 (5 neurons)
# Processing hyper voxel : 455/1100 (5 neurons)
# Processing hyper voxel : 270/1100 (5 neurons)
# Processing hyper voxel : 381/1100 (5 neurons)
# Processing hyper voxel : 589/1100 (4 neurons)
# Processing hyper voxel : 137/1100 (4 neurons)
# Processing hyper voxel : 401/1100 (4 neurons)
# Processing hyper voxel : 387/1100 (4 neurons)
# Processing hyper voxel : 685/1100 (4 neurons)
# Processing hyper voxel : 564/1100 (4 neurons)
# Processing hyper voxel : 565/1100 (4 neurons)
# Processing hyper voxel : 266/1100 (4 neurons)
# Processing hyper voxel : 259/1100 (4 neurons)
# Processing hyper voxel : 456/1100 (4 neurons)
# Processing hyper voxel : 480/1100 (4 neurons)
# Processing hyper voxel : 148/1100 (4 neurons)
# Processing hyper voxel : 247/1100 (4 neurons)
# Processing hyper voxel : 686/1100 (3 neurons)
# Processing hyper voxel : 621/1100 (3 neurons)
# Processing hyper voxel : 601/1100 (3 neurons)
# Processing hyper voxel : 595/1100 (3 neurons)
# Processing hyper voxel : 521/1100 (3 neurons)
# Processing hyper voxel : 606/1100 (3 neurons)
# Processing hyper voxel : 491/1100 (3 neurons)
# Processing hyper voxel : 454/1100 (3 neurons)
# Processing hyper voxel : 392/1100 (3 neurons)
# Processing hyper voxel : 511/1100 (3 neurons)
# Processing hyper voxel : 399/1100 (3 neurons)
# Processing hyper voxel : 343/1100 (3 neurons)
# Processing hyper voxel : 720/1100 (3 neurons)
# Processing hyper voxel : 145/1100 (3 neurons)
# Processing hyper voxel : 289/1100 (3 neurons)
# Processing hyper voxel : 281/1100 (3 neurons)
# Processing hyper voxel : 375/1100 (3 neurons)
# Processing hyper voxel : 358/1100 (3 neurons)
# Processing hyper voxel : 291/1100 (3 neurons)
# Processing hyper voxel : 346/1100 (3 neurons)
# Processing hyper voxel : 345/1100 (3 neurons)
# Processing hyper voxel : 719/1100 (3 neurons)
# Processing hyper voxel : 159/1100 (3 neurons)
# Processing hyper voxel : 718/1100 (3 neurons)
# Processing hyper voxel : 705/1100 (3 neurons)
# Processing hyper voxel : 492/1100 (2 neurons)
# Processing hyper voxel : 496/1100 (2 neurons)
# Processing hyper voxel : 135/1100 (2 neurons)
# Processing hyper voxel : 807/1100 (2 neurons)
# Processing hyper voxel : 820/1100 (2 neurons)
# Processing hyper voxel : 818/1100 (2 neurons)
# Processing hyper voxel : 292/1100 (2 neurons)
# Processing hyper voxel : 136/1100 (2 neurons)
# Processing hyper voxel : 806/1100 (2 neurons)
# Processing hyper voxel : 290/1100 (2 neurons)
# Processing hyper voxel : 512/1100 (2 neurons)
# Processing hyper voxel : 584/1100 (2 neurons)
# Processing hyper voxel : 612/1100 (2 neurons)
# Processing hyper voxel : 149/1100 (2 neurons)
# Processing hyper voxel : 622/1100 (2 neurons)
# Processing hyper voxel : 254/1100 (2 neurons)
# Processing hyper voxel : 710/1100 (2 neurons)
# Processing hyper voxel : 619/1100 (2 neurons)
# Processing hyper voxel : 502/1100 (2 neurons)
# Processing hyper voxel : 508/1100 (2 neurons)
# Processing hyper voxel : 344/1100 (2 neurons)
# Processing hyper voxel : 237/1100 (2 neurons)
# Processing hyper voxel : 695/1100 (2 neurons)
# Processing hyper voxel : 383/1100 (2 neurons)
# Processing hyper voxel : 382/1100 (2 neurons)
# Processing hyper voxel : 402/1100 (2 neurons)
# Processing hyper voxel : 160/1100 (2 neurons)
# Processing hyper voxel : 411/1100 (2 neurons)
# Processing hyper voxel : 412/1100 (2 neurons)
# Processing hyper voxel : 687/1100 (2 neurons)
# Processing hyper voxel : 144/1100 (2 neurons)
# Processing hyper voxel : 370/1100 (2 neurons)
# Processing hyper voxel : 463/1100 (2 neurons)
# Processing hyper voxel : 730/1100 (2 neurons)
# Processing hyper voxel : 127/1100 (2 neurons)
# Processing hyper voxel : 590/1100 (2 neurons)
# Processing hyper voxel : 170/1100 (2 neurons)
# Processing hyper voxel : 134/1100 (2 neurons)
# Processing hyper voxel : 169/1100 (2 neurons)
# Processing hyper voxel : 236/1100 (2 neurons)
# Processing hyper voxel : 364/1100 (2 neurons)
# Processing hyper voxel : 674/1100 (2 neurons)
# Processing hyper voxel : 930/1100 (1 neurons)
# Processing hyper voxel : 731/1100 (1 neurons)
# Processing hyper voxel : 842/1100 (1 neurons)
# Processing hyper voxel : 840/1100 (1 neurons)
# Processing hyper voxel : 729/1100 (1 neurons)
# Processing hyper voxel : 829/1100 (1 neurons)
# Processing hyper voxel : 721/1100 (1 neurons)
# Processing hyper voxel : 732/1100 (1 neurons)
# Processing hyper voxel : 613/1100 (1 neurons)
# Processing hyper voxel : 817/1100 (1 neurons)
# Processing hyper voxel : 711/1100 (1 neurons)
# Processing hyper voxel : 773/1100 (1 neurons)
# Processing hyper voxel : 693/1100 (1 neurons)
# Processing hyper voxel : 783/1100 (1 neurons)
# Processing hyper voxel : 699/1100 (1 neurons)
# Processing hyper voxel : 675/1100 (1 neurons)
# Processing hyper voxel : 673/1100 (1 neurons)
# Processing hyper voxel : 663/1100 (1 neurons)
# Processing hyper voxel : 700/1100 (1 neurons)
# Processing hyper voxel : 795/1100 (1 neurons)
# Processing hyper voxel : 796/1100 (1 neurons)
# Processing hyper voxel : 797/1100 (1 neurons)
# Processing hyper voxel : 640/1100 (1 neurons)
# Processing hyper voxel : 805/1100 (1 neurons)
# Processing hyper voxel : 704/1100 (1 neurons)
# Processing hyper voxel : 808/1100 (1 neurons)
# Processing hyper voxel : 816/1100 (1 neurons)
# Processing hyper voxel : 633/1100 (1 neurons)
# Processing hyper voxel : 630/1100 (1 neurons)
# Processing hyper voxel : 629/1100 (1 neurons)
# Processing hyper voxel : 623/1100 (1 neurons)
# Processing hyper voxel : 618/1100 (1 neurons)
# Processing hyper voxel : 717/1100 (1 neurons)
# Processing hyper voxel : 772/1100 (1 neurons)
# Processing hyper voxel : 6/1100 (1 neurons)
# Processing hyper voxel : 583/1100 (1 neurons)
# Processing hyper voxel : 243/1100 (1 neurons)
# Processing hyper voxel : 235/1100 (1 neurons)
# Processing hyper voxel : 234/1100 (1 neurons)
# Processing hyper voxel : 233/1100 (1 neurons)
# Processing hyper voxel : 232/1100 (1 neurons)
# Processing hyper voxel : 224/1100 (1 neurons)
# Processing hyper voxel : 180/1100 (1 neurons)
# Processing hyper voxel : 168/1100 (1 neurons)
# Processing hyper voxel : 162/1100 (1 neurons)
# Processing hyper voxel : 161/1100 (1 neurons)
# Processing hyper voxel : 156/1100 (1 neurons)
# Processing hyper voxel : 155/1100 (1 neurons)
# Processing hyper voxel : 138/1100 (1 neurons)
# Processing hyper voxel : 248/1100 (1 neurons)
# Processing hyper voxel : 126/1100 (1 neurons)
# Processing hyper voxel : 123/1100 (1 neurons)
# Processing hyper voxel : 116/1100 (1 neurons)
# Processing hyper voxel : 112/1100 (1 neurons)
# Processing hyper voxel : 70/1100 (1 neurons)
# Processing hyper voxel : 60/1100 (1 neurons)
# Processing hyper voxel : 48/1100 (1 neurons)
# Processing hyper voxel : 37/1100 (1 neurons)
# Processing hyper voxel : 36/1100 (1 neurons)
# Processing hyper voxel : 35/1100 (1 neurons)
# Processing hyper voxel : 34/1100 (1 neurons)
# Processing hyper voxel : 26/1100 (1 neurons)
# Processing hyper voxel : 24/1100 (1 neurons)
# Processing hyper voxel : 23/1100 (1 neurons)
# Processing hyper voxel : 124/1100 (1 neurons)
# Processing hyper voxel : 605/1100 (1 neurons)
# Processing hyper voxel : 271/1100 (1 neurons)
# Processing hyper voxel : 277/1100 (1 neurons)
# Processing hyper voxel : 578/1100 (1 neurons)
# Processing hyper voxel : 563/1100 (1 neurons)
# Processing hyper voxel : 562/1100 (1 neurons)
# Processing hyper voxel : 554/1100 (1 neurons)
# Processing hyper voxel : 532/1100 (1 neurons)
# Processing hyper voxel : 531/1100 (1 neurons)
# Processing hyper voxel : 522/1100 (1 neurons)
# Processing hyper voxel : 520/1100 (1 neurons)
# Processing hyper voxel : 519/1100 (1 neurons)
# Processing hyper voxel : 503/1100 (1 neurons)
# Processing hyper voxel : 481/1100 (1 neurons)
# Processing hyper voxel : 473/1100 (1 neurons)
# Processing hyper voxel : 469/1100 (1 neurons)
# Processing hyper voxel : 275/1100 (1 neurons)
# Processing hyper voxel : 931/1100 (1 neurons)
# Processing hyper voxel : 453/1100 (1 neurons)
# Processing hyper voxel : 445/1100 (1 neurons)
# Processing hyper voxel : 444/1100 (1 neurons)
# Processing hyper voxel : 409/1100 (1 neurons)
# Processing hyper voxel : 398/1100 (1 neurons)
# Processing hyper voxel : 386/1100 (1 neurons)
# Processing hyper voxel : 385/1100 (1 neurons)
# Processing hyper voxel : 372/1100 (1 neurons)
# Processing hyper voxel : 371/1100 (1 neurons)
# Processing hyper voxel : 347/1100 (1 neurons)
# Processing hyper voxel : 334/1100 (1 neurons)
# Processing hyper voxel : 313/1100 (1 neurons)
# Processing hyper voxel : 302/1100 (1 neurons)
# Processing hyper voxel : 457/1100 (1 neurons)
# Processing hyper voxel : 950/1100 (1 neurons)

# %%
from snudda.optimise.optimise_pruning import OptimisePruning
op = OptimisePruning(network_path=network_path)

# %%
op.merge_putative_synapses(force_merge=True)
# Out:
# Read 34393 out of total 34393 synapses

# %%
op.prune.connectivity_distributions
# Out:
# {(1,
#   2,
#   10): ({'f1': 1.0,
#    'soft_max': None,
#    'mu2': None,
#    'a3': None,
#    'dist_pruning': None,
#    'cluster_pruning': False}, None)}

# %%
op.prune.type_id_lookup
# Out:
# {'iSPN': 1, 'dSPN': 2}

# %%
op.prune.hist_file["meta/connectivity_distributions"][()]
# Out:
# b'{"iSPN$$dSPN": {"GABA": {"conductance": [2.4e-10, 1e-10], "channel_parameters": {"mod_file": "tmGabaA"}, "cluster_size": 1, "cluster_spread": null, "pruning": {"f1": null, "soft_max": null, "mu2": null, "a3": null, "dist_pruning": null, "cluster_pruning": false}, "channel_model_id": 10, "lognormal_mu_sigma": [-22.230424900260093, 0.40010675493807013]}}}'

# %%
res = op.optimize(pre_type=pre_type, post_type=post_type, con_type=con_type, 
                  experimental_data=experimental_data, 
                  avg_num_synapses_per_pair=avg_num_synapses_per_pair,
                  extra_pruning_parameters=extra_pruning_parameters, 
                  workers=8, maxiter=1000, pop_size=pop_size, tol=0.00001, 
                  param_names=param_names, param_bounds="default")
# Out:
# /home/hjorth/HBP/Snudda/venv/lib/python3.13/site-packages/scipy/optimize/_differentialevolution.py:487: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# numprocs=1
# Worker iter: 100, fitness 14.623571211967693
# Worker iter: 100, fitness 14.994381459705158
# Worker iter: 100, fitness 14.76172571541003
# Worker iter: 100, fitness 14.88243172427904
# Worker iter: 100, fitness 14.852437023795416
# Worker iter: 100, fitness 14.789961432875305
# Worker iter: 100, fitness 14.762400555580921
# Worker iter: 100, fitness 14.69791873731197
# Worker iter: 200, fitness 13.71132908850922
# Worker iter: 200, fitness 13.72350342500788
# Worker iter: 200, fitness 13.718633690408417
# Worker iter: 200, fitness 13.695284900651906
# Worker iter: 200, fitness 13.71132908850922
# Worker iter: 200, fitness 13.694065685826253Worker iter: 200, fitness 13.712538512727178
#
# Worker iter: 200, fitness 13.712538512727178
# Worker iter: 300, fitness 13.653614730785591
# Worker iter: 300, fitness 13.680624825611199
# Worker iter: 300, fitness 13.656049515272073
# Worker iter: 300, fitness 13.653614730785591
# Worker iter: 300, fitness 13.653614730785591
# Worker iter: 300, fitness 13.680624825611199
# Worker iter: 300, fitness 13.653614730785591
# Worker iter: 300, fitness 13.653614730785591
# Worker iter: 400, fitness 13.653614730785591
# Worker iter: 400, fitness 13.653614730785591
# Worker iter: 400, fitness 13.652400018055724
# Worker iter: 400, fitness 13.652400018055724
# Worker iter: 400, fitness 13.652400018055724
# Worker iter: 400, fitness 13.652400018055724
# Worker iter: 400, fitness 13.653614730785591
# Worker iter: 400, fitness 13.652400018055724
# Worker iter: 500, fitness 13.652400018055724
# Duration: 149.8223332389989 s

# %%
op.export_json("network-config-opt.json", append=True, res=res)

# %% [markdown]
# # Best parameter set

# %%
param_str = ""
for p_name, p_val in zip(param_names, res.x):
    param_str += f"{p_name} = {p_val:.4f}, "
    
if "distPruning" in extra_pruning_parameters:
   param_str += f" ({extra_pruning_parameters['distPruning']})"                                                  
                                                 
print(param_str)
# Out:
# f1 = 0.1741, mu2 = 1.5767, a3 = 0.9837,  (1-exp(-(0.4*d/60e-6)**2))

# %%
res
# Out:
#              message: Optimization terminated successfully.
#              success: True
#                  fun: 13.652400018055724
#                    x: [ 1.741e-01  1.577e+00  9.837e-01]
#                  nit: 86
#                 nfev: 3919
#           population: [[ 1.741e-01  1.577e+00  9.837e-01]
#                        [ 1.741e-01  1.577e+00  9.837e-01]
#                        ...
#                        [ 1.741e-01  1.577e+00  9.837e-01]
#                        [ 1.741e-01  1.577e+00  9.837e-01]]
#  population_energies: [ 1.365e+01  1.365e+01 ...  1.365e+01  1.365e+01]

# %%
import os
from snudda.analyse.analyse import SnuddaAnalyse
import glob

# Get the last file
# list_of_files = glob.glob(os.path.join(network_path, "temp", "network-synapses-*hdf5"))
# network_file = max(list_of_files, key=os.path.getctime)

network_file = os.path.join(network_path, "network-synapses.hdf5")

dist3D = False
y_max_H = None

sa = SnuddaAnalyse(network_file)
# Out:
# Assuming volume type: cube [cube or full]
# Only using 20000 neurons of the connection data
# Creating figures directory networks/iSPN_to_dSPN_f1_mu2_a3_distdep/figures
# Number of neurons: 300
# Synapse row 0 - 0.0 % time: 0.001104124999983469 seconds
# Created connection matrix 0.0034011669995379634 seconds
# Created gap junction connection matrix 0.00035866600046574604 seconds
# Creating population dictionary
# Done.
# Warning: the analysis cube specified by sideLen is too large.
# !!! Setting sideLen to None
# Calculating synapse distance histogram
# Creating dist histogram
# n_synapses = 3329, at 0
# Created distance histogram (optimised) in 0.006459958000050392 seconds
# Saving cache to networks/iSPN_to_dSPN_f1_mu2_a3_distdep/network-synapses.hdf5-cache

# %%
if pre_type == "dSPN" and post_type == "iSPN":
    sa.plot_connection_probability("dSPN", "iSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(3, 47), (3, 66)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("dSPN", "iSPN", sub_title=param_str)
elif pre_type == "dSPN" and post_type == "dSPN":
    sa.plot_connection_probability("dSPN", "dSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(5, 19), (3, 43)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("dSPN", "dSPN", sub_title=param_str)
elif pre_type == "iSPN" and post_type == "iSPN":
    sa.plot_connection_probability("iSPN", "iSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(14, 39), (7, 31)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("iSPN", "iSPN", sub_title=param_str)
elif pre_type == "iSPN" and post_type == "dSPN":
    sa.plot_connection_probability("iSPN", "dSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(13, 47), (10, 80)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("iSPN", "dSPN", sub_title=param_str)
elif pre_type == "FS" and post_type == "FS":
    sa.plot_connection_probability("FS", "FS", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(7, 12)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "FS", sub_title=param_str)
elif pre_type == "FS" and post_type == "iSPN":
    sa.plot_connection_probability("FS", "iSPN", dist_3d=True, exp_max_dist=[100e-6, 150e-6, 250e-6], exp_data_detailed=[(6, 9), (21, 54), (27,77)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "iSPN", sub_title=param_str)
elif pre_type == "FS" and post_type == "dSPN":
    sa.plot_connection_probability("FS", "dSPN", dist_3d=True, exp_max_dist=[100e-6, 150e-6, 250e-6], exp_data_detailed=[(8, 9), (29, 48), (48,90)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "dSPN", sub_title=param_str)
    
elif pre_type == "FS" and post_type == "LTS":
    sa.plot_connection_probability("FS", "LTS", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(2, 12)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "LTS", sub_title=param_str)
elif pre_type == 'LTS' and post_type == "dSPN":
    sa.plot_connection_probability("LTS", "dSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(2, 60)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("LTS", "dSPN", sub_title=param_str)
elif pre_type == 'LTS' and post_type == "iSPN":
    sa.plot_connection_probability("LTS", "iSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(2, 60)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("LTS", "iSPN", sub_title=param_str)
elif pre_type == 'ChIN' and post_type == "dSPN":
    sa.plot_connection_probability("ChIN", "dSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data=[0.05], sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "dSPN", sub_title=param_str)
elif pre_type == 'ChIN' and post_type == "iSPN":
    sa.plot_connection_probability("ChIN", "iSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data=[0.05], sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "iSPN", sub_title=param_str)

# Missing pairwise experimental data...
    
elif pre_type == 'ChIN' and post_type == "FS":
    sa.plot_connection_probability("ChIN", "FS", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "FS", sub_title=param_str)
elif pre_type == 'ChIN' and post_type == "LTS":
    sa.plot_connection_probability("ChIN", "LTS", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "LTS", sub_title=param_str)

elif pre_type == 'LTS' and post_type == "ChIN":
    sa.plot_connection_probability("LTS", "ChIN", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("LTS", "ChIN", sub_title=param_str)

    
elif pre_type == 'dSPN' and post_type == "ChIN":
    sa.plot_connection_probability("dSPN", "ChIN", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("dSPN", "ChIN", sub_title=param_str)
elif pre_type == 'iSPN' and post_type == "ChIN":
    sa.plot_connection_probability("iSPN", "ChIN", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("iSPN", "ChIN", sub_title=param_str)
# Out:
# Plotting connection probability iSPN to dSPN (synapses)
# Centering in None : Keeping 150/150
# Counting connections
# Requested: 10000000.0 calculated [22500.]
# Num pairs outside plot range 0
# P(d<5e-05) = 0.23638344226579522
# P(d<0.0001) = 0.14040648890546337
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1443: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/iSPN_to_dSPN_f1_mu2_a3_distdep/figures/Network-distance-dependent-connection-probability-iSPN-to-dSPN-synapses-3D-dist.png
# Plotting number of connections
# Only analysing centre post synaptic neurons, sideLen = 0.00025
# Centering in None : Keeping 150/150
# Calculating max synapses
# Calculating mean synapses
# Plotting 1363 connections
# Wrote networks/iSPN_to_dSPN_f1_mu2_a3_distdep/figures/Network-number-of-synapses-from-iSPN-to-dSPN-per-cell.png
