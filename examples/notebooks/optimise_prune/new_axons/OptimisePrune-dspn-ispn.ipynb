# %% [markdown]
# # Optimise pruning parameters
#
# This Notebook shows how to optimise the pruning parameters of your network based on pairwise connectivity data.
#
# First we need to create a small network that we can use for the optimisation of the pruning parameters.
#
# In this example we do not need to have realistic neuron densities, so we will place the neurons in a cube of diameter 150 micrometers.

# %%
import os
import numpy as np

n_neurons = 300

pop_size = 15
# epochs = 10

pre_type = "dSPN"     # "iSPN"
post_type = "iSPN"  # "iSPN"
con_type = "GABA"

avg_num_synapses_per_pair = 3  # Expected mean, error weight

# param_names = ["f1", "softMax", "mu2", "a3"]
param_names = ["f1", "mu2", "a3"]

distance_dependent_pruning = True

SPN2SPNdistDepPruning = "1-exp(-(0.4*d/60e-6)**2)"
FS_dist_dep_pruning = "exp(-(0.5*d/60e-6)**2)" 
LTS_dist_dep_pruning = "1-exp(-(0.4*d/60e-6)**2)"


extra_pruning_parameters = { }

if distance_dependent_pruning:
    if pre_type == "FS" and (post_type == "dSPN" or post_type == "iSPN"):
        extra_pruning_parameters = { 'distPruning': FS_dist_dep_pruning }
    elif "SPN" in pre_type and "SPN" in post_type:
        extra_pruning_parameters = { 'distPruning': SPN2SPNdistDepPruning }
    elif "LTS" in pre_type and "SPN" in post_type:
        extra_pruning_parameters = { 'distPruning': LTS_dist_dep_pruning }
    else:
        # No distance dependent pruning available for this neuron type, set it to False
        distance_dependent_pruning = False
        
dd_str = "_distdep" if distance_dependent_pruning else ""
par_str = "_".join(param_names) + dd_str
network_path = os.path.join("networks", f"{pre_type}_to_{post_type}_{par_str}")

        
all_experimental_data = {}
all_experimental_data["dSPN", "iSPN"] = [(0, 50e-6, 3/47.0), (0, 100e-6, 3/66.0)]
all_experimental_data["dSPN", "dSPN"] = [(0, 50e-6, 5/19.0), (0, 100e-6, 3/43.0)]
all_experimental_data["iSPN", "iSPN"] = [(0, 50e-6, 14/39.0), (0, 100e-6, 7/31.0)]
all_experimental_data["iSPN", "dSPN"] = [(0, 50e-6, 13/47.0), (0, 100e-6, 10/80.0)]

all_experimental_data["FS", "FS"] = [(0, 250e-6, 7/12.0)]
all_experimental_data["FS", "iSPN"] = [(0, 100e-6, 6/9.0), (0, 150e-6, 21/54.0), (0, 250e-6, 27/77.0)]
all_experimental_data["FS", "dSPN"] = [(0, 100e-6, 8/9.0), (0, 150e-6, 29/48.0), (0, 250e-6, 48/90.0)]
all_experimental_data["FS", "LTS"] = [(0, 250e-6, 2/12.0)]

all_experimental_data["LTS", "dSPN"] = [(0, 250e-6, 2/60.0)]
all_experimental_data["LTS", "iSPN"] = [(0, 250e-6, 2/60.0)]

all_experimental_data["ChIN", "dSPN"] = [(0, 250e-6, 0.05)]
all_experimental_data["ChIN", "iSPN"] = [(0, 250e-6, 0.05)]


experimental_data = all_experimental_data[pre_type, post_type]

cube_side = np.max([max(x[1], 250e-6) for x in experimental_data])

axon_cloud = dict()
LTS_density_str = ("12*3000*1e12*( 0.25*exp(-(((x-200e-6)/100e-6)**2 "
                           "+ ((y-0)/50e-6)**2 + ((z-0)/30e-6)**2)) "
                           "+ 1*exp(-(((x-300e-6)/300e-6)**2 + ((y-0)/15e-6)**2 + ((z-0)/10e-6)**2)) "
                           "+ 1*exp(-(((x-700e-6)/100e-6)**2 + ((y-0)/15e-6)**2 + ((z-0)/15e-6)**2)) )")

axon_cloud["LTS"] = ("xyz", LTS_density_str, [-200e-6, 900e-6, -100e-6, 100e-6, -30e-6, 30e-6])
axon_cloud["CHIN"] = ("r", "5000*1e12/3*exp(-r/120e-6)", 350e-6)

# %%
from snudda.place.create_cube_mesh import create_cube_mesh

mesh_file = os.path.join(network_path, "cube-mesh.obj")
create_cube_mesh(mesh_file, [0,0,0], cube_side)

from snudda.init import SnuddaInit
si = SnuddaInit(network_path=network_path, random_seed=123, snudda_data="../../../../../BasalGangliaData/data/")

si.define_structure(struct_name="Cube", struct_mesh=mesh_file, d_min=12e-6, mesh_bin_width=25e-6)

if pre_type in axon_cloud:
    pre_ac = axon_cloud[pre_type]
else:
    pre_ac = None
    
if post_type in axon_cloud:
    post_ac = axon_cloud[post_type]
else:
    post_ac = None

if pre_type == post_type:
    
    si.add_neurons(name=pre_type, num_neurons=n_neurons, volume_id="Cube", axon_density=pre_ac,
                    neuron_dir=os.path.join("$DATA","neurons","striatum",pre_type.lower()))
else:
    si.add_neurons(name=pre_type, num_neurons=int(n_neurons/2), volume_id="Cube", axon_density=pre_ac,
                    neuron_dir=os.path.join("$DATA","neurons","striatum", pre_type.lower()))
    si.add_neurons(name=post_type, num_neurons=int(n_neurons/2), volume_id="Cube", axon_density=post_ac,
                    neuron_dir=os.path.join("$DATA","neurons","striatum", post_type.lower()))
    

# The parameters here does not matter, they will be set during optimisation
si.add_neuron_target(neuron_name=pre_type,
                     target_name=post_type,
                     region_name="Cube",
                     connection_type=con_type,
                     dist_pruning=None,
                     f1=None, soft_max=None, mu2=None,
                     a3=None,
                     conductance=[0.24e-9, 0.1e-9],
                     mod_file="tmGabaA")

si.write_json()
# Out:
# Adding neurons: dSPN from dir /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn
# Adding neurons: iSPN from dir /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn
# Writing networks/dSPN_to_iSPN_f1_mu2_a3_distdep/network-config.json

# %%
from snudda import SnuddaPlace
sp = SnuddaPlace(network_path=network_path, verbose=False)
sp.place()
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/BasalGangliaData/data from networks/dSPN_to_iSPN_f1_mu2_a3_distdep/network-config.json
# No n_putative_points and putative_density, setting n_putative_points = 6172
# (this must be larger than the number of neurons you want to place)
# Generating 6172 points for networks/dSPN_to_iSPN_f1_mu2_a3_distdep/cube-mesh.obj
# Filtering, keeping inside points: 2413 / 3257
# neuron_name = 'dSPN_0', num = np.int64(37), neuron_path = '$SNUDDA_DATA/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20220620'
# neuron_name = 'dSPN_1', num = np.int64(38), neuron_path = '$SNUDDA_DATA/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20220620'
# neuron_name = 'dSPN_2', num = np.int64(38), neuron_path = '$SNUDDA_DATA/neurons/striatum/dspn/str-dspn-e150917_c6_D1-m21-6-DE-v20220623'
# neuron_name = 'dSPN_3', num = np.int64(37), neuron_path = '$SNUDDA_DATA/neurons/striatum/dspn/str-dspn-e150917_c9_d1-mWT-1215MSN03-v20220620'
# neuron_name = 'iSPN_0', num = np.int64(38), neuron_path = '$SNUDDA_DATA/neurons/striatum/ispn/str-ispn-e150908_c4_D2-m51-5-DE-v20220622'
# neuron_name = 'iSPN_1', num = np.int64(37), neuron_path = '$SNUDDA_DATA/neurons/striatum/ispn/str-ispn-e150917_c11_D2-mWT-MSN1-v20220623'
# neuron_name = 'iSPN_2', num = np.int64(37), neuron_path = '$SNUDDA_DATA/neurons/striatum/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20220623'
# neuron_name = 'iSPN_3', num = np.int64(38), neuron_path = '$SNUDDA_DATA/neurons/striatum/ispn/str-ispn-e160118_c10_D2-m46-3-DE-v20220622'

# %%
from snudda.plotting import PlotNetwork
network_file = os.path.join(network_path, "network-neuron-positions.hdf5")
pn = PlotNetwork(network_file)
pn.plot(plot_axon=False, plot_dendrite=False, plot_synapses=False)
pn.close()
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/BasalGangliaData/data from networks/dSPN_to_iSPN_f1_mu2_a3_distdep/network-config.json

# %%
from snudda import SnuddaDetect

sd = SnuddaDetect(network_path=network_path, hyper_voxel_size=100)
sd.detect()
# Out:
# Reading SNUDDA_DATA=/home/hjorth/HBP/BasalGangliaData/data from networks/dSPN_to_iSPN_f1_mu2_a3_distdep/network-config.json
# No d_view specified, running distribute neurons in serial
# Processing hyper voxel : 443/1100 (286 neurons)
# Processing hyper voxel : 444/1100 (261 neurons)
# Processing hyper voxel : 433/1100 (242 neurons)
# Processing hyper voxel : 434/1100 (230 neurons)
# Processing hyper voxel : 544/1100 (203 neurons)
# Processing hyper voxel : 543/1100 (201 neurons)
# Processing hyper voxel : 534/1100 (176 neurons)
# Processing hyper voxel : 533/1100 (168 neurons)
# Processing hyper voxel : 344/1100 (99 neurons)
# Processing hyper voxel : 343/1100 (87 neurons)
# Processing hyper voxel : 453/1100 (77 neurons)
# Processing hyper voxel : 334/1100 (77 neurons)
# Processing hyper voxel : 442/1100 (72 neurons)
# Processing hyper voxel : 454/1100 (71 neurons)
# Processing hyper voxel : 333/1100 (68 neurons)
# Processing hyper voxel : 445/1100 (61 neurons)
# Processing hyper voxel : 553/1100 (61 neurons)
# Processing hyper voxel : 432/1100 (56 neurons)
# Processing hyper voxel : 435/1100 (53 neurons)
# Processing hyper voxel : 554/1100 (49 neurons)
# Processing hyper voxel : 545/1100 (47 neurons)
# Processing hyper voxel : 423/1100 (46 neurons)
# Processing hyper voxel : 542/1100 (42 neurons)
# Processing hyper voxel : 532/1100 (40 neurons)
# Processing hyper voxel : 424/1100 (39 neurons)
# Processing hyper voxel : 643/1100 (38 neurons)
# Processing hyper voxel : 524/1100 (36 neurons)
# Processing hyper voxel : 644/1100 (35 neurons)
# Processing hyper voxel : 523/1100 (35 neurons)
# Processing hyper voxel : 633/1100 (35 neurons)
# Processing hyper voxel : 535/1100 (34 neurons)
# Processing hyper voxel : 342/1100 (29 neurons)
# Processing hyper voxel : 455/1100 (29 neurons)
# Processing hyper voxel : 354/1100 (28 neurons)
# Processing hyper voxel : 634/1100 (27 neurons)
# Processing hyper voxel : 345/1100 (26 neurons)
# Processing hyper voxel : 353/1100 (26 neurons)
# Processing hyper voxel : 332/1100 (23 neurons)
# Processing hyper voxel : 335/1100 (20 neurons)
# Processing hyper voxel : 555/1100 (20 neurons)
# Processing hyper voxel : 653/1100 (18 neurons)
# Processing hyper voxel : 452/1100 (16 neurons)
# Processing hyper voxel : 525/1100 (15 neurons)
# Processing hyper voxel : 324/1100 (14 neurons)
# Processing hyper voxel : 323/1100 (14 neurons)
# Processing hyper voxel : 244/1100 (13 neurons)
# Processing hyper voxel : 552/1100 (13 neurons)
# Processing hyper voxel : 425/1100 (13 neurons)
# Processing hyper voxel : 352/1100 (13 neurons)
# Processing hyper voxel : 642/1100 (13 neurons)
# Processing hyper voxel : 563/1100 (11 neurons)
# Processing hyper voxel : 422/1100 (10 neurons)
# Processing hyper voxel : 436/1100 (10 neurons)
# Processing hyper voxel : 623/1100 (10 neurons)
# Processing hyper voxel : 446/1100 (10 neurons)
# Processing hyper voxel : 654/1100 (9 neurons)
# Processing hyper voxel : 645/1100 (9 neurons)
# Processing hyper voxel : 441/1100 (9 neurons)
# Processing hyper voxel : 456/1100 (9 neurons)
# Processing hyper voxel : 254/1100 (9 neurons)
# Processing hyper voxel : 624/1100 (9 neurons)
# Processing hyper voxel : 463/1100 (8 neurons)
# Processing hyper voxel : 355/1100 (8 neurons)
# Processing hyper voxel : 632/1100 (8 neurons)
# Processing hyper voxel : 522/1100 (8 neurons)
# Processing hyper voxel : 234/1100 (7 neurons)
# Processing hyper voxel : 465/1100 (7 neurons)
# Processing hyper voxel : 655/1100 (7 neurons)
# Processing hyper voxel : 546/1100 (7 neurons)
# Processing hyper voxel : 253/1100 (7 neurons)
# Processing hyper voxel : 635/1100 (7 neurons)
# Processing hyper voxel : 243/1100 (7 neurons)
# Processing hyper voxel : 464/1100 (7 neurons)
# Processing hyper voxel : 734/1100 (7 neurons)
# Processing hyper voxel : 531/1100 (6 neurons)
# Processing hyper voxel : 536/1100 (6 neurons)
# Processing hyper voxel : 431/1100 (6 neurons)
# Processing hyper voxel : 562/1100 (6 neurons)
# Processing hyper voxel : 564/1100 (6 neurons)
# Processing hyper voxel : 233/1100 (6 neurons)
# Processing hyper voxel : 242/1100 (6 neurons)
# Processing hyper voxel : 346/1100 (6 neurons)
# Processing hyper voxel : 245/1100 (5 neurons)
# Processing hyper voxel : 541/1100 (5 neurons)
# Processing hyper voxel : 664/1100 (4 neurons)
# Processing hyper voxel : 356/1100 (4 neurons)
# Processing hyper voxel : 336/1100 (4 neurons)
# Processing hyper voxel : 362/1100 (4 neurons)
# Processing hyper voxel : 663/1100 (4 neurons)
# Processing hyper voxel : 565/1100 (4 neurons)
# Processing hyper voxel : 724/1100 (4 neurons)
# Processing hyper voxel : 462/1100 (4 neurons)
# Processing hyper voxel : 513/1100 (4 neurons)
# Processing hyper voxel : 753/1100 (3 neurons)
# Processing hyper voxel : 143/1100 (3 neurons)
# Processing hyper voxel : 326/1100 (3 neurons)
# Processing hyper voxel : 652/1100 (3 neurons)
# Processing hyper voxel : 526/1100 (3 neurons)
# Processing hyper voxel : 322/1100 (3 neurons)
# Processing hyper voxel : 154/1100 (3 neurons)
# Processing hyper voxel : 646/1100 (3 neurons)
# Processing hyper voxel : 451/1100 (3 neurons)
# Processing hyper voxel : 514/1100 (3 neurons)
# Processing hyper voxel : 521/1100 (3 neurons)
# Processing hyper voxel : 764/1100 (3 neurons)
# Processing hyper voxel : 235/1100 (3 neurons)
# Processing hyper voxel : 466/1100 (3 neurons)
# Processing hyper voxel : 743/1100 (3 neurons)
# Processing hyper voxel : 556/1100 (3 neurons)
# Processing hyper voxel : 325/1100 (3 neurons)
# Processing hyper voxel : 723/1100 (3 neurons)
# Processing hyper voxel : 622/1100 (3 neurons)
# Processing hyper voxel : 363/1100 (3 neurons)
# Processing hyper voxel : 413/1100 (3 neurons)
# Processing hyper voxel : 426/1100 (3 neurons)
# Processing hyper voxel : 252/1100 (3 neurons)
# Processing hyper voxel : 414/1100 (3 neurons)
# Processing hyper voxel : 613/1100 (3 neurons)
# Processing hyper voxel : 733/1100 (3 neurons)
# Processing hyper voxel : 364/1100 (3 neurons)
# Processing hyper voxel : 574/1100 (3 neurons)
# Processing hyper voxel : 351/1100 (3 neurons)
# Processing hyper voxel : 725/1100 (3 neurons)
# Processing hyper voxel : 527/1100 (2 neurons)
# Processing hyper voxel : 251/1100 (2 neurons)
# Processing hyper voxel : 625/1100 (2 neurons)
# Processing hyper voxel : 321/1100 (2 neurons)
# Processing hyper voxel : 142/1100 (2 neurons)
# Processing hyper voxel : 246/1100 (2 neurons)
# Processing hyper voxel : 752/1100 (2 neurons)
# Processing hyper voxel : 152/1100 (2 neurons)
# Processing hyper voxel : 263/1100 (2 neurons)
# Processing hyper voxel : 261/1100 (2 neurons)
# Processing hyper voxel : 854/1100 (2 neurons)
# Processing hyper voxel : 614/1100 (2 neurons)
# Processing hyper voxel : 754/1100 (2 neurons)
# Processing hyper voxel : 547/1100 (2 neurons)
# Processing hyper voxel : 636/1100 (2 neurons)
# Processing hyper voxel : 755/1100 (2 neurons)
# Processing hyper voxel : 864/1100 (2 neurons)
# Processing hyper voxel : 763/1100 (2 neurons)
# Processing hyper voxel : 255/1100 (2 neurons)
# Processing hyper voxel : 557/1100 (2 neurons)
# Processing hyper voxel : 573/1100 (2 neurons)
# Processing hyper voxel : 537/1100 (2 neurons)
# Processing hyper voxel : 133/1100 (2 neurons)
# Processing hyper voxel : 503/1100 (2 neurons)
# Processing hyper voxel : 515/1100 (2 neurons)
# Processing hyper voxel : 223/1100 (2 neurons)
# Processing hyper voxel : 153/1100 (2 neurons)
# Processing hyper voxel : 341/1100 (2 neurons)
# Processing hyper voxel : 437/1100 (2 neurons)
# Processing hyper voxel : 337/1100 (2 neurons)
# Processing hyper voxel : 457/1100 (2 neurons)
# Processing hyper voxel : 226/1100 (2 neurons)
# Processing hyper voxel : 822/1100 (2 neurons)
# Processing hyper voxel : 427/1100 (2 neurons)
# Processing hyper voxel : 232/1100 (2 neurons)
# Processing hyper voxel : 722/1100 (2 neurons)
# Processing hyper voxel : 412/1100 (2 neurons)
# Processing hyper voxel : 331/1100 (2 neurons)
# Processing hyper voxel : 732/1100 (2 neurons)
# Processing hyper voxel : 403/1100 (2 neurons)
# Processing hyper voxel : 744/1100 (2 neurons)
# Processing hyper voxel : 735/1100 (2 neurons)
# Processing hyper voxel : 742/1100 (2 neurons)
# Processing hyper voxel : 714/1100 (1 neurons)
# Processing hyper voxel : 641/1100 (1 neurons)
# Processing hyper voxel : 784/1100 (1 neurons)
# Processing hyper voxel : 924/1100 (1 neurons)
# Processing hyper voxel : 785/1100 (1 neurons)
# Processing hyper voxel : 713/1100 (1 neurons)
# Processing hyper voxel : 745/1100 (1 neurons)
# Processing hyper voxel : 885/1100 (1 neurons)
# Processing hyper voxel : 884/1100 (1 neurons)
# Processing hyper voxel : 824/1100 (1 neurons)
# Processing hyper voxel : 648/1100 (1 neurons)
# Processing hyper voxel : 651/1100 (1 neurons)
# Processing hyper voxel : 751/1100 (1 neurons)
# Processing hyper voxel : 834/1100 (1 neurons)
# Processing hyper voxel : 656/1100 (1 neurons)
# Processing hyper voxel : 660/1100 (1 neurons)
# Processing hyper voxel : 661/1100 (1 neurons)
# Processing hyper voxel : 662/1100 (1 neurons)
# Processing hyper voxel : 647/1100 (1 neurons)
# Processing hyper voxel : 774/1100 (1 neurons)
# Processing hyper voxel : 843/1100 (1 neurons)
# Processing hyper voxel : 844/1100 (1 neurons)
# Processing hyper voxel : 775/1100 (1 neurons)
# Processing hyper voxel : 833/1100 (1 neurons)
# Processing hyper voxel : 746/1100 (1 neurons)
# Processing hyper voxel : 674/1100 (1 neurons)
# Processing hyper voxel : 756/1100 (1 neurons)
# Processing hyper voxel : 765/1100 (1 neurons)
# Processing hyper voxel : 814/1100 (1 neurons)
# Processing hyper voxel : 41/1100 (1 neurons)
# Processing hyper voxel : 626/1100 (1 neurons)
# Processing hyper voxel : 365/1100 (1 neurons)
# Processing hyper voxel : 361/1100 (1 neurons)
# Processing hyper voxel : 340/1100 (1 neurons)
# Processing hyper voxel : 327/1100 (1 neurons)
# Processing hyper voxel : 320/1100 (1 neurons)
# Processing hyper voxel : 317/1100 (1 neurons)
# Processing hyper voxel : 315/1100 (1 neurons)
# Processing hyper voxel : 313/1100 (1 neurons)
# Processing hyper voxel : 312/1100 (1 neurons)
# Processing hyper voxel : 273/1100 (1 neurons)
# Processing hyper voxel : 264/1100 (1 neurons)
# Processing hyper voxel : 241/1100 (1 neurons)
# Processing hyper voxel : 237/1100 (1 neurons)
# Processing hyper voxel : 366/1100 (1 neurons)
# Processing hyper voxel : 236/1100 (1 neurons)
# Processing hyper voxel : 224/1100 (1 neurons)
# Processing hyper voxel : 220/1100 (1 neurons)
# Processing hyper voxel : 184/1100 (1 neurons)
# Processing hyper voxel : 174/1100 (1 neurons)
# Processing hyper voxel : 164/1100 (1 neurons)
# Processing hyper voxel : 144/1100 (1 neurons)
# Processing hyper voxel : 141/1100 (1 neurons)
# Processing hyper voxel : 134/1100 (1 neurons)
# Processing hyper voxel : 124/1100 (1 neurons)
# Processing hyper voxel : 123/1100 (1 neurons)
# Processing hyper voxel : 53/1100 (1 neurons)
# Processing hyper voxel : 43/1100 (1 neurons)
# Processing hyper voxel : 42/1100 (1 neurons)
# Processing hyper voxel : 227/1100 (1 neurons)
# Processing hyper voxel : 367/1100 (1 neurons)
# Processing hyper voxel : 373/1100 (1 neurons)
# Processing hyper voxel : 374/1100 (1 neurons)
# Processing hyper voxel : 585/1100 (1 neurons)
# Processing hyper voxel : 576/1100 (1 neurons)
# Processing hyper voxel : 575/1100 (1 neurons)
# Processing hyper voxel : 566/1100 (1 neurons)
# Processing hyper voxel : 558/1100 (1 neurons)
# Processing hyper voxel : 551/1100 (1 neurons)
# Processing hyper voxel : 550/1100 (1 neurons)
# Processing hyper voxel : 540/1100 (1 neurons)
# Processing hyper voxel : 512/1100 (1 neurons)
# Processing hyper voxel : 511/1100 (1 neurons)
# Processing hyper voxel : 505/1100 (1 neurons)
# Processing hyper voxel : 502/1100 (1 neurons)
# Processing hyper voxel : 485/1100 (1 neurons)
# Processing hyper voxel : 475/1100 (1 neurons)
# Processing hyper voxel : 473/1100 (1 neurons)
# Processing hyper voxel : 472/1100 (1 neurons)
# Processing hyper voxel : 471/1100 (1 neurons)
# Processing hyper voxel : 963/1100 (1 neurons)
# Processing hyper voxel : 461/1100 (1 neurons)
# Processing hyper voxel : 450/1100 (1 neurons)
# Processing hyper voxel : 447/1100 (1 neurons)
# Processing hyper voxel : 440/1100 (1 neurons)
# Processing hyper voxel : 430/1100 (1 neurons)
# Processing hyper voxel : 421/1100 (1 neurons)
# Processing hyper voxel : 418/1100 (1 neurons)
# Processing hyper voxel : 417/1100 (1 neurons)
# Processing hyper voxel : 415/1100 (1 neurons)
# Processing hyper voxel : 405/1100 (1 neurons)
# Processing hyper voxel : 402/1100 (1 neurons)
# Processing hyper voxel : 631/1100 (1 neurons)
# Processing hyper voxel : 964/1100 (1 neurons)

# %%
from snudda.optimise.optimise_pruning import OptimisePruning
op = OptimisePruning(network_path=network_path)

# %%
op.merge_putative_synapses(force_merge=True)
# Out:
# Read 15424 out of total 15424 synapses

# %%
op.prune.connectivity_distributions
# Out:
# {(1,
#   2,
#   10): ({'f1': 1.0,
#    'soft_max': None,
#    'mu2': None,
#    'a3': None,
#    'dist_pruning': None,
#    'cluster_pruning': False}, None)}

# %%
op.prune.type_id_lookup
# Out:
# {'dSPN': 1, 'iSPN': 2}

# %%
op.prune.hist_file["meta/connectivity_distributions"][()]
# Out:
# b'{"dSPN$$iSPN": {"GABA": {"conductance": [2.4e-10, 1e-10], "channel_parameters": {"mod_file": "tmGabaA"}, "cluster_size": 1, "cluster_spread": null, "pruning": {"f1": null, "soft_max": null, "mu2": null, "a3": null, "dist_pruning": null, "cluster_pruning": false}, "channel_model_id": 10, "lognormal_mu_sigma": [-22.230424900260093, 0.40010675493807013]}}}'

# %%
res = op.optimize(pre_type=pre_type, post_type=post_type, con_type=con_type, 
                  experimental_data=experimental_data, 
                  avg_num_synapses_per_pair=avg_num_synapses_per_pair,
                  extra_pruning_parameters=extra_pruning_parameters, 
                  workers=8, maxiter=1000, pop_size=pop_size, tol=0.00001, 
                  param_names=param_names, param_bounds="default")
# Out:
# /home/hjorth/HBP/Snudda/venv/lib/python3.13/site-packages/scipy/optimize/_differentialevolution.py:487: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# numprocs=1
# Worker iter: 100, fitness 7.457335064103088
# Worker iter: 100, fitness 7.533502545605547
# Worker iter: 100, fitness 6.900369373035158
# Worker iter: 100, fitness 6.8992668454668395
# Worker iter: 100, fitness 7.465055498908163
# Worker iter: 100, fitness 7.5520659115696045
# Worker iter: 100, fitness 7.233583120654148
# Worker iter: 100, fitness 7.050507199427527
# Worker iter: 200, fitness 6.682176556176171
# Worker iter: 200, fitness 6.787535287383452
# Worker iter: 200, fitness 6.801150797291767
# Worker iter: 200, fitness 6.797570910746632
# Worker iter: 200, fitness 6.7607974951160115
# Worker iter: 200, fitness 6.85590551896653
# Worker iter: 200, fitness 6.879672973479273
# Worker iter: 200, fitness 6.682176556176171
# Worker iter: 300, fitness 6.627445462839647
# Worker iter: 300, fitness 6.606850023520946
# Worker iter: 300, fitness 6.609263644657829
# Worker iter: 300, fitness 6.572900008294193
# Worker iter: 300, fitness 6.572900008294193
# Worker iter: 300, fitness 6.618587653981838
# Worker iter: 300, fitness 6.609263644657829
# Worker iter: 300, fitness 6.609263644657829
# Worker iter: 400, fitness 6.572900008294193
# Duration: 73.80252520199974 s

# %%
op.export_json("network-config-opt.json", append=True, res=res)

# %% [markdown]
# # Best parameter set

# %%
param_str = ""
for p_name, p_val in zip(param_names, res.x):
    param_str += f"{p_name} = {p_val:.4f}, "
    
if "distPruning" in extra_pruning_parameters:
   param_str += f" ({extra_pruning_parameters['distPruning']})"                                                  
                                                 
print(param_str)
# Out:
# f1 = 0.2175, mu2 = 1.7053, a3 = 0.4214,  (1-exp(-(0.4*d/60e-6)**2))

# %%
res
# Out:
#              message: Optimization terminated successfully.
#              success: True
#                  fun: 6.572900008294193
#                    x: [ 2.175e-01  1.705e+00  4.214e-01]
#                  nit: 68
#                 nfev: 3109
#           population: [[ 2.175e-01  1.705e+00  4.214e-01]
#                        [ 2.176e-01  1.705e+00  4.215e-01]
#                        ...
#                        [ 2.175e-01  1.705e+00  4.214e-01]
#                        [ 2.175e-01  1.705e+00  4.215e-01]]
#  population_energies: [ 6.573e+00  6.573e+00 ...  6.573e+00  6.573e+00]

# %%
import os
from snudda.analyse.analyse import SnuddaAnalyse
import glob

# Get the last file
# list_of_files = glob.glob(os.path.join(network_path, "temp", "network-synapses-*hdf5"))
# network_file = max(list_of_files, key=os.path.getctime)

network_file = os.path.join(network_path, "network-synapses.hdf5")

dist3D = False
y_max_H = None

sa = SnuddaAnalyse(network_file)
# Out:
# Assuming volume type: cube [cube or full]
# Only using 20000 neurons of the connection data
# Creating figures directory networks/dSPN_to_iSPN_f1_mu2_a3_distdep/figures
# Number of neurons: 300
# Synapse row 0 - 0.0 % time: 0.0009316670002590399 seconds
# Created connection matrix 0.0013443750012811506 seconds
# Created gap junction connection matrix 0.00013470799967763014 seconds
# Creating population dictionary
# Done.
# Warning: the analysis cube specified by sideLen is too large.
# !!! Setting sideLen to None
# Calculating synapse distance histogram
# Creating dist histogram
# n_synapses = 632, at 0
# Created distance histogram (optimised) in 0.001044208000166691 seconds
# Saving cache to networks/dSPN_to_iSPN_f1_mu2_a3_distdep/network-synapses.hdf5-cache

# %%
if pre_type == "dSPN" and post_type == "iSPN":
    sa.plot_connection_probability("dSPN", "iSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(3, 47), (3, 66)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("dSPN", "iSPN", sub_title=param_str)
elif pre_type == "dSPN" and post_type == "dSPN":
    sa.plot_connection_probability("dSPN", "dSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(5, 19), (3, 43)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("dSPN", "dSPN", sub_title=param_str)
elif pre_type == "iSPN" and post_type == "iSPN":
    sa.plot_connection_probability("iSPN", "iSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(14, 39), (7, 31)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("iSPN", "iSPN", sub_title=param_str)
elif pre_type == "iSPN" and post_type == "dSPN":
    sa.plot_connection_probability("iSPN", "dSPN", dist_3d=True, exp_max_dist=[50e-6, 100e-6], exp_data_detailed=[(13, 47), (10, 80)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("iSPN", "dSPN", sub_title=param_str)
elif pre_type == "FS" and post_type == "FS":
    sa.plot_connection_probability("FS", "FS", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(7, 12)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "FS", sub_title=param_str)
elif pre_type == "FS" and post_type == "iSPN":
    sa.plot_connection_probability("FS", "iSPN", dist_3d=True, exp_max_dist=[100e-6, 150e-6, 250e-6], exp_data_detailed=[(6, 9), (21, 54), (27,77)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "iSPN", sub_title=param_str)
elif pre_type == "FS" and post_type == "dSPN":
    sa.plot_connection_probability("FS", "dSPN", dist_3d=True, exp_max_dist=[100e-6, 150e-6, 250e-6], exp_data_detailed=[(8, 9), (29, 48), (48,90)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "dSPN", sub_title=param_str)
    
elif pre_type == "FS" and post_type == "LTS":
    sa.plot_connection_probability("FS", "LTS", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(2, 12)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("FS", "LTS", sub_title=param_str)
elif pre_type == 'LTS' and post_type == "dSPN":
    sa.plot_connection_probability("LTS", "dSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(2, 60)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("LTS", "dSPN", sub_title=param_str)
elif pre_type == 'LTS' and post_type == "iSPN":
    sa.plot_connection_probability("LTS", "iSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data_detailed=[(2, 60)], sub_title=param_str)
    sa.plot_num_synapses_per_pair("LTS", "iSPN", sub_title=param_str)
elif pre_type == 'ChIN' and post_type == "dSPN":
    sa.plot_connection_probability("ChIN", "dSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data=[0.05], sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "dSPN", sub_title=param_str)
elif pre_type == 'ChIN' and post_type == "iSPN":
    sa.plot_connection_probability("ChIN", "iSPN", dist_3d=True, exp_max_dist=[250e-6], exp_data=[0.05], sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "iSPN", sub_title=param_str)

# Missing pairwise experimental data...
    
elif pre_type == 'ChIN' and post_type == "FS":
    sa.plot_connection_probability("ChIN", "FS", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "FS", sub_title=param_str)
elif pre_type == 'ChIN' and post_type == "LTS":
    sa.plot_connection_probability("ChIN", "LTS", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("ChIN", "LTS", sub_title=param_str)

elif pre_type == 'LTS' and post_type == "ChIN":
    sa.plot_connection_probability("LTS", "ChIN", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("LTS", "ChIN", sub_title=param_str)

    
elif pre_type == 'dSPN' and post_type == "ChIN":
    sa.plot_connection_probability("dSPN", "ChIN", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("dSPN", "ChIN", sub_title=param_str)
elif pre_type == 'iSPN' and post_type == "ChIN":
    sa.plot_connection_probability("iSPN", "ChIN", dist_3d=True, sub_title=param_str)
    sa.plot_num_synapses_per_pair("iSPN", "ChIN", sub_title=param_str)
# Out:
# Plotting connection probability dSPN to iSPN (synapses)
# Centering in None : Keeping 150/150
# Counting connections
# Requested: 10000000.0 calculated [22500.]
# Num pairs outside plot range 0
# P(d<5e-05) = 0.054466230936819175
# P(d<0.0001) = 0.03561439492821182
# /home/hjorth/HBP/Snudda/snudda/analyse/analyse.py:1443: RuntimeWarning: invalid value encountered in divide
#   p_con = np.divide(count_con, count_all)
# Wrote networks/dSPN_to_iSPN_f1_mu2_a3_distdep/figures/Network-distance-dependent-connection-probability-dSPN-to-iSPN-synapses-3D-dist.png
# Plotting number of connections
# Only analysing centre post synaptic neurons, sideLen = 0.00025
# Centering in None : Keeping 150/150
# Calculating max synapses
# Calculating mean synapses
# Plotting 275 connections
# Wrote networks/dSPN_to_iSPN_f1_mu2_a3_distdep/figures/Network-number-of-synapses-from-dSPN-to-iSPN-per-cell.png
