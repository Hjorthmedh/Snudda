# %% [markdown]
# This example illustrates how to create input to a population of neurons.
#
# First run the simple_network_creation.ipynb so that you have a networks/simple_example folder in the example/notebooks folder with the small network.

# %%
import os
from snudda.input import SnuddaInput
network_path = os.path.join("networks","simple_example")
si = SnuddaInput(network_path=network_path, input_config_file=os.path.join("input_config","simple-input-1.json"))
si.generate()
# Out:
# Time = 10.0
# Using hdf5 version latest
# Loading HDF5-file: networks/simple_example/network-pruned-synapses.hdf5
# Loading input configuration from input_config/simple-input-1.json
# Reading neuron postions
# Loading networks/simple_example/network-neuron-positions.hdf5
# No SlurmID set, using -1
# Load done. 0.007853750023059547
# Reading config file networks/simple_example/network-config.json
# Reading random see from config file: 924159892
# Running in serial
# Running makePopulationUnitSpikeTrains
# Running makeNeuronInputParallel
# !!! Warning, no synaptic input for neuron ID 0, name iSPN_2 or type iSPN
# !!! Warning, no synaptic input for neuron ID 1, name iSPN_0 or type iSPN
# !!! Warning, no synaptic input for neuron ID 3, name iSPN_2 or type iSPN
# !!! Warning, no synaptic input for neuron ID 9, name iSPN_0 or type iSPN
# !!! Warning, no synaptic input for neuron ID 11, name iSPN_1 or type iSPN
# !!! Warning, no synaptic input for neuron ID 20, name iSPN_3 or type iSPN
# ...

# %%
from snudda.plotting.plot_input import PlotInput
input_file = os.path.join(network_path, "input-spikes.hdf5")
spi = PlotInput(input_file)
spi.plot_input([2,4,5,6,7,8])

# %%
spi.plot_input([2,4,5, 6])
