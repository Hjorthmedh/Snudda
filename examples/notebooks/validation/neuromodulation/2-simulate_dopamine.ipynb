# %%
from neuromodulation_sim import *

# %%
network_path = os.path.join("networks/dopamine_validation")

# %%
# If the BasalGangliaData directory exists, then use that for our data
BG_path = os.path.join("..", "..","..","..","..", "BasalGangliaData", "data")
if os.path.exists(BG_path):
    os.environ["SNUDDA_DATA"] = BG_path
    print(f"Setting SNUDDA_DATA to {BG_path}")
else:
    print(f"SNUDDA_DATA environment variable not changed (may be empty)")
# Out:
# Setting SNUDDA_DATA to ../../../../../BasalGangliaData/data

# %%
simulate(network_path=network_path)
# Out:
# Warning: No external synaptic input file given!
# Using network_file: networks/dopamine_validation/network-synapses.hdf5
# Using input_file: None
# Using output_file: networks/dopamine_validation/simulation/test.hdf5
# Using logFile: networks/dopamine_validation/log/network-simulation-log.txt-0
# Worker 0 : Loading network from networks/dopamine_validation/network-synapses.hdf5
# Loading 10 neurons with 101 synapses and 0 gap junctions
# Loading config file networks/dopamine_validation/network-config.json
#  Using neuromodulation module in Snudda
# 0 : Memory status: 18% free
# Distributing neurons.
# Setup neurons
# Node 0 - cell 0 dSPN_1
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/bluepyopt/ephys/simulators.py:89: UserWarning: Unable to find Neuron hoc shared library in /usr/local/nrn/lib/python/neuron, not disabling banner
#   'not disabling banner' % nrnpy_path)
# Neuron dSPN_1 (0) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 1 dSPN_0
# Neuron dSPN_0 (1) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 2 dSPN_3
# Neuron dSPN_3 (2) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 3 dSPN_3
# Neuron dSPN_3 (3) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 4 dSPN_2
# Neuron dSPN_2 (4) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 5 dSPN_2
# Neuron dSPN_2 (5) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 6 dSPN_1
# Neuron dSPN_1 (6) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 7 dSPN_0
# Neuron dSPN_0 (7) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 8 dSPN_1
# Neuron dSPN_1 (8) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 9 dSPN_3
# Neuron dSPN_3 (9) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# 0 : Memory status: 18% free
# Adding gap junctions.
# connect_network_gap_junctions_local
# Finding node local gap junctions...
# Adding synapses.
# connect_network_synapses
# 0 : Memory status: 18% free
# 0 : Memory status: 18% free
# Adding to 0 the amplitude 6.092461538461538e-10
# Within the function to 0 the amplitude 0.6092461538461539
# Adding to 1 the amplitude 4.799510204081633e-10
# Within the function to 1 the amplitude 0.47995102040816323
# Adding to 2 the amplitude 5.871153846153846e-10
# Within the function to 2 the amplitude 0.5871153846153846
# Adding to 3 the amplitude 5.871153846153846e-10
# Within the function to 3 the amplitude 0.5871153846153846
# Adding to 4 the amplitude 3.661102564102564e-10
# Within the function to 4 the amplitude 0.3661102564102564
# Adding to 5 the amplitude 3.8662307692307695e-10
# Within the function to 5 the amplitude 0.38662307692307696
# Adding to 6 the amplitude 5.118102564102564e-10
# Within the function to 6 the amplitude 0.5118102564102565
# Adding to 7 the amplitude 5.003591836734693e-10
# Within the function to 7 the amplitude 0.5003591836734693
# Adding to 8 the amplitude 5.848871794871795e-10
# Within the function to 8 the amplitude 0.5848871794871795
# Adding to 9 the amplitude 6.460897435897435e-10
# Within the function to 9 the amplitude 0.6460897435897435
# Running simulation for 2.0 s
# Running Neuron simulator 2000 ms, with dt=0.025
# 1% done. Elapsed: 5.3 s, estimated time left: 520.0 s
# 2% done. Elapsed: 10.4 s, estimated time left: 510.6 s
# 54% done. Elapsed: 301.8 s, estimated time left: 257.1 s
# 55% done. Elapsed: 307.7 s, estimated time left: 251.8 s
# 56% done. Elapsed: 313.5 s, estimated time left: 246.3 s
# 57% done. Elapsed: 319.4 s, estimated time left: 241.0 s
# 58% done. Elapsed: 325.5 s, estimated time left: 235.7 s
# 59% done. Elapsed: 331.0 s, estimated time left: 230.0 s
# 60% done. Elapsed: 337.0 s, estimated time left: 224.7 s
# 61% done. Elapsed: 342.6 s, estimated time left: 219.0 s
# 62% done. Elapsed: 348.1 s, estimated time left: 213.4 s
# 63% done. Elapsed: 353.5 s, estimated time left: 207.6 s
# 64% done. Elapsed: 358.9 s, estimated time left: 201.9 s
# 65% done. Elapsed: 364.4 s, estimated time left: 196.2 s
# 66% done. Elapsed: 370.1 s, estimated time left: 190.7 s
# 67% done. Elapsed: 375.6 s, estimated time left: 185.0 s
# 68% done. Elapsed: 381.0 s, estimated time left: 179.3 s
# 69% done. Elapsed: 386.6 s, estimated time left: 173.7 s
# 70% done. Elapsed: 392.1 s, estimated time left: 168.0 s
# 71% done. Elapsed: 397.6 s, estimated time left: 162.4 s
# 72% done. Elapsed: 403.2 s, estimated time left: 156.8 s
# 73% done. Elapsed: 408.7 s, estimated time left: 151.1 s
# 74% done. Elapsed: 415.3 s, estimated time left: 145.9 s
# 75% done. Elapsed: 420.8 s, estimated time left: 140.3 s
# 76% done. Elapsed: 426.2 s, estimated time left: 134.6 s
# 77% done. Elapsed: 431.7 s, estimated time left: 129.0 s
# 78% done. Elapsed: 437.2 s, estimated time left: 123.3 s
# 79% done. Elapsed: 442.7 s, estimated time left: 117.7 s
# 80% done. Elapsed: 448.6 s, estimated time left: 112.1 s
# 81% done. Elapsed: 454.1 s, estimated time left: 106.5 s
# 82% done. Elapsed: 459.6 s, estimated time left: 100.9 s
# 83% done. Elapsed: 465.3 s, estimated time left: 95.3 s
# 84% done. Elapsed: 470.9 s, estimated time left: 89.7 s
# 85% done. Elapsed: 476.5 s, estimated time left: 84.1 s
# 86% done. Elapsed: 482.1 s, estimated time left: 78.5 s
# 87% done. Elapsed: 487.8 s, estimated time left: 72.9 s
# 88% done. Elapsed: 493.4 s, estimated time left: 67.3 s
# 89% done. Elapsed: 499.0 s, estimated time left: 61.7 s
# 90% done. Elapsed: 504.6 s, estimated time left: 56.1 s
# 91% done. Elapsed: 510.2 s, estimated time left: 50.5 s
# 92% done. Elapsed: 515.7 s, estimated time left: 44.8 s
# 93% done. Elapsed: 521.3 s, estimated time left: 39.2 s
# 94% done. Elapsed: 526.7 s, estimated time left: 33.6 s
# 95% done. Elapsed: 532.2 s, estimated time left: 28.0 s
# 96% done. Elapsed: 537.2 s, estimated time left: 22.4 s
# 97% done. Elapsed: 541.9 s, estimated time left: 16.8 s
# 98% done. Elapsed: 546.5 s, estimated time left: 11.2 s
# 99% done. Elapsed: 551.1 s, estimated time left: 5.6 s
# Neuron simulation finished
# Simulation done.
# Simulation run time: 555.7 s
# Writing network output to networks/dopamine_validation/simulation/test.hdf5
# CHeck why not able to save...
# Using sample dt = 0.0005 (sample step size 20)
# Worker 1/1 writing data to networks/dopamine_validation/simulation/test.hdf5
