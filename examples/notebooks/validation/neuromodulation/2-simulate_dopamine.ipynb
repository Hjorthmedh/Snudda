# %%
from neuromodulation_sim import *

# %%
network_path = os.path.join("networks/dopamine_validation")

# %%
# If the BasalGangliaData directory exists, then use that for our data
BG_path = os.path.join("..", "..","..","..","..", "BasalGangliaData", "data")
if os.path.exists(BG_path):
    os.environ["SNUDDA_DATA"] = BG_path
    print(f"Setting SNUDDA_DATA to {BG_path}")
else:
    print(f"SNUDDA_DATA environment variable not changed (may be empty)")
# Out:
# Setting SNUDDA_DATA to ../../../../../BasalGangliaData/data

# %%
simulate(network_path=network_path)
# Out:
# Reading SNUDDA_DATA=../../../../../BasalGangliaData/data from networks/dopamine_validation/network-config.json
# Warning: No external synaptic input file given!
# Using network_file: networks/dopamine_validation/network-synapses.hdf5
# Using input_file: None
# Using output_file: networks/dopamine_validation/simulation/test.hdf5
# Using logFile: networks/dopamine_validation/log/network-simulation-log.txt-0
# Worker 0 : Loading network from networks/dopamine_validation/network-synapses.hdf5
# Loading 10 neurons with 82 synapses and 0 gap junctions
# Loading config file networks/dopamine_validation/network-config.json
#  Using neuromodulation module in Snudda
# 0 : Memory status: 45% free
# Distributing neurons.
# Setup neurons
# Empty modFile field for ChIN -> dSPN synapses. This channel is IGNORED.
# Empty modFile field for ChIN -> iSPN synapses. This channel is IGNORED.
# Node 0 - cell 0 dSPN_1
# /home/hjorth/.local/lib/python3.9/site-packages/bluepyopt/ephys/simulators.py:83: UserWarning: Unable to find Neuron hoc shared library in /usr/local/lib/python/neuron, not disabling banner
#   warnings.warn('Unable to find Neuron hoc shared library in %s, '
# Neuron dSPN_1 (0) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 1 dSPN_0
# Neuron dSPN_0 (1) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 2 dSPN_3
# Neuron dSPN_3 (2) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 3 dSPN_3
# Neuron dSPN_3 (3) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 4 dSPN_2
# Neuron dSPN_2 (4) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 5 dSPN_2
# Neuron dSPN_2 (5) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 6 dSPN_1
# Neuron dSPN_1 (6) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 7 dSPN_0
# Neuron dSPN_0 (7) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 8 dSPN_1
# Neuron dSPN_1 (8) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 9 dSPN_3
# Neuron dSPN_3 (9) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# 0 : Memory status: 45% free
# Adding gap junctions.
# connect_network_gap_junctions_local
# Finding node local gap junctions...
# Added 0.0 gap junctions to simulation (0 total)
# Adding synapses.
# connect_network_synapses
# Added 82 on worker 0
# Added 82 synapses to simulation (82 total)
# 0 : Memory status: 45% free
# 0 : Memory status: 45% free
# Adding to 0 the amplitude 6.092461538461538e-10
# Within the function to 0 the amplitude 0.6092461538461539
# Adding to 1 the amplitude 4.799510204081633e-10
# Within the function to 1 the amplitude 0.47995102040816323
# Adding to 2 the amplitude 5.871153846153846e-10
# Within the function to 2 the amplitude 0.5871153846153846
# Adding to 3 the amplitude 5.871153846153846e-10
# Within the function to 3 the amplitude 0.5871153846153846
# Adding to 4 the amplitude 3.661102564102564e-10
# Within the function to 4 the amplitude 0.3661102564102564
# Adding to 5 the amplitude 3.8662307692307695e-10
# Within the function to 5 the amplitude 0.38662307692307696
# Adding to 6 the amplitude 5.118102564102564e-10
# Within the function to 6 the amplitude 0.5118102564102565
# Adding to 7 the amplitude 5.003591836734693e-10
# Within the function to 7 the amplitude 0.5003591836734693
# Adding to 8 the amplitude 5.848871794871795e-10
# Within the function to 8 the amplitude 0.5848871794871795
# Adding to 9 the amplitude 6.460897435897435e-10
# Within the function to 9 the amplitude 0.6460897435897435
# Running simulation for 2.0 s
# Running Neuron simulator 2000 ms, with dt=0.025
# 1% done. Elapsed: 3.9 s, estimated time left: 389.0 s
# 2% done. Elapsed: 7.8 s, estimated time left: 382.0 s
# 3% done. Elapsed: 11.7 s, estimated time left: 378.3 s
# 4% done. Elapsed: 15.5 s, estimated time left: 372.1 s
# 5% done. Elapsed: 19.3 s, estimated time left: 366.3 s
# 6% done. Elapsed: 23.1 s, estimated time left: 361.5 s
# 7% done. Elapsed: 27.0 s, estimated time left: 359.0 s
# 8% done. Elapsed: 30.8 s, estimated time left: 354.1 s
# 9% done. Elapsed: 34.6 s, estimated time left: 350.3 s
# 10% done. Elapsed: 38.5 s, estimated time left: 346.6 s
# 11% done. Elapsed: 42.2 s, estimated time left: 341.5 s
# 12% done. Elapsed: 45.9 s, estimated time left: 336.6 s
# 13% done. Elapsed: 49.6 s, estimated time left: 331.8 s
# 14% done. Elapsed: 53.3 s, estimated time left: 327.3 s
# 15% done. Elapsed: 57.1 s, estimated time left: 323.4 s
# 16% done. Elapsed: 60.8 s, estimated time left: 319.0 s
# 17% done. Elapsed: 64.5 s, estimated time left: 314.8 s
# 18% done. Elapsed: 68.1 s, estimated time left: 310.5 s
# 19% done. Elapsed: 71.8 s, estimated time left: 306.2 s
# 20% done. Elapsed: 75.5 s, estimated time left: 302.2 s
# 21% done. Elapsed: 79.2 s, estimated time left: 298.1 s
# 22% done. Elapsed: 83.0 s, estimated time left: 294.2 s
# 23% done. Elapsed: 86.6 s, estimated time left: 290.1 s
# 24% done. Elapsed: 90.4 s, estimated time left: 286.2 s
# 25% done. Elapsed: 94.0 s, estimated time left: 282.1 s
# 26% done. Elapsed: 97.7 s, estimated time left: 278.1 s
# 27% done. Elapsed: 101.4 s, estimated time left: 274.1 s
# 28% done. Elapsed: 105.1 s, estimated time left: 270.2 s
# 29% done. Elapsed: 108.8 s, estimated time left: 266.4 s
# 30% done. Elapsed: 112.5 s, estimated time left: 262.6 s
# 31% done. Elapsed: 116.2 s, estimated time left: 258.7 s
# 32% done. Elapsed: 119.9 s, estimated time left: 254.8 s
# 33% done. Elapsed: 123.6 s, estimated time left: 251.0 s
# 34% done. Elapsed: 127.3 s, estimated time left: 247.2 s
# 35% done. Elapsed: 131.0 s, estimated time left: 243.3 s
# 36% done. Elapsed: 134.7 s, estimated time left: 239.5 s
# 37% done. Elapsed: 138.5 s, estimated time left: 235.7 s
# 38% done. Elapsed: 142.2 s, estimated time left: 232.0 s
# 39% done. Elapsed: 146.1 s, estimated time left: 228.5 s
# 40% done. Elapsed: 149.8 s, estimated time left: 224.7 s
# 41% done. Elapsed: 153.5 s, estimated time left: 220.9 s
# 42% done. Elapsed: 157.3 s, estimated time left: 217.2 s
# 43% done. Elapsed: 162.2 s, estimated time left: 215.0 s
# 44% done. Elapsed: 166.0 s, estimated time left: 211.2 s
# 45% done. Elapsed: 169.8 s, estimated time left: 207.5 s
# 46% done. Elapsed: 173.5 s, estimated time left: 203.7 s
# 47% done. Elapsed: 177.3 s, estimated time left: 199.9 s
# 48% done. Elapsed: 181.1 s, estimated time left: 196.1 s
# 49% done. Elapsed: 184.8 s, estimated time left: 192.4 s
# 50% done. Elapsed: 188.6 s, estimated time left: 188.6 s
# 51% done. Elapsed: 192.3 s, estimated time left: 184.8 s
# 52% done. Elapsed: 196.2 s, estimated time left: 181.1 s
# 53% done. Elapsed: 199.9 s, estimated time left: 177.3 s
# 54% done. Elapsed: 203.6 s, estimated time left: 173.5 s
# 55% done. Elapsed: 207.4 s, estimated time left: 169.7 s
# 56% done. Elapsed: 211.1 s, estimated time left: 165.9 s
# 57% done. Elapsed: 214.9 s, estimated time left: 162.1 s
# 58% done. Elapsed: 218.6 s, estimated time left: 158.3 s
# 59% done. Elapsed: 222.4 s, estimated time left: 154.5 s
# 60% done. Elapsed: 226.1 s, estimated time left: 150.8 s
# 61% done. Elapsed: 230.0 s, estimated time left: 147.0 s
# 62% done. Elapsed: 233.8 s, estimated time left: 143.3 s
# 63% done. Elapsed: 237.7 s, estimated time left: 139.6 s
# 64% done. Elapsed: 241.4 s, estimated time left: 135.8 s
# 65% done. Elapsed: 245.2 s, estimated time left: 132.0 s
# 66% done. Elapsed: 248.9 s, estimated time left: 128.2 s
# 67% done. Elapsed: 252.7 s, estimated time left: 124.4 s
# 68% done. Elapsed: 256.4 s, estimated time left: 120.7 s
# 69% done. Elapsed: 260.2 s, estimated time left: 116.9 s
# 70% done. Elapsed: 264.0 s, estimated time left: 113.1 s
# 71% done. Elapsed: 267.8 s, estimated time left: 109.4 s
# 72% done. Elapsed: 271.6 s, estimated time left: 105.6 s
# 73% done. Elapsed: 275.4 s, estimated time left: 101.9 s
# 74% done. Elapsed: 279.2 s, estimated time left: 98.1 s
# 75% done. Elapsed: 282.9 s, estimated time left: 94.3 s
# 76% done. Elapsed: 287.0 s, estimated time left: 90.6 s
# 77% done. Elapsed: 290.9 s, estimated time left: 86.9 s
# 78% done. Elapsed: 294.7 s, estimated time left: 83.1 s
# 79% done. Elapsed: 298.5 s, estimated time left: 79.3 s
# 80% done. Elapsed: 302.2 s, estimated time left: 75.6 s
# 81% done. Elapsed: 306.0 s, estimated time left: 71.8 s
# 82% done. Elapsed: 309.8 s, estimated time left: 68.0 s
# 83% done. Elapsed: 313.5 s, estimated time left: 64.2 s
# 84% done. Elapsed: 317.3 s, estimated time left: 60.4 s
# 85% done. Elapsed: 321.1 s, estimated time left: 56.7 s
# 86% done. Elapsed: 324.8 s, estimated time left: 52.9 s
# 87% done. Elapsed: 328.6 s, estimated time left: 49.1 s
# 88% done. Elapsed: 332.4 s, estimated time left: 45.3 s
# 89% done. Elapsed: 336.1 s, estimated time left: 41.5 s
# 90% done. Elapsed: 339.9 s, estimated time left: 37.8 s
# 91% done. Elapsed: 343.6 s, estimated time left: 34.0 s
# 92% done. Elapsed: 347.4 s, estimated time left: 30.2 s
# 93% done. Elapsed: 351.2 s, estimated time left: 26.4 s
# 94% done. Elapsed: 354.9 s, estimated time left: 22.7 s
# 95% done. Elapsed: 358.7 s, estimated time left: 18.9 s
# 96% done. Elapsed: 362.5 s, estimated time left: 15.1 s
# 97% done. Elapsed: 366.2 s, estimated time left: 11.3 s
# 98% done. Elapsed: 370.0 s, estimated time left: 7.6 s
# 99% done. Elapsed: 373.7 s, estimated time left: 3.8 s
# Neuron simulation finished
# Simulation done.
# Simulation run time: 377.4 s
# Writing network output to networks/dopamine_validation/simulation/test.hdf5
# Using sample dt = 0.0005 (sample step size 20)
# Worker 1/1 writing data to networks/dopamine_validation/simulation/test.hdf5
