# %%
from neuromodulation_sim import *

# %%
network_path = os.path.join("networks/dopamine_validation")

# %%
# If the BasalGangliaData directory exists, then use that for our data
BG_path = os.path.join("..", "..","..","..","..", "BasalGangliaData", "data")
if os.path.exists(BG_path):
    os.environ["SNUDDA_DATA"] = BG_path
    print(f"Setting SNUDDA_DATA to {BG_path}")
else:
    print(f"SNUDDA_DATA environment variable not changed (may be empty)")
# Out:
# Setting SNUDDA_DATA to ../../../../../BasalGangliaData/data

# %%
simulate_control(network_path=network_path)
# Out:
# Warning: No external synaptic input file given!
# Using network_file: networks/dopamine_validation/network-synapses.hdf5
# Using input_file: None
# Using output_file: networks/dopamine_validation/simulation/test_control.hdf5
# Using logFile: networks/dopamine_validation/log/network-simulation-log.txt-0
# Worker 0 : Loading network from networks/dopamine_validation/network-synapses.hdf5
# Loading 10 neurons with 101 synapses and 0 gap junctions
# Loading config file networks/dopamine_validation/network-config.json
#  Using neuromodulation module in Snudda
# 0 : Memory status: 18% free
# Distributing neurons.
# Setup neurons
# Node 0 - cell 0 dSPN_1
# /home/jofrony/miniconda3/envs/py37/lib/python3.7/site-packages/bluepyopt/ephys/simulators.py:89: UserWarning: Unable to find Neuron hoc shared library in /usr/local/nrn/lib/python/neuron, not disabling banner
#   'not disabling banner' % nrnpy_path)
# Neuron dSPN_1 (0) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 1 dSPN_0
# Neuron dSPN_0 (1) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 2 dSPN_3
# Neuron dSPN_3 (2) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 3 dSPN_3
# Neuron dSPN_3 (3) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 4 dSPN_2
# Neuron dSPN_2 (4) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 5 dSPN_2
# Neuron dSPN_2 (5) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 6 dSPN_1
# Neuron dSPN_1 (6) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 7 dSPN_0
# Neuron dSPN_0 (7) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 8 dSPN_1
# Neuron dSPN_1 (8) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 9 dSPN_3
# Neuron dSPN_3 (9) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# 0 : Memory status: 18% free
# Adding to 0 the amplitude 6.092461538461538e-10
# Within the function to 0 the amplitude 0.6092461538461539
# Adding to 1 the amplitude 4.799510204081633e-10
# Within the function to 1 the amplitude 0.47995102040816323
# Adding to 2 the amplitude 5.871153846153846e-10
# Within the function to 2 the amplitude 0.5871153846153846
# Adding to 3 the amplitude 5.871153846153846e-10
# Within the function to 3 the amplitude 0.5871153846153846
# Adding to 4 the amplitude 3.661102564102564e-10
# Within the function to 4 the amplitude 0.3661102564102564
# Adding to 5 the amplitude 3.8662307692307695e-10
# Within the function to 5 the amplitude 0.38662307692307696
# Adding to 6 the amplitude 5.118102564102564e-10
# Within the function to 6 the amplitude 0.5118102564102565
# Adding to 7 the amplitude 5.003591836734693e-10
# Within the function to 7 the amplitude 0.5003591836734693
# Adding to 8 the amplitude 5.848871794871795e-10
# Within the function to 8 the amplitude 0.5848871794871795
# Adding to 9 the amplitude 6.460897435897435e-10
# Within the function to 9 the amplitude 0.6460897435897435
# Running simulation for 2.0 s
# Running Neuron simulator 2000 ms, with dt=0.025
# 1% done. Elapsed: 4.2 s, estimated time left: 419.7 s
# 2% done. Elapsed: 8.6 s, estimated time left: 422.8 s
# 3% done. Elapsed: 13.4 s, estimated time left: 433.9 s
# 4% done. Elapsed: 18.1 s, estimated time left: 435.0 s
# 5% done. Elapsed: 23.3 s, estimated time left: 442.7 s
# 6% done. Elapsed: 28.4 s, estimated time left: 444.7 s
# 7% done. Elapsed: 33.6 s, estimated time left: 446.1 s
# 8% done. Elapsed: 38.7 s, estimated time left: 445.2 s
# 9% done. Elapsed: 43.8 s, estimated time left: 442.7 s
# 10% done. Elapsed: 48.8 s, estimated time left: 439.6 s
# 11% done. Elapsed: 53.9 s, estimated time left: 436.5 s
# 12% done. Elapsed: 59.0 s, estimated time left: 433.0 s
# 13% done. Elapsed: 64.4 s, estimated time left: 431.2 s
# 14% done. Elapsed: 69.7 s, estimated time left: 428.3 s
# 15% done. Elapsed: 75.1 s, estimated time left: 425.7 s
# 16% done. Elapsed: 80.4 s, estimated time left: 422.0 s
# 17% done. Elapsed: 85.7 s, estimated time left: 418.6 s
# 18% done. Elapsed: 91.0 s, estimated time left: 414.3 s
# 19% done. Elapsed: 96.1 s, estimated time left: 409.8 s
# 20% done. Elapsed: 101.3 s, estimated time left: 405.3 s
# 21% done. Elapsed: 106.7 s, estimated time left: 401.3 s
# 22% done. Elapsed: 112.0 s, estimated time left: 397.1 s
# 23% done. Elapsed: 117.2 s, estimated time left: 392.4 s
# 24% done. Elapsed: 122.4 s, estimated time left: 387.7 s
# 25% done. Elapsed: 127.8 s, estimated time left: 383.4 s
# 26% done. Elapsed: 133.1 s, estimated time left: 378.7 s
# 27% done. Elapsed: 138.5 s, estimated time left: 374.6 s
# 28% done. Elapsed: 144.0 s, estimated time left: 370.3 s
# 29% done. Elapsed: 149.2 s, estimated time left: 365.4 s
# 30% done. Elapsed: 154.5 s, estimated time left: 360.4 s
# 31% done. Elapsed: 159.8 s, estimated time left: 355.6 s
# 32% done. Elapsed: 165.0 s, estimated time left: 350.7 s
# 33% done. Elapsed: 170.4 s, estimated time left: 345.9 s
# 34% done. Elapsed: 175.6 s, estimated time left: 340.9 s
# 35% done. Elapsed: 180.9 s, estimated time left: 336.0 s
# 36% done. Elapsed: 186.4 s, estimated time left: 331.3 s
# 37% done. Elapsed: 194.0 s, estimated time left: 330.4 s
# 38% done. Elapsed: 201.4 s, estimated time left: 328.6 s
# 39% done. Elapsed: 209.0 s, estimated time left: 327.0 s
# 40% done. Elapsed: 214.5 s, estimated time left: 321.7 s
# 41% done. Elapsed: 219.7 s, estimated time left: 316.2 s
# 42% done. Elapsed: 225.1 s, estimated time left: 310.8 s
# 43% done. Elapsed: 230.6 s, estimated time left: 305.7 s
# 44% done. Elapsed: 236.1 s, estimated time left: 300.4 s
# 45% done. Elapsed: 241.5 s, estimated time left: 295.1 s
# 46% done. Elapsed: 247.3 s, estimated time left: 290.3 s
# 47% done. Elapsed: 253.0 s, estimated time left: 285.3 s
# 48% done. Elapsed: 259.1 s, estimated time left: 280.6 s
# 49% done. Elapsed: 264.9 s, estimated time left: 275.7 s
# 50% done. Elapsed: 270.5 s, estimated time left: 270.5 s
# 51% done. Elapsed: 276.2 s, estimated time left: 265.4 s
# 52% done. Elapsed: 281.8 s, estimated time left: 260.1 s
# 53% done. Elapsed: 287.8 s, estimated time left: 255.2 s
# 54% done. Elapsed: 293.6 s, estimated time left: 250.1 s
# 55% done. Elapsed: 299.4 s, estimated time left: 245.0 s
# 56% done. Elapsed: 305.2 s, estimated time left: 239.8 s
# 57% done. Elapsed: 310.7 s, estimated time left: 234.4 s
# 58% done. Elapsed: 316.4 s, estimated time left: 229.1 s
# 59% done. Elapsed: 322.0 s, estimated time left: 223.8 s
# 60% done. Elapsed: 327.7 s, estimated time left: 218.5 s
# 61% done. Elapsed: 333.6 s, estimated time left: 213.3 s
# 62% done. Elapsed: 339.5 s, estimated time left: 208.1 s
# 63% done. Elapsed: 344.8 s, estimated time left: 202.5 s
# 64% done. Elapsed: 350.9 s, estimated time left: 197.4 s
# 65% done. Elapsed: 356.3 s, estimated time left: 191.9 s
# 66% done. Elapsed: 361.8 s, estimated time left: 186.4 s
# 67% done. Elapsed: 367.1 s, estimated time left: 180.8 s
# 68% done. Elapsed: 372.4 s, estimated time left: 175.3 s
# 69% done. Elapsed: 377.8 s, estimated time left: 169.7 s
# 70% done. Elapsed: 383.5 s, estimated time left: 164.3 s
# 71% done. Elapsed: 388.8 s, estimated time left: 158.8 s
# 72% done. Elapsed: 394.1 s, estimated time left: 153.3 s
# 73% done. Elapsed: 399.6 s, estimated time left: 147.8 s
# 74% done. Elapsed: 405.0 s, estimated time left: 142.3 s
# 75% done. Elapsed: 410.4 s, estimated time left: 136.8 s
# 76% done. Elapsed: 415.9 s, estimated time left: 131.3 s
# 77% done. Elapsed: 421.3 s, estimated time left: 125.9 s
# 78% done. Elapsed: 426.8 s, estimated time left: 120.4 s
# 79% done. Elapsed: 433.2 s, estimated time left: 115.2 s
# 80% done. Elapsed: 438.6 s, estimated time left: 109.6 s
# 81% done. Elapsed: 443.9 s, estimated time left: 104.1 s
# 82% done. Elapsed: 449.3 s, estimated time left: 98.6 s
# 83% done. Elapsed: 454.7 s, estimated time left: 93.1 s
# 84% done. Elapsed: 460.1 s, estimated time left: 87.6 s
# 85% done. Elapsed: 466.0 s, estimated time left: 82.2 s
# 86% done. Elapsed: 471.3 s, estimated time left: 76.7 s
# 87% done. Elapsed: 476.8 s, estimated time left: 71.2 s
# 88% done. Elapsed: 482.4 s, estimated time left: 65.8 s
# 89% done. Elapsed: 488.0 s, estimated time left: 60.3 s
# 90% done. Elapsed: 493.6 s, estimated time left: 54.8 s
# 91% done. Elapsed: 499.2 s, estimated time left: 49.4 s
# 92% done. Elapsed: 504.8 s, estimated time left: 43.9 s
# 93% done. Elapsed: 510.4 s, estimated time left: 38.4 s
# 94% done. Elapsed: 515.9 s, estimated time left: 32.9 s
# 95% done. Elapsed: 521.5 s, estimated time left: 27.4 s
# 96% done. Elapsed: 526.9 s, estimated time left: 22.0 s
# 97% done. Elapsed: 532.5 s, estimated time left: 16.5 s
# 98% done. Elapsed: 538.0 s, estimated time left: 11.0 s
# 99% done. Elapsed: 543.4 s, estimated time left: 5.5 s
# Neuron simulation finished
# Simulation done.
# Simulation run time: 548.8 s
# Writing network output to networks/dopamine_validation/simulation/test_control.hdf5
# CHeck why not able to save...
# Using sample dt = 0.0005 (sample step size 20)
# Worker 1/1 writing data to networks/dopamine_validation/simulation/test_control.hdf5
