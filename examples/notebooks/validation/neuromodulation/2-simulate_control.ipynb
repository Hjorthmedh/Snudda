# %%
from neuromodulation_sim import *

# %%
network_path = os.path.join("networks/dopamine_validation")

# %%
# If the BasalGangliaData directory exists, then use that for our data
BG_path = os.path.join("..", "..","..","..","..", "BasalGangliaData", "data")
if os.path.exists(BG_path):
    os.environ["SNUDDA_DATA"] = BG_path
    print(f"Setting SNUDDA_DATA to {BG_path}")
else:
    print(f"SNUDDA_DATA environment variable not changed (may be empty)")
# Out:
# Setting SNUDDA_DATA to ../../../../../BasalGangliaData/data

# %%
simulate_control(network_path=network_path)
# Out:
# Reading SNUDDA_DATA=../../../../../BasalGangliaData/data from networks/dopamine_validation/network-config.json
# Warning: No external synaptic input file given!
# Using network_file: networks/dopamine_validation/network-synapses.hdf5
# Using input_file: None
# Using output_file: networks/dopamine_validation/simulation/test_control.hdf5
# Using logFile: networks/dopamine_validation/log/network-simulation-log.txt-0
# Creating save/traces (on master node 0)
# Worker 0 : Loading network from networks/dopamine_validation/network-synapses.hdf5
# Loading 10 neurons with 82 synapses and 0 gap junctions
# Loading config file networks/dopamine_validation/network-config.json
#  Using neuromodulation module in Snudda
# 0 : Memory status: 46% free
# Distributing neurons.
# Setup neurons
# Empty modFile field for ChIN -> dSPN synapses. This channel is IGNORED.
# Empty modFile field for ChIN -> iSPN synapses. This channel is IGNORED.
# Node 0 - cell 0 dSPN_1
# /home/hjorth/.local/lib/python3.9/site-packages/bluepyopt/ephys/simulators.py:83: UserWarning: Unable to find Neuron hoc shared library in /usr/local/lib/python/neuron, not disabling banner
#   warnings.warn('Unable to find Neuron hoc shared library in %s, '
# Neuron dSPN_1 (0) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 1 dSPN_0
# Neuron dSPN_0 (1) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 2 dSPN_3
# Neuron dSPN_3 (2) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 3 dSPN_3
# Neuron dSPN_3 (3) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 4 dSPN_2
# Neuron dSPN_2 (4) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 5 dSPN_2
# Neuron dSPN_2 (5) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 6 dSPN_1
# Neuron dSPN_1 (6) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 7 dSPN_0
# Neuron dSPN_0 (7) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 8 dSPN_1
# Neuron dSPN_1 (8) resting voltage = -87.00000000000001
# !!! Popping extra segment from neuron -- temp fix!
# Node 0 - cell 9 dSPN_3
# Neuron dSPN_3 (9) resting voltage = -86.0
# !!! Popping extra segment from neuron -- temp fix!
# 0 : Memory status: 45% free
# Adding to 0 the amplitude 6.092461538461538e-10
# Within the function to 0 the amplitude 0.6092461538461539
# Adding to 1 the amplitude 4.799510204081633e-10
# Within the function to 1 the amplitude 0.47995102040816323
# Adding to 2 the amplitude 5.871153846153846e-10
# Within the function to 2 the amplitude 0.5871153846153846
# Adding to 3 the amplitude 5.871153846153846e-10
# Within the function to 3 the amplitude 0.5871153846153846
# Adding to 4 the amplitude 3.661102564102564e-10
# Within the function to 4 the amplitude 0.3661102564102564
# Adding to 5 the amplitude 3.8662307692307695e-10
# Within the function to 5 the amplitude 0.38662307692307696
# Adding to 6 the amplitude 5.118102564102564e-10
# Within the function to 6 the amplitude 0.5118102564102565
# Adding to 7 the amplitude 5.003591836734693e-10
# Within the function to 7 the amplitude 0.5003591836734693
# Adding to 8 the amplitude 5.848871794871795e-10
# Within the function to 8 the amplitude 0.5848871794871795
# Adding to 9 the amplitude 6.460897435897435e-10
# Within the function to 9 the amplitude 0.6460897435897435
# Running simulation for 2.0 s
# Running Neuron simulator 2000 ms, with dt=0.025
# 52% done. Elapsed: 192.8 s, estimated time left: 178.0 s
# 53% done. Elapsed: 196.6 s, estimated time left: 174.3 s
# 54% done. Elapsed: 200.1 s, estimated time left: 170.5 s
# 55% done. Elapsed: 203.8 s, estimated time left: 166.7 s
# 56% done. Elapsed: 207.4 s, estimated time left: 163.0 s
# 57% done. Elapsed: 211.1 s, estimated time left: 159.2 s
# 58% done. Elapsed: 214.6 s, estimated time left: 155.4 s
# 59% done. Elapsed: 218.2 s, estimated time left: 151.6 s
# 60% done. Elapsed: 221.9 s, estimated time left: 147.9 s
# 61% done. Elapsed: 225.5 s, estimated time left: 144.1 s
# 62% done. Elapsed: 229.1 s, estimated time left: 140.4 s
# 63% done. Elapsed: 233.0 s, estimated time left: 136.9 s
# 64% done. Elapsed: 236.8 s, estimated time left: 133.2 s
# 65% done. Elapsed: 240.4 s, estimated time left: 129.4 s
# 66% done. Elapsed: 244.1 s, estimated time left: 125.7 s
# 67% done. Elapsed: 247.7 s, estimated time left: 122.0 s
# 68% done. Elapsed: 251.4 s, estimated time left: 118.3 s
# 69% done. Elapsed: 255.0 s, estimated time left: 114.6 s
# 70% done. Elapsed: 258.7 s, estimated time left: 110.9 s
# 71% done. Elapsed: 262.3 s, estimated time left: 107.1 s
# 72% done. Elapsed: 266.0 s, estimated time left: 103.4 s
# 73% done. Elapsed: 269.6 s, estimated time left: 99.7 s
# 74% done. Elapsed: 273.1 s, estimated time left: 96.0 s
# 75% done. Elapsed: 276.8 s, estimated time left: 92.3 s
# 76% done. Elapsed: 280.5 s, estimated time left: 88.6 s
# 77% done. Elapsed: 284.2 s, estimated time left: 84.9 s
# 78% done. Elapsed: 287.8 s, estimated time left: 81.2 s
# 79% done. Elapsed: 291.5 s, estimated time left: 77.5 s
# 80% done. Elapsed: 295.3 s, estimated time left: 73.8 s
# 81% done. Elapsed: 299.1 s, estimated time left: 70.2 s
# 82% done. Elapsed: 303.0 s, estimated time left: 66.5 s
# 83% done. Elapsed: 306.7 s, estimated time left: 62.8 s
# 84% done. Elapsed: 310.5 s, estimated time left: 59.1 s
# 85% done. Elapsed: 314.3 s, estimated time left: 55.5 s
# 86% done. Elapsed: 318.1 s, estimated time left: 51.8 s
# 87% done. Elapsed: 322.0 s, estimated time left: 48.1 s
# 88% done. Elapsed: 325.8 s, estimated time left: 44.4 s
# 89% done. Elapsed: 329.5 s, estimated time left: 40.7 s
# 90% done. Elapsed: 333.2 s, estimated time left: 37.0 s
# 91% done. Elapsed: 336.9 s, estimated time left: 33.3 s
# 92% done. Elapsed: 340.7 s, estimated time left: 29.6 s
# 93% done. Elapsed: 344.5 s, estimated time left: 25.9 s
# 94% done. Elapsed: 348.2 s, estimated time left: 22.2 s
# 95% done. Elapsed: 352.1 s, estimated time left: 18.5 s
# 96% done. Elapsed: 355.9 s, estimated time left: 14.8 s
# 97% done. Elapsed: 359.8 s, estimated time left: 11.1 s
# 98% done. Elapsed: 363.6 s, estimated time left: 7.4 s
# 99% done. Elapsed: 367.3 s, estimated time left: 3.7 s
# Neuron simulation finished
# Simulation done.
# Simulation run time: 371.0 s
# Writing network output to networks/dopamine_validation/simulation/test_control.hdf5
# Using sample dt = 0.0005 (sample step size 20)
# Worker 1/1 writing data to networks/dopamine_validation/simulation/test_control.hdf5
