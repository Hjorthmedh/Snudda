# %%
import os
import numpy as np

network_path = "forKadri-FS1050-1"
input_name = "SfN2022-forKadri-oscillating-20Hz-ramp-up-background"
sim_file_gj = os.path.join(network_path, "simulation", f"output-GJ-{input_name}.hdf5")
sim_file_nogj = os.path.join(network_path, "simulation", f"output-noGJ-{input_name}.hdf5")
fig_path = os.path.join(network_path, "figures")
sl = None
sls_gj = None
sls_nogj = None

# %%
from snudda.utils import SnuddaLoad
from snudda.utils import SnuddaLoadNetworkSimulation

sl = SnuddaLoad(network_path)
sls_gj = SnuddaLoadNetworkSimulation(network_simulation_output_file=sim_file_gj)
sls_nogj = SnuddaLoadNetworkSimulation(network_simulation_output_file=sim_file_nogj)
# Out:
# Loading 1050 neurons with 20763 synapses and 10598 gap junctions
# Loading forKadri-FS1050-1/simulation/output-GJ-SfN2022-forKadri-oscillating-20Hz-ramp-up-background.hdf5
# WARNING. Depolarisation block in neuron - neuron_id: (name, parameter_key, morphology_key):
# 12: (FS_0, pb1ef6b01, mb1b67bcc)
# 18: (FS_0, p4feff98b, m86da4874)
# 22: (FS_0, pb1ef6b01, m15ae4048)
# 26: (FS_1, p6eb0c221, meffc0dfa)
# 40: (FS_3, p92705ff4, m86da4874)
# 41: (FS_0, p4feff98b, m4cd420e2)
# 44: (FS_0, p59a48310, m4cd420e2)
# 47: (FS_0, pb1ef6b01, me486b19e)
# 49: (FS_1, p31916918, mf0a83676)
# 58: (FS_1, p6eb0c221, ma88f99b9)
# 77: (FS_0, pb1ef6b01, m15ae4048)
# 81: (FS_1, pf86c86e4, m9d1605c7)
# 82: (FS_3, p92705ff4, me486b19e)
# 83: (FS_0, p59a48310, m86da4874)
# 98: (FS_3, p92705ff4, m4fdebda2)
# 100: (FS_1, p31916918, ma88f99b9)
# 101: (FS_0, pb1ef6b01, m15ae4048)
# 102: (FS_1, pf9439e45, m9d1605c7)
# 107: (FS_1, p31916918, meffc0dfa)
# 116: (FS_0, pb1ef6b01, mb1b67bcc)
# 117: (FS_0, p4feff98b, m4cd420e2)
# 118: (FS_0, p4feff98b, m4cd420e2)
# 124: (FS_0, pb1ef6b01, m15ae4048)
# 128: (FS_3, p92705ff4, m86da4874)
# 129: (FS_0, pb1ef6b01, m86da4874)
# 131: (FS_0, p59a48310, m4cd420e2)
# 143: (FS_0, p4feff98b, m9175e580)
# 144: (FS_1, pf86c86e4, ma88f99b9)
# 159: (FS_0, pb1ef6b01, m15ae4048)
# 160: (FS_1, p31916918, m868d56db)
# 166: (FS_1, pf9439e45, mf0a83676)
# 174: (FS_1, p6eb0c221, mf0a83676)
# 183: (FS_0, pb1ef6b01, m86da4874)
# 187: (FS_1, p6eb0c221, macdedfff)
# 196: (FS_0, p4feff98b, m86da4874)
# 198: (FS_1, pf86c86e4, ma88f99b9)
# 200: (FS_1, pf86c86e4, m868d56db)
# 202: (FS_0, p4feff98b, m86da4874)
# 204: (FS_1, p6eb0c221, m868d56db)
# 207: (FS_3, p92705ff4, m9175e580)
# 211: (FS_3, p92705ff4, m86da4874)
# 217: (FS_1, p31916918, m868d56db)
# 225: (FS_1, pf86c86e4, macdedfff)
# 226: (FS_0, p59a48310, m86da4874)
# 231: (FS_1, p31916918, m9d1605c7)
# 233: (FS_0, p59a48310, m86da4874)
# 243: (FS_1, p6eb0c221, mf0a83676)
# 247: (FS_2, p71c7354b, m2353c9ea)
# 248: (FS_0, p59a48310, m4fdebda2)
# 259: (FS_3, p92705ff4, m4cd420e2)
# 260: (FS_0, p4feff98b, m86da4874)
# 262: (FS_1, p31916918, mf0a83676)
# 271: (FS_0, pb1ef6b01, m4cd420e2)
# 278: (FS_0, p4feff98b, m86da4874)
# 297: (FS_0, pb1ef6b01, mb1b67bcc)
# 300: (FS_1, pf86c86e4, mf0a83676)
# 301: (FS_0, p4feff98b, m4cd420e2)
# 302: (FS_1, p31916918, m9d1605c7)
# 303: (FS_1, p31916918, m9d1605c7)
# 310: (FS_0, pb1ef6b01, mb1b67bcc)
# 317: (FS_1, p31916918, mf0a83676)
# 326: (FS_0, p4feff98b, m86da4874)
# 327: (FS_0, pb1ef6b01, me486b19e)
# 332: (FS_0, p59a48310, m86da4874)
# 336: (FS_1, p6eb0c221, mf0a83676)
# 356: (FS_1, pf86c86e4, m868d56db)
# 358: (FS_0, pb1ef6b01, m86da4874)
# 370: (FS_0, p59a48310, m4fdebda2)
# 371: (FS_0, pb1ef6b01, m86da4874)
# 372: (FS_1, pf9439e45, ma88f99b9)
# 390: (FS_0, pb1ef6b01, m15ae4048)
# 395: (FS_0, p59a48310, m4cd420e2)
# 402: (FS_0, p59a48310, m86da4874)
# 409: (FS_1, p6eb0c221, m2a6ab0d6)
# 417: (FS_0, p59a48310, m86da4874)
# 418: (FS_1, p31916918, meffc0dfa)
# 426: (FS_0, p4feff98b, me486b19e)
# 431: (FS_1, pf86c86e4, meffc0dfa)
# 435: (FS_1, pf86c86e4, m9d1605c7)
# 451: (FS_0, p59a48310, m15ae4048)
# 452: (FS_1, p6eb0c221, m868d56db)
# 454: (FS_1, p31916918, m48f576bb)
# 457: (FS_2, p563801bd, mc8ef3a88)
# 467: (FS_0, p59a48310, m4cd420e2)
# 469: (FS_1, p6eb0c221, m48f576bb)
# 478: (FS_2, p71c7354b, mf4ff6845)
# 479: (FS_0, pb1ef6b01, m15ae4048)
# 495: (FS_1, p6eb0c221, m868d56db)
# 501: (FS_1, pf86c86e4, mf0a83676)
# 505: (FS_0, p59a48310, m4cd420e2)
# 508: (FS_2, p71c7354b, m7fb43a9c)
# 510: (FS_0, pb1ef6b01, m4cd420e2)
# 519: (FS_0, p4feff98b, me486b19e)
# 520: (FS_1, p6eb0c221, m9d1605c7)
# 523: (FS_0, p4feff98b, m4fdebda2)
# 524: (FS_0, p4feff98b, m9175e580)
# 525: (FS_1, p31916918, m9d1605c7)
# 533: (FS_0, p4feff98b, m86da4874)
# 540: (FS_0, p59a48310, m9175e580)
# 543: (FS_1, pf9439e45, m48f576bb)
# 548: (FS_3, p92705ff4, m4fdebda2)
# 555: (FS_0, p4feff98b, m9175e580)
# 557: (FS_3, p92705ff4, m86da4874)
# 558: (FS_0, p4feff98b, me486b19e)
# 562: (FS_0, p59a48310, m15ae4048)
# 566: (FS_0, p59a48310, m15ae4048)
# 579: (FS_0, p4feff98b, m86da4874)
# 583: (FS_0, p59a48310, m4cd420e2)
# 585: (FS_1, pf86c86e4, m9d1605c7)
# 588: (FS_1, p31916918, ma88f99b9)
# 589: (FS_1, p31916918, m868d56db)
# 590: (FS_0, p59a48310, m15ae4048)
# 591: (FS_0, p4feff98b, me486b19e)
# 594: (FS_0, pb1ef6b01, m4cd420e2)
# 596: (FS_1, p31916918, mf0a83676)
# 600: (FS_0, p59a48310, m86da4874)
# 602: (FS_3, p92705ff4, m86da4874)
# 605: (FS_1, pf9439e45, mf0a83676)
# 608: (FS_0, pb1ef6b01, mb1b67bcc)
# 619: (FS_0, pb1ef6b01, m4cd420e2)
# 627: (FS_0, p4feff98b, m4cd420e2)
# 628: (FS_1, p31916918, macdedfff)
# 630: (FS_0, p59a48310, m4cd420e2)
# 633: (FS_0, p4feff98b, m86da4874)
# 637: (FS_3, p92705ff4, m4cd420e2)
# 638: (FS_0, pb1ef6b01, mb1b67bcc)
# 640: (FS_3, p92705ff4, m4cd420e2)
# 643: (FS_3, p92705ff4, m86da4874)
# 645: (FS_3, p92705ff4, me486b19e)
# 651: (FS_1, p6eb0c221, m48f576bb)
# 666: (FS_0, pb1ef6b01, m9175e580)
# 677: (FS_1, p31916918, meffc0dfa)
# 678: (FS_1, pf86c86e4, meffc0dfa)
# 683: (FS_1, p31916918, m9d1605c7)
# 686: (FS_1, p6eb0c221, m868d56db)
# 694: (FS_0, p59a48310, m4fdebda2)
# 698: (FS_1, pf86c86e4, m9d1605c7)
# 700: (FS_0, p59a48310, m4cd420e2)
# 704: (FS_1, p31916918, ma88f99b9)
# 707: (FS_1, pf86c86e4, ma88f99b9)
# 714: (FS_3, p92705ff4, m15ae4048)
# 716: (FS_1, p6eb0c221, macdedfff)
# 722: (FS_0, p59a48310, m9175e580)
# 732: (FS_1, p6eb0c221, ma88f99b9)
# 739: (FS_0, p59a48310, m4fdebda2)
# 745: (FS_0, p59a48310, me486b19e)
# 746: (FS_0, p59a48310, m15ae4048)
# 752: (FS_0, pb1ef6b01, m4cd420e2)
# 756: (FS_0, p59a48310, m15ae4048)
# 757: (FS_0, p59a48310, m86da4874)
# 758: (FS_0, p59a48310, m15ae4048)
# 759: (FS_1, pf9439e45, m2a6ab0d6)
# 764: (FS_0, p4feff98b, m4fdebda2)
# 782: (FS_0, pb1ef6b01, m15ae4048)
# 784: (FS_0, p4feff98b, m86da4874)
# 787: (FS_0, p4feff98b, m86da4874)
# 789: (FS_1, p31916918, m9d1605c7)
# 796: (FS_0, p59a48310, m4cd420e2)
# 797: (FS_0, p4feff98b, m86da4874)
# 798: (FS_0, pb1ef6b01, me486b19e)
# 799: (FS_1, pf86c86e4, m2a6ab0d6)
# 810: (FS_0, pb1ef6b01, mb1b67bcc)
# 813: (FS_0, p59a48310, me486b19e)
# 815: (FS_0, p59a48310, m9175e580)
# 816: (FS_1, p6eb0c221, m48f576bb)
# 820: (FS_0, pb1ef6b01, m15ae4048)
# 823: (FS_1, p6eb0c221, meffc0dfa)
# 827: (FS_0, p59a48310, me486b19e)
# 833: (FS_0, pb1ef6b01, m86da4874)
# 840: (FS_0, p4feff98b, me486b19e)
# 847: (FS_0, p4feff98b, m4fdebda2)
# 848: (FS_1, pf86c86e4, m9d1605c7)
# 853: (FS_0, p4feff98b, m4cd420e2)
# 854: (FS_0, pb1ef6b01, mb1b67bcc)
# 858: (FS_1, pf86c86e4, m868d56db)
# 859: (FS_1, pf86c86e4, mf0a83676)
# 867: (FS_0, p4feff98b, m86da4874)
# 868: (FS_0, p59a48310, m15ae4048)
# 877: (FS_0, p59a48310, m15ae4048)
# 883: (FS_0, p4feff98b, m4cd420e2)
# 885: (FS_1, pf9439e45, m48f576bb)
# 893: (FS_0, pb1ef6b01, m86da4874)
# 902: (FS_0, p59a48310, m9175e580)
# 903: (FS_0, p4feff98b, m4fdebda2)
# 910: (FS_0, pb1ef6b01, m4fdebda2)
# 913: (FS_0, p59a48310, m15ae4048)
# 920: (FS_1, pf9439e45, m9d1605c7)
# 921: (FS_1, p31916918, m9d1605c7)
# 934: (FS_1, p31916918, ma88f99b9)
# 936: (FS_3, p92705ff4, m86da4874)
# 940: (FS_0, pb1ef6b01, m15ae4048)
# 943: (FS_0, p4feff98b, me486b19e)
# 953: (FS_0, pb1ef6b01, me486b19e)
# 955: (FS_1, p6eb0c221, ma88f99b9)
# 962: (FS_1, pf86c86e4, m2a6ab0d6)
# 964: (FS_1, p6eb0c221, meffc0dfa)
# 967: (FS_0, p4feff98b, me486b19e)
# 968: (FS_0, p4feff98b, me486b19e)
# 970: (FS_0, p59a48310, m4cd420e2)
# 994: (FS_0, p4feff98b, m4cd420e2)
# 999: (FS_1, p31916918, mf0a83676)
# 1010: (FS_1, p31916918, m9d1605c7)
# 1013: (FS_1, pf9439e45, ma88f99b9)
# 1017: (FS_1, pf9439e45, ma88f99b9)
# 1022: (FS_0, pb1ef6b01, mb1b67bcc)
# 1023: (FS_1, p31916918, mf0a83676)
# 1026: (FS_0, p4feff98b, m86da4874)
# 1033: (FS_0, p4feff98b, me486b19e)
# 1043: (FS_3, p92705ff4, m86da4874)
# Loading forKadri-FS1050-1/simulation/output-noGJ-SfN2022-forKadri-oscillating-20Hz-ramp-up-background.hdf5
# WARNING. Depolarisation block in neuron - neuron_id: (name, parameter_key, morphology_key):
# 22: (FS_0, pb1ef6b01, m15ae4048)
# 49: (FS_1, p31916918, mf0a83676)
# 77: (FS_0, pb1ef6b01, m15ae4048)
# 98: (FS_3, p92705ff4, m4fdebda2)
# 100: (FS_1, p31916918, ma88f99b9)
# 109: (FS_0, p4feff98b, me486b19e)
# 116: (FS_0, pb1ef6b01, mb1b67bcc)
# 143: (FS_0, p4feff98b, m9175e580)
# 159: (FS_0, pb1ef6b01, m15ae4048)
# 297: (FS_0, pb1ef6b01, mb1b67bcc)
# 303: (FS_1, p31916918, m9d1605c7)
# 417: (FS_0, p59a48310, m86da4874)
# 418: (FS_1, p31916918, meffc0dfa)
# 451: (FS_0, p59a48310, m15ae4048)
# 469: (FS_1, p6eb0c221, m48f576bb)
# 533: (FS_0, p4feff98b, m86da4874)
# 557: (FS_3, p92705ff4, m86da4874)
# 588: (FS_1, p31916918, ma88f99b9)
# 590: (FS_0, p59a48310, m15ae4048)
# 591: (FS_0, p4feff98b, me486b19e)
# 608: (FS_0, pb1ef6b01, mb1b67bcc)
# 627: (FS_0, p4feff98b, m4cd420e2)
# 643: (FS_3, p92705ff4, m86da4874)
# 657: (FS_1, pf9439e45, m48f576bb)
# 716: (FS_1, p6eb0c221, macdedfff)
# 732: (FS_1, p6eb0c221, ma88f99b9)
# 739: (FS_0, p59a48310, m4fdebda2)
# 752: (FS_0, pb1ef6b01, m4cd420e2)
# 784: (FS_0, p4feff98b, m86da4874)
# 788: (FS_0, p59a48310, m4fdebda2)
# 797: (FS_0, p4feff98b, m86da4874)
# 844: (FS_0, p4feff98b, m4cd420e2)
# 867: (FS_0, p4feff98b, m86da4874)
# 937: (FS_3, p92705ff4, m86da4874)
# 944: (FS_0, p4feff98b, m86da4874)
# 1017: (FS_1, pf9439e45, ma88f99b9)
# 1022: (FS_0, pb1ef6b01, mb1b67bcc)

# %%
from snudda.plotting import PlotInput
input_file = os.path.join(network_path, f"{input_name}.hdf5")
spi = PlotInput(input_file)
# Out:
# Loading 1050 neurons with 20763 synapses and 10598 gap junctions

# %%
spi.plot_input(num_neurons=5, neuron_type="FS", fig_size=(15,5))

# %%
from snudda.plotting import SnuddaPlotSpikeRaster2
fig_file_1 = f"spike-raster-osc-GJ-{input_name}.png"
fig_file_2 = f"spike-histogram-osc-GJ-{input_name}.png"
spr = SnuddaPlotSpikeRaster2(network_path=network_path, simulation_file=sim_file_gj, figure_path=fig_path,
                             snudda_load=sl, snudda_simulation_load=sls_gj)

# %%
# spr.plot_spike_raster(fig_file=fig_file_1)

# %%
spr.plot_spike_histogram(fig_file=fig_file_2, bin_size=10e-3)
# Out:
# <AxesSubplot:xlabel='Time (s)', ylabel='Frequency (Hz)'>

# %%
time_range = (6,8)
fig_file_3 = f"spike-period-histogram-osc-GJ-{input_name}-range-{time_range[0]}-{time_range[1]}.png"

spr.plot_period_histogram_mod(neuron_id=None, period=1/20, time_range=time_range, fig_file=fig_file_3)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Writing figure to forKadri-FS1050-1/figures/spike-period-histogram-osc-GJ-SfN2022-forKadri-oscillating-20Hz-ramp-up-background-range-6-8.png
# (array([7112, 8025, 8290, 7981, 7830, 6873, 6582, 6054, 6127, 6322]),
#  array([2.49999202e-05, 5.02249992e-03, 1.00199999e-02, 1.50174999e-02,
#         2.00149999e-02, 2.50124999e-02, 3.00099999e-02, 3.50074999e-02,
#         4.00049999e-02, 4.50024999e-02, 4.99999999e-02]))

# %%
from snudda.plotting import SnuddaPlotSpikeRaster2
fig_file_1b = f"spike-raster-osc-noGJ-{input_name}.png"
fig_file_2b = f"spike-histogram-osc-noGJ-{input_name}.png"
spr2 = SnuddaPlotSpikeRaster2(network_path=network_path, simulation_file=sim_file_nogj, figure_path=fig_path,
                             snudda_load=sl, snudda_simulation_load=sls_nogj)

# %%
# spr2.plot_spike_raster(fig_file=fig_file_1b)

# %%
spr2.plot_spike_histogram(fig_file=fig_file_2b, bin_size=0.010)
# Out:
# <AxesSubplot:xlabel='Time (s)', ylabel='Frequency (Hz)'>

# %%
time_range = (6,8)
fig_file_3b = f"spike-period-histogram-osc-noGJ-{input_name}-range-{time_range[0]}-{time_range[1]}.png"

spr2.plot_period_histogram_mod(neuron_id=None, period=1/20, time_range=time_range, fig_file=fig_file_3b)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Writing figure to forKadri-FS1050-1/figures/spike-period-histogram-osc-noGJ-SfN2022-forKadri-oscillating-20Hz-ramp-up-background-range-6-8.png
# (array([5506, 6071, 6625, 6489, 6434, 5836, 5272, 4953, 4919, 5235]),
#  array([2.49999195e-05, 5.02249992e-03, 1.00199999e-02, 1.50174999e-02,
#         2.00149999e-02, 2.50124999e-02, 3.00099999e-02, 3.50074999e-02,
#         4.00049999e-02, 4.50024999e-02, 4.99999999e-02]))

# %%
from snudda.plotting.plot_cross_correlogram import PlotCrossCorrelogram
pcc1 = PlotCrossCorrelogram(sim_file_gj, snudda_simulation_load=sls_gj)
# Out:
# Loading forKadri-FS1050-1/simulation/output-GJ-SfN2022-forKadri-oscillating-20Hz-ramp-up-background.hdf5
# WARNING. Depolarisation block in neuron - neuron_id: (name, parameter_key, morphology_key):
# 12: (FS_0, pb1ef6b01, mb1b67bcc)
# 18: (FS_0, p4feff98b, m86da4874)
# 22: (FS_0, pb1ef6b01, m15ae4048)
# 26: (FS_1, p6eb0c221, meffc0dfa)
# 40: (FS_3, p92705ff4, m86da4874)
# 41: (FS_0, p4feff98b, m4cd420e2)
# 44: (FS_0, p59a48310, m4cd420e2)
# 47: (FS_0, pb1ef6b01, me486b19e)
# 49: (FS_1, p31916918, mf0a83676)
# 58: (FS_1, p6eb0c221, ma88f99b9)
# 77: (FS_0, pb1ef6b01, m15ae4048)
# 81: (FS_1, pf86c86e4, m9d1605c7)
# 82: (FS_3, p92705ff4, me486b19e)
# 83: (FS_0, p59a48310, m86da4874)
# 98: (FS_3, p92705ff4, m4fdebda2)
# 100: (FS_1, p31916918, ma88f99b9)
# 101: (FS_0, pb1ef6b01, m15ae4048)
# 102: (FS_1, pf9439e45, m9d1605c7)
# 107: (FS_1, p31916918, meffc0dfa)
# 116: (FS_0, pb1ef6b01, mb1b67bcc)
# 117: (FS_0, p4feff98b, m4cd420e2)
# 118: (FS_0, p4feff98b, m4cd420e2)
# 124: (FS_0, pb1ef6b01, m15ae4048)
# 128: (FS_3, p92705ff4, m86da4874)
# 129: (FS_0, pb1ef6b01, m86da4874)
# 131: (FS_0, p59a48310, m4cd420e2)
# 143: (FS_0, p4feff98b, m9175e580)
# 144: (FS_1, pf86c86e4, ma88f99b9)
# 159: (FS_0, pb1ef6b01, m15ae4048)
# 160: (FS_1, p31916918, m868d56db)
# 166: (FS_1, pf9439e45, mf0a83676)
# 174: (FS_1, p6eb0c221, mf0a83676)
# 183: (FS_0, pb1ef6b01, m86da4874)
# 187: (FS_1, p6eb0c221, macdedfff)
# 196: (FS_0, p4feff98b, m86da4874)
# 198: (FS_1, pf86c86e4, ma88f99b9)
# 200: (FS_1, pf86c86e4, m868d56db)
# 202: (FS_0, p4feff98b, m86da4874)
# 204: (FS_1, p6eb0c221, m868d56db)
# 207: (FS_3, p92705ff4, m9175e580)
# 211: (FS_3, p92705ff4, m86da4874)
# 217: (FS_1, p31916918, m868d56db)
# 225: (FS_1, pf86c86e4, macdedfff)
# 226: (FS_0, p59a48310, m86da4874)
# 231: (FS_1, p31916918, m9d1605c7)
# 233: (FS_0, p59a48310, m86da4874)
# 243: (FS_1, p6eb0c221, mf0a83676)
# 247: (FS_2, p71c7354b, m2353c9ea)
# 248: (FS_0, p59a48310, m4fdebda2)
# 259: (FS_3, p92705ff4, m4cd420e2)
# 260: (FS_0, p4feff98b, m86da4874)
# 262: (FS_1, p31916918, mf0a83676)
# 271: (FS_0, pb1ef6b01, m4cd420e2)
# 278: (FS_0, p4feff98b, m86da4874)
# 297: (FS_0, pb1ef6b01, mb1b67bcc)
# 300: (FS_1, pf86c86e4, mf0a83676)
# 301: (FS_0, p4feff98b, m4cd420e2)
# 302: (FS_1, p31916918, m9d1605c7)
# 303: (FS_1, p31916918, m9d1605c7)
# 310: (FS_0, pb1ef6b01, mb1b67bcc)
# 317: (FS_1, p31916918, mf0a83676)
# 326: (FS_0, p4feff98b, m86da4874)
# 327: (FS_0, pb1ef6b01, me486b19e)
# 332: (FS_0, p59a48310, m86da4874)
# 336: (FS_1, p6eb0c221, mf0a83676)
# 356: (FS_1, pf86c86e4, m868d56db)
# 358: (FS_0, pb1ef6b01, m86da4874)
# 370: (FS_0, p59a48310, m4fdebda2)
# 371: (FS_0, pb1ef6b01, m86da4874)
# 372: (FS_1, pf9439e45, ma88f99b9)
# 390: (FS_0, pb1ef6b01, m15ae4048)
# 395: (FS_0, p59a48310, m4cd420e2)
# 402: (FS_0, p59a48310, m86da4874)
# 409: (FS_1, p6eb0c221, m2a6ab0d6)
# 417: (FS_0, p59a48310, m86da4874)
# 418: (FS_1, p31916918, meffc0dfa)
# 426: (FS_0, p4feff98b, me486b19e)
# 431: (FS_1, pf86c86e4, meffc0dfa)
# 435: (FS_1, pf86c86e4, m9d1605c7)
# 451: (FS_0, p59a48310, m15ae4048)
# 452: (FS_1, p6eb0c221, m868d56db)
# 454: (FS_1, p31916918, m48f576bb)
# 457: (FS_2, p563801bd, mc8ef3a88)
# 467: (FS_0, p59a48310, m4cd420e2)
# 469: (FS_1, p6eb0c221, m48f576bb)
# 478: (FS_2, p71c7354b, mf4ff6845)
# 479: (FS_0, pb1ef6b01, m15ae4048)
# 495: (FS_1, p6eb0c221, m868d56db)
# 501: (FS_1, pf86c86e4, mf0a83676)
# 505: (FS_0, p59a48310, m4cd420e2)
# 508: (FS_2, p71c7354b, m7fb43a9c)
# 510: (FS_0, pb1ef6b01, m4cd420e2)
# 519: (FS_0, p4feff98b, me486b19e)
# 520: (FS_1, p6eb0c221, m9d1605c7)
# 523: (FS_0, p4feff98b, m4fdebda2)
# 524: (FS_0, p4feff98b, m9175e580)
# 525: (FS_1, p31916918, m9d1605c7)
# 533: (FS_0, p4feff98b, m86da4874)
# 540: (FS_0, p59a48310, m9175e580)
# 543: (FS_1, pf9439e45, m48f576bb)
# 548: (FS_3, p92705ff4, m4fdebda2)
# 555: (FS_0, p4feff98b, m9175e580)
# 557: (FS_3, p92705ff4, m86da4874)
# 558: (FS_0, p4feff98b, me486b19e)
# 562: (FS_0, p59a48310, m15ae4048)
# 566: (FS_0, p59a48310, m15ae4048)
# 579: (FS_0, p4feff98b, m86da4874)
# 583: (FS_0, p59a48310, m4cd420e2)
# 585: (FS_1, pf86c86e4, m9d1605c7)
# 588: (FS_1, p31916918, ma88f99b9)
# 589: (FS_1, p31916918, m868d56db)
# 590: (FS_0, p59a48310, m15ae4048)
# 591: (FS_0, p4feff98b, me486b19e)
# 594: (FS_0, pb1ef6b01, m4cd420e2)
# 596: (FS_1, p31916918, mf0a83676)
# 600: (FS_0, p59a48310, m86da4874)
# 602: (FS_3, p92705ff4, m86da4874)
# 605: (FS_1, pf9439e45, mf0a83676)
# 608: (FS_0, pb1ef6b01, mb1b67bcc)
# 619: (FS_0, pb1ef6b01, m4cd420e2)
# 627: (FS_0, p4feff98b, m4cd420e2)
# 628: (FS_1, p31916918, macdedfff)
# 630: (FS_0, p59a48310, m4cd420e2)
# 633: (FS_0, p4feff98b, m86da4874)
# 637: (FS_3, p92705ff4, m4cd420e2)
# 638: (FS_0, pb1ef6b01, mb1b67bcc)
# 640: (FS_3, p92705ff4, m4cd420e2)
# 643: (FS_3, p92705ff4, m86da4874)
# 645: (FS_3, p92705ff4, me486b19e)
# 651: (FS_1, p6eb0c221, m48f576bb)
# 666: (FS_0, pb1ef6b01, m9175e580)
# 677: (FS_1, p31916918, meffc0dfa)
# 678: (FS_1, pf86c86e4, meffc0dfa)
# 683: (FS_1, p31916918, m9d1605c7)
# 686: (FS_1, p6eb0c221, m868d56db)
# 694: (FS_0, p59a48310, m4fdebda2)
# 698: (FS_1, pf86c86e4, m9d1605c7)
# 700: (FS_0, p59a48310, m4cd420e2)
# 704: (FS_1, p31916918, ma88f99b9)
# 707: (FS_1, pf86c86e4, ma88f99b9)
# 714: (FS_3, p92705ff4, m15ae4048)
# 716: (FS_1, p6eb0c221, macdedfff)
# 722: (FS_0, p59a48310, m9175e580)
# 732: (FS_1, p6eb0c221, ma88f99b9)
# 739: (FS_0, p59a48310, m4fdebda2)
# 745: (FS_0, p59a48310, me486b19e)
# 746: (FS_0, p59a48310, m15ae4048)
# 752: (FS_0, pb1ef6b01, m4cd420e2)
# 756: (FS_0, p59a48310, m15ae4048)
# 757: (FS_0, p59a48310, m86da4874)
# 758: (FS_0, p59a48310, m15ae4048)
# 759: (FS_1, pf9439e45, m2a6ab0d6)
# 764: (FS_0, p4feff98b, m4fdebda2)
# 782: (FS_0, pb1ef6b01, m15ae4048)
# 784: (FS_0, p4feff98b, m86da4874)
# 787: (FS_0, p4feff98b, m86da4874)
# 789: (FS_1, p31916918, m9d1605c7)
# 796: (FS_0, p59a48310, m4cd420e2)
# 797: (FS_0, p4feff98b, m86da4874)
# 798: (FS_0, pb1ef6b01, me486b19e)
# 799: (FS_1, pf86c86e4, m2a6ab0d6)
# 810: (FS_0, pb1ef6b01, mb1b67bcc)
# 813: (FS_0, p59a48310, me486b19e)
# 815: (FS_0, p59a48310, m9175e580)
# 816: (FS_1, p6eb0c221, m48f576bb)
# 820: (FS_0, pb1ef6b01, m15ae4048)
# 823: (FS_1, p6eb0c221, meffc0dfa)
# 827: (FS_0, p59a48310, me486b19e)
# 833: (FS_0, pb1ef6b01, m86da4874)
# 840: (FS_0, p4feff98b, me486b19e)
# 847: (FS_0, p4feff98b, m4fdebda2)
# 848: (FS_1, pf86c86e4, m9d1605c7)
# 853: (FS_0, p4feff98b, m4cd420e2)
# 854: (FS_0, pb1ef6b01, mb1b67bcc)
# 858: (FS_1, pf86c86e4, m868d56db)
# 859: (FS_1, pf86c86e4, mf0a83676)
# 867: (FS_0, p4feff98b, m86da4874)
# 868: (FS_0, p59a48310, m15ae4048)
# 877: (FS_0, p59a48310, m15ae4048)
# 883: (FS_0, p4feff98b, m4cd420e2)
# 885: (FS_1, pf9439e45, m48f576bb)
# 893: (FS_0, pb1ef6b01, m86da4874)
# 902: (FS_0, p59a48310, m9175e580)
# 903: (FS_0, p4feff98b, m4fdebda2)
# 910: (FS_0, pb1ef6b01, m4fdebda2)
# 913: (FS_0, p59a48310, m15ae4048)
# 920: (FS_1, pf9439e45, m9d1605c7)
# 921: (FS_1, p31916918, m9d1605c7)
# 934: (FS_1, p31916918, ma88f99b9)
# 936: (FS_3, p92705ff4, m86da4874)
# 940: (FS_0, pb1ef6b01, m15ae4048)
# 943: (FS_0, p4feff98b, me486b19e)
# 953: (FS_0, pb1ef6b01, me486b19e)
# 955: (FS_1, p6eb0c221, ma88f99b9)
# 962: (FS_1, pf86c86e4, m2a6ab0d6)
# 964: (FS_1, p6eb0c221, meffc0dfa)
# 967: (FS_0, p4feff98b, me486b19e)
# 968: (FS_0, p4feff98b, me486b19e)
# 970: (FS_0, p59a48310, m4cd420e2)
# 994: (FS_0, p4feff98b, m4cd420e2)
# 999: (FS_1, p31916918, mf0a83676)
# 1010: (FS_1, p31916918, m9d1605c7)
# 1013: (FS_1, pf9439e45, ma88f99b9)
# 1017: (FS_1, pf9439e45, ma88f99b9)
# 1022: (FS_0, pb1ef6b01, mb1b67bcc)
# 1023: (FS_1, p31916918, mf0a83676)
# 1026: (FS_0, p4feff98b, m86da4874)
# 1033: (FS_0, p4feff98b, me486b19e)
# 1043: (FS_3, p92705ff4, m86da4874)

# %%
time_range = (6, 8)
fig_name = os.path.join(fig_path, f"FS-cross-correlogram-GJ-{input_name}-range-{time_range[0]}-{time_range[1]}")
                        
pcc1.plot_all_pair_cross_correlogram(neuron_id=None, time_range=time_range,
                                     fig_file_name=fig_name)

# %%
from snudda.plotting.plot_cross_correlogram import PlotCrossCorrelogram
pcc2 = PlotCrossCorrelogram(sim_file_nogj, snudda_simulation_load=sls_nogj)
# Out:
# Loading forKadri-FS1050-1/simulation/output-noGJ-SfN2022-forKadri-oscillating-20Hz-ramp-up-background.hdf5
# WARNING. Depolarisation block in neuron - neuron_id: (name, parameter_key, morphology_key):
# 22: (FS_0, pb1ef6b01, m15ae4048)
# 49: (FS_1, p31916918, mf0a83676)
# 77: (FS_0, pb1ef6b01, m15ae4048)
# 98: (FS_3, p92705ff4, m4fdebda2)
# 100: (FS_1, p31916918, ma88f99b9)
# 109: (FS_0, p4feff98b, me486b19e)
# 116: (FS_0, pb1ef6b01, mb1b67bcc)
# 143: (FS_0, p4feff98b, m9175e580)
# 159: (FS_0, pb1ef6b01, m15ae4048)
# 297: (FS_0, pb1ef6b01, mb1b67bcc)
# 303: (FS_1, p31916918, m9d1605c7)
# 417: (FS_0, p59a48310, m86da4874)
# 418: (FS_1, p31916918, meffc0dfa)
# 451: (FS_0, p59a48310, m15ae4048)
# 469: (FS_1, p6eb0c221, m48f576bb)
# 533: (FS_0, p4feff98b, m86da4874)
# 557: (FS_3, p92705ff4, m86da4874)
# 588: (FS_1, p31916918, ma88f99b9)
# 590: (FS_0, p59a48310, m15ae4048)
# 591: (FS_0, p4feff98b, me486b19e)
# 608: (FS_0, pb1ef6b01, mb1b67bcc)
# 627: (FS_0, p4feff98b, m4cd420e2)
# 643: (FS_3, p92705ff4, m86da4874)
# 657: (FS_1, pf9439e45, m48f576bb)
# 716: (FS_1, p6eb0c221, macdedfff)
# 732: (FS_1, p6eb0c221, ma88f99b9)
# 739: (FS_0, p59a48310, m4fdebda2)
# 752: (FS_0, pb1ef6b01, m4cd420e2)
# 784: (FS_0, p4feff98b, m86da4874)
# 788: (FS_0, p59a48310, m4fdebda2)
# 797: (FS_0, p4feff98b, m86da4874)
# 844: (FS_0, p4feff98b, m4cd420e2)
# 867: (FS_0, p4feff98b, m86da4874)
# 937: (FS_3, p92705ff4, m86da4874)
# 944: (FS_0, p4feff98b, m86da4874)
# 1017: (FS_1, pf9439e45, ma88f99b9)
# 1022: (FS_0, pb1ef6b01, mb1b67bcc)

# %%
time_range = (6, 8)
fig_name = os.path.join(fig_path, f"FS-cross-correlogram-noGJ-{input_name}-range-{time_range[0]}-{time_range[1]}")
                        
pcc2.plot_all_pair_cross_correlogram(neuron_id=None, time_range=time_range,
                                     fig_file_name=fig_name)
