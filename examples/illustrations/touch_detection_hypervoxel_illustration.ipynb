# %% [markdown]
# # Touch detection in hyper voxel
# This creates the touch detection illustration, showing both the ball and stick neurons, and the voxelised version in the hyper voxel.

# %%
from touch_detection_hypervoxel_illustration import TouchDetectionHypervoxelIllustration

tdhi = TouchDetectionHypervoxelIllustration()
# Out:
# No d_view specified, running distribute neurons in serial
# Processing hyper voxel : 0/8 (2 neurons)
# Processing hyper voxel : 0/8 (2 neurons)
# --> Figures written to touch_detection_hypervoxel_illustration_network/figures
