# %% [markdown]
# # Touch detection illustration
# Twenty neurons ball and stick neurons are placed in two lines such that each connected neuron pair has four synapses. This simple network is used both in the illustration of touch detection and pruning in the methods paper, and also in unit testing.

# %%
from touch_detection_illustration import TouchDetectionIllustration

tdi = TouchDetectionIllustration()
tdi.plot("touch_detection_synapses.pdf")
# Out:
# No d_view specified, running distribute neurons in serial
# Processing hyper voxel : 0/8 (20 neurons)
# Read 400 out of total 400 synapses
# Loading 20 neurons with 400 synapses and 0 gap junctions
