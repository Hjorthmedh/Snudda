# %%
# %matplotlib inline

import os
network_path = os.path.join("..", "networks", "lateral_twopop_virtual")
network_file = os.path.join(network_path, "network-synapses-virtual.hdf5")
simulation_file_with_synapses = os.path.join(network_path, "simulation", "output-with-synapses-12Hz-virtual-5Hz.hdf5")
simulation_file_no_synapses = os.path.join(network_path, "simulation", "output-no-synapses-12Hz-virtual-5Hz.hdf5")
duration = 5

# %%
from snudda.plotting.plot_neuron_voltage import PlotNeuronVoltage

snudda_data = "../../../../../../BasalGangliaData/data/"

pnv = PlotNeuronVoltage(network_path=network_path,
                        network_file=network_file,
                        simulation_file=simulation_file_with_synapses,
                        snudda_data=snudda_data)
# Out:
# Loading network data ../networks/lateral_twopop_virtual/network-synapses-virtual.hdf5
# Loading simulation data ../networks/lateral_twopop_virtual/simulation/output-with-synapses-12Hz-virtual-5Hz.hdf5
# Loading ../networks/lateral_twopop_virtual/simulation/output-with-synapses-12Hz-virtual-5Hz.hdf5

# %%
time_bins = [[0, 0.5], [0.5, 1], [1, 1.5], [1.5, 2], [2, 2.5], [2.5, 3], [3, 3.5], [3.5, 4], [4, 4.5], [4.5, 5], [5, 5.5]]

neuron_id_list = pnv.network_loader.get_neuron_id(include_virtual=False)

for neuron_id in neuron_id_list[:10]:
    fig_name = os.path.join(network_path, "figures", f"dendritic_voltage-{neuron_id}-with-synapses-5Hz-virtual.png")
    
    pnv.plot_binned_neuron_voltage(neuron_id=neuron_id, time_bins=time_bins, title="With synapses, 5Hz virtual neighbours", 
                                   fig_name=fig_name, y_range=(-0.1, -0.05),
                                   fig_size=(10,10))
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20211026/morphology/WT-P270-09-15ak-cor-res3-var2.swc
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20211026/morphology/WT-P270-09-15ak-cor-res3-var2.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var2.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var2.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var0.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var5.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var7.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var7.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var1.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var5.swc

# %%
from snudda.plotting.plot_neuron_voltage import PlotNeuronVoltage

snudda_data = "../../../../../../BasalGangliaData/data/"

pnv2 = PlotNeuronVoltage(network_path=network_path,
                         network_file=network_file,
                         simulation_file=simulation_file_no_synapses,
                         snudda_data=snudda_data)
# Out:
# Loading network data ../networks/lateral_twopop_virtual/network-synapses-virtual.hdf5
# Loading simulation data ../networks/lateral_twopop_virtual/simulation/output-no-synapses-12Hz-virtual-5Hz.hdf5
# Loading ../networks/lateral_twopop_virtual/simulation/output-no-synapses-12Hz-virtual-5Hz.hdf5

# %%
time_bins = [[0, 0.5], [0.5, 1], [1, 1.5], [1.5, 2], [2, 2.5], [2.5, 3], [3, 3.5], [3.5, 4], [4, 4.5], [4.5, 5], [5, 5.5]]

neuron_id_list2 = pnv2.network_loader.get_neuron_id(include_virtual=False)


for neuron_id in neuron_id_list2[:5]:

    fig_name = os.path.join(network_path, "figures", f"dendritic_voltage-{neuron_id}-no-synapses-5Hz-virtual.png")

    pnv2.plot_binned_neuron_voltage(neuron_id=neuron_id, time_bins=time_bins, title=f"No synapses, 5Hz virtual neighbours", 
                                    fig_name=fig_name, y_range=(-0.1, -0.05),
                                    fig_size=(10,10))
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20211026/morphology/WT-P270-09-15ak-cor-res3-var2.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20211026/morphology/WT-P270-09-15ak-cor-res3-var2.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var2.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var2.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var0.swc

# %%
neuron_id=3831
pnv.list_all_section_dist(neuron_id=neuron_id)
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var5.swc
# Section 0, center dist 24 um, length 41 um
# Section 1, center dist 118 um, length 148 um
# Section 2, center dist 115 um, length 143 um
# Section 3, center dist 14 um, length 22 um
# Section 4, center dist 103 um, length 155 um
# Section 5, center dist 92 um, length 132 um
# Section 6, center dist 13 um, length 20 um
# Section 7, center dist 104 um, length 162 um
# Section 8, center dist 88 um, length 131 um
# Section 9, center dist 12 um, length 17 um
# Section 10, center dist 25 um, length 10 um
# Section 11, center dist 30 um, length 0 um
# Section 12, center dist 71 um, length 81 um
# Section 13, center dist 134 um, length 46 um
# Section 14, center dist 159 um, length 95 um
# Section 15, center dist 41 um, length 22 um
# Section 16, center dist 122 um, length 140 um
# Section 17, center dist 109 um, length 113 um
# Section 18, center dist 129 um, length 198 um
# Section 19, center dist 26 um, length 13 um
# Section 20, center dist 145 um, length 225 um
# Section 21, center dist 52 um, length 39 um
# Section 22, center dist 88 um, length 32 um
# Section 23, center dist 133 um, length 122 um
# Section 24, center dist 12 um, length 17 um
# Section 25, center dist 26 um, length 10 um
# Section 26, center dist 51 um, length 40 um
# Section 27, center dist 103 um, length 66 um
# Section 28, center dist 91 um, length 41 um
# Section 29, center dist 35 um, length 10 um
# Section 30, center dist 100 um, length 119 um
# Section 31, center dist 120 um, length 159 um
# Section 32, center dist 35 um, length 28 um
# Section 33, center dist 112 um, length 126 um
# Section 34, center dist 126 um, length 153 um
# Section 35, center dist 10 um, length 13 um
# Section 36, center dist 17 um, length 1 um
# Section 37, center dist 110 um, length 185 um
# Section 38, center dist 25 um, length 15 um
# Section 39, center dist 124 um, length 184 um
# Section 40, center dist 51 um, length 38 um
# Section 41, center dist 136 um, length 132 um
# Section 42, center dist 109 um, length 78 um
# Section 43, center dist 19 um, length 5 um
# Section 44, center dist 110 um, length 177 um
# Section 45, center dist 24 um, length 6 um
# Section 46, center dist 89 um, length 125 um
# Section 47, center dist 44 um, length 34 um
# Section 48, center dist 109 um, length 97 um
# Section 49, center dist 129 um, length 136 um
# Section 50, center dist 7 um, length 7 um
# Section 51, center dist 15 um, length 8 um
# Section 52, center dist 74 um, length 109 um
# Section 53, center dist 35 um, length 31 um
# Section 54, center dist 80 um, length 58 um
# Section 55, center dist 80 um, length 58 um
# Section 56, center dist 143 um, length 67 um
# Section 57, center dist 126 um, length 33 um
# Section 58, center dist 93 um, length 164 um
# Section 59, center dist 17 um, length 26 um
# Section 60, center dist 59 um, length 59 um
# Section 61, center dist 118 um, length 59 um
# Section 62, center dist 91 um, length 4 um
# Section 63, center dist 100 um, length 15 um
# Section 64, center dist 99 um, length 12 um
# Section 65, center dist 126 um, length 192 um

# %%
section_id = [-1, 4, 56]
pnv.plot_neuron_voltage(neuron_id=neuron_id,section_id=section_id, sliding_window_size=10000, title="With synapses")
pnv2.plot_neuron_voltage(neuron_id=neuron_id,section_id=section_id, sliding_window_size=10000, title="No synapses")
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var5.swc
# Volt size (200001, 4)
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var5.swc
# Volt size (200001, 4)
# <Axes: title={'center': 'No synapses - dSPN_0 (3831) - sliding window 10000'}>

# %%
neuron_id = 2288
pnv.list_all_section_dist(neuron_id=neuron_id)
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20211026/morphology/WT-P270-09-15ak-cor-res3-var2.swc
# Section 0, center dist 8 um, length 8 um
# Section 1, center dist 17 um, length 11 um
# Section 2, center dist 30 um, length 14 um
# Section 3, center dist 55 um, length 36 um
# Section 4, center dist 82 um, length 90 um
# Section 5, center dist 109 um, length 172 um
# Section 6, center dist 27 um, length 32 um
# Section 7, center dist 48 um, length 10 um
# Section 8, center dist 92 um, length 97 um
# Section 9, center dist 13 um, length 18 um
# Section 10, center dist 24 um, length 4 um
# Section 11, center dist 132 um, length 212 um
# Section 12, center dist 45 um, length 37 um
# Section 13, center dist 69 um, length 12 um
# Section 14, center dist 105 um, length 59 um
# Section 15, center dist 159 um, length 49 um
# Section 16, center dist 171 um, length 73 um
# Section 17, center dist 142 um, length 133 um
# Section 18, center dist 127 um, length 127 um
# Section 19, center dist 112 um, length 181 um
# Section 20, center dist 63 um, length 119 um
# Section 21, center dist 13 um, length 18 um
# Section 22, center dist 26 um, length 9 um
# Section 23, center dist 88 um, length 116 um
# Section 24, center dist 36 um, length 12 um
# Section 25, center dist 35 um, length 28 um
# Section 26, center dist 12 um, length 17 um
# Section 27, center dist 27 um, length 13 um
# Section 28, center dist 45 um, length 21 um
# Section 29, center dist 144 um, length 179 um
# Section 30, center dist 145 um, length 179 um
# Section 31, center dist 44 um, length 19 um
# Section 32, center dist 28 um, length 15 um
# Section 33, center dist 106 um, length 142 um
# Section 34, center dist 44 um, length 18 um
# Section 35, center dist 104 um, length 101 um
# Section 36, center dist 201 um, length 92 um
# Section 37, center dist 177 um, length 45 um
# Section 38, center dist 223 um, length 46 um
# Section 39, center dist 225 um, length 50 um
# Section 40, center dist 71 um, length 36 um
# Section 41, center dist 27 um, length 47 um
# Section 42, center dist 60 um, length 18 um
# Section 43, center dist 113 um, length 88 um
# Section 44, center dist 101 um, length 64 um
# Section 45, center dist 142 um, length 183 um

# %%
section_id = [0, 16, 38]
pnv.plot_neuron_voltage(neuron_id=neuron_id,section_id=section_id, sliding_window_size=10000, title="With synapses")
pnv2.plot_neuron_voltage(neuron_id=neuron_id,section_id=section_id, sliding_window_size=10000, title="No synapses")
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20211026/morphology/WT-P270-09-15ak-cor-res3-var2.swc
# Volt size (200001, 3)
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e151123_c1_D2-mWT-P270-09-v20211026/morphology/WT-P270-09-15ak-cor-res3-var2.swc
# Volt size (200001, 3)
# <Axes: title={'center': 'No synapses - iSPN_2 (2288) - sliding window 10000'}>
