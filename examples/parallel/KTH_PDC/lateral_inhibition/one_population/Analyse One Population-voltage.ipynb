# %% [markdown]
# # Verifying that lateral GABA inhibtion affects firing rate in a population

# %%
# %matplotlib inline

import os
network_path = os.path.join("..", "networks", "lateral_onepop")
simulation_file_with_synapses = os.path.join(network_path, "simulation", "output-with-synapses-volt.hdf5")
simulation_file_no_synapses = os.path.join(network_path, "simulation", "output-no-synapses-volt.hdf5")
duration = 5

# %% [markdown]
# # Plot network

# %%
from snudda.plotting import PlotNetwork

pn = PlotNetwork(network_path)
pn.plot_populations(unmarked_alpha=0)
pn.plot_populations(unmarked_alpha=0.02)

# The commented code below also plots the network, but with the option to plot more detail of the neurons:
# pn = PlotNetwork(network_path)
# pn.plot(plot_axon=False, plot_dendrite=False, plot_synapses=False, colour_population_unit=True)

pn.close()  # Close the hdf5 file so others can use it (or better shut down kernel after)
# Out:
# Reading SNUDDA_DATA=../../../../../../BasalGangliaData/data/ from ../networks/lateral_onepop/network-config.json
# Population unit 1 has 2000 neurons
# Population unit 1 has 2000 neurons

# %% [markdown]
# # Plot neuron input

# %%
from snudda.plotting import PlotInput
input_file = os.path.join(network_path, "input-spikes.hdf5")
spi = PlotInput(input_file, network_path)
spi.plot_input_population_unit(population_unit_id=1, num_neurons=2, neuron_type="dSPN", fig_size=(15,5))
spi.plot_input_population_unit(population_unit_id=1, num_neurons=2, neuron_type="iSPN", fig_size=(15,5))

# %% [markdown]
# # Plot neuron activity
#
# ## With lateral inhibtion

# %%
from snudda.plotting import SnuddaPlotSpikeRaster2
fig_file_raster = f"spike-raster.png"

time_range_zoom = (0,duration)
spr = SnuddaPlotSpikeRaster2(network_path=network_path, simulation_file=simulation_file_with_synapses)

spr.plot_spike_raster(fig_file=fig_file_raster, time_range=time_range_zoom)
# Out:
# Loading ../networks/lateral_onepop/simulation/output-with-synapses-volt.hdf5
# WARNING. Depolarisation block in neuron - neuron_id: (name, parameter_key, morphology_key):
# 69: (iSPN_0, p581376d6, mf2f3395e)
# 70: (iSPN_0, p635b801c, m3a845add)
# 89: (dSPN_2, pb267a31a, m7721d5cf)
# 163: (iSPN_0, p581376d6, md0f5647c)
# 190: (iSPN_0, p635b801c, m69613ef9)
# 239: (iSPN_0, p635b801c, md0f5647c)
# 266: (iSPN_0, pf721cf77, m3a845add)
# 325: (iSPN_0, p581376d6, md0f5647c)
# 342: (iSPN_0, p581376d6, md0f5647c)
# 373: (iSPN_0, pf721cf77, m3a845add)
# 395: (iSPN_0, p635b801c, md0f5647c)
# 397: (iSPN_0, p581376d6, m3a845add)
# 411: (dSPN_0, pb0529fb9, mbb8e5b24)
# 436: (iSPN_3, p57956f10, m1083058d)
# 444: (iSPN_0, p635b801c, m7bc82287)
# 466: (iSPN_0, p581376d6, m7bc82287)
# 507: (iSPN_0, pf721cf77, md0f5647c)
# 549: (iSPN_0, p581376d6, m3a845add)
# 571: (iSPN_0, p581376d6, mf2f3395e)
# 574: (iSPN_0, p635b801c, mf2f3395e)
# 590: (iSPN_0, pf721cf77, md0f5647c)
# 625: (iSPN_0, pf721cf77, md0f5647c)
# 651: (iSPN_0, p67dac726, m3a845add)
# 674: (iSPN_0, p581376d6, mc16840cd)
# 724: (iSPN_0, p635b801c, m6486ed26)
# 725: (iSPN_0, p581376d6, m3a845add)
# 828: (iSPN_0, pf721cf77, m3a845add)
# 848: (iSPN_0, pfb05971b, m6486ed26)
# 920: (dSPN_2, pb267a31a, m7721d5cf)
# 924: (iSPN_0, p039c9f4f, m7bc82287)
# 948: (iSPN_0, p635b801c, m6486ed26)
# 971: (iSPN_0, p039c9f4f, md0f5647c)
# 994: (iSPN_0, p581376d6, m3a845add)
# 1022: (iSPN_3, p55446481, m1083058d)
# 1037: (iSPN_0, pf721cf77, mf2f3395e)
# 1056: (iSPN_0, p635b801c, mc16840cd)
# 1072: (dSPN_0, p1863c9a5, m9fda9b20)
# 1078: (iSPN_0, p635b801c, m3a845add)
# 1138: (iSPN_0, pfb05971b, m6486ed26)
# 1253: (iSPN_0, p635b801c, md0f5647c)
# 1285: (iSPN_0, p039c9f4f, mf2f3395e)
# 1287: (iSPN_0, p581376d6, mf2f3395e)
# 1298: (iSPN_0, p635b801c, md0f5647c)
# 1343: (iSPN_0, pf721cf77, m6486ed26)
# 1459: (iSPN_0, p581376d6, m6486ed26)
# 1495: (iSPN_0, p039c9f4f, m7bc82287)
# 1496: (iSPN_0, pf721cf77, mf2f3395e)
# 1540: (iSPN_0, pd300f5b9, mf2f3395e)
# 1570: (iSPN_0, p635b801c, md0f5647c)
# 1590: (iSPN_0, p67dac726, mf2f3395e)
# 1599: (iSPN_0, p039c9f4f, m7bc82287)
# 1617: (iSPN_0, pfb05971b, m3a845add)
# 1619: (iSPN_0, p581376d6, m6486ed26)
# 1651: (iSPN_0, pf721cf77, md0f5647c)
# 1652: (iSPN_0, p635b801c, m3a845add)
# 1684: (iSPN_0, p635b801c, mc16840cd)
# 1768: (iSPN_0, p039c9f4f, m7bc82287)
# 1770: (iSPN_0, pf721cf77, m3a845add)
# 1804: (iSPN_0, p635b801c, mf2f3395e)
# 1918: (iSPN_0, p581376d6, mf2f3395e)
# 1938: (iSPN_0, p635b801c, mf2f3395e)
# 1939: (iSPN_0, p635b801c, m6486ed26)
# 1965: (iSPN_0, p635b801c, m6486ed26)
# 1985: (iSPN_0, p039c9f4f, m7bc82287)
# 1987: (iSPN_0, p581376d6, md0f5647c)
# Saving figure to ../networks/lateral_onepop/figures/spike-raster.png

# %%
spr.plot_spike_histogram(label_text="lateral inhibition")
# Out:
# Saving figure ../networks/lateral_onepop/figures/spike-frequency-pop-units1.pdf
# <Axes: xlabel='Time (s)', ylabel='Frequency (Hz)'>

# %% [markdown]
# ## Without lateral inhibition

# %%
from snudda.plotting import SnuddaPlotSpikeRaster2
fig_file_raster = f"spike-raster.png"

time_range_zoom = (0,duration)
spr_no = SnuddaPlotSpikeRaster2(network_path=network_path, simulation_file=simulation_file_no_synapses)

spr_no.plot_spike_raster(fig_file=fig_file_raster, time_range=time_range_zoom)
# Out:
# Loading ../networks/lateral_onepop/simulation/output-no-synapses-volt.hdf5
# WARNING. Depolarisation block in neuron - neuron_id: (name, parameter_key, morphology_key):
# 47: (iSPN_0, p039c9f4f, md0f5647c)
# 69: (iSPN_0, p581376d6, mf2f3395e)
# 70: (iSPN_0, p635b801c, m3a845add)
# 163: (iSPN_0, p581376d6, md0f5647c)
# 188: (iSPN_0, p635b801c, m6486ed26)
# 217: (iSPN_0, pf721cf77, md0f5647c)
# 282: (iSPN_0, p67dac726, mf2f3395e)
# 327: (iSPN_0, p581376d6, mf2f3395e)
# 342: (iSPN_0, p581376d6, md0f5647c)
# 372: (iSPN_0, p67dac726, mf2f3395e)
# 373: (iSPN_0, pf721cf77, m3a845add)
# 395: (iSPN_0, p635b801c, md0f5647c)
# 397: (iSPN_0, p581376d6, m3a845add)
# 421: (iSPN_0, p67dac726, mf2f3395e)
# 436: (iSPN_3, p57956f10, m1083058d)
# 442: (iSPN_0, p581376d6, mf2f3395e)
# 445: (iSPN_0, pf721cf77, m3a845add)
# 460: (dSPN_2, pb267a31a, m7721d5cf)
# 507: (iSPN_0, pf721cf77, md0f5647c)
# 527: (iSPN_0, p581376d6, mf2f3395e)
# 528: (iSPN_0, p635b801c, m3a845add)
# 549: (iSPN_0, p581376d6, m3a845add)
# 571: (iSPN_0, p581376d6, mf2f3395e)
# 574: (iSPN_0, p635b801c, mf2f3395e)
# 588: (iSPN_0, pf721cf77, mc16840cd)
# 591: (iSPN_0, pf721cf77, mf2f3395e)
# 608: (iSPN_0, p581376d6, mf2f3395e)
# 625: (iSPN_0, pf721cf77, md0f5647c)
# 626: (iSPN_0, p039c9f4f, m3a845add)
# 673: (iSPN_0, p039c9f4f, md0f5647c)
# 694: (iSPN_0, p581376d6, m3a845add)
# 696: (iSPN_0, p67dac726, mc16840cd)
# 697: (iSPN_0, pf721cf77, mf2f3395e)
# 724: (iSPN_0, p635b801c, m6486ed26)
# 767: (iSPN_0, pf721cf77, m3a845add)
# 848: (iSPN_0, pfb05971b, m6486ed26)
# 919: (dSPN_1, p6c462b98, mc44c4566)
# 948: (iSPN_0, p635b801c, m6486ed26)
# 1056: (iSPN_0, p635b801c, mc16840cd)
# 1080: (iSPN_0, p635b801c, mf2f3395e)
# 1116: (iSPN_0, pf721cf77, mf2f3395e)
# 1138: (iSPN_0, pfb05971b, m6486ed26)
# 1146: (iSPN_0, pf721cf77, m6486ed26)
# 1238: (iSPN_0, p039c9f4f, m6486ed26)
# 1251: (iSPN_0, p635b801c, m6486ed26)
# 1253: (iSPN_0, p635b801c, md0f5647c)
# 1286: (iSPN_0, p581376d6, mf2f3395e)
# 1287: (iSPN_0, p581376d6, mf2f3395e)
# 1299: (iSPN_0, pf721cf77, mc16840cd)
# 1300: (iSPN_0, p581376d6, m6486ed26)
# 1325: (iSPN_0, p039c9f4f, md0f5647c)
# 1343: (iSPN_0, pf721cf77, m6486ed26)
# 1459: (iSPN_0, p581376d6, m6486ed26)
# 1479: (iSPN_0, pf721cf77, mf2f3395e)
# 1494: (iSPN_0, p581376d6, mc16840cd)
# 1497: (iSPN_0, p635b801c, md0f5647c)
# 1522: (iSPN_0, pf721cf77, m3a845add)
# 1533: (dSPN_0, pb0529fb9, m9fda9b20)
# 1570: (iSPN_0, p635b801c, md0f5647c)
# 1619: (iSPN_0, p581376d6, m6486ed26)
# 1626: (iSPN_3, p57956f10, m541041a7)
# 1652: (iSPN_0, p635b801c, m3a845add)
# 1671: (iSPN_0, p581376d6, m6486ed26)
# 1732: (dSPN_2, pb267a31a, mf0350288)
# 1734: (iSPN_0, p581376d6, m6486ed26)
# 1750: (iSPN_0, pf721cf77, m3a845add)
# 1804: (iSPN_0, p635b801c, mf2f3395e)
# 1837: (iSPN_0, p581376d6, mf2f3395e)
# 1858: (iSPN_0, p581376d6, m3a845add)
# 1917: (iSPN_0, p039c9f4f, m3a845add)
# 1918: (iSPN_0, p581376d6, mf2f3395e)
# 1938: (iSPN_0, p635b801c, mf2f3395e)
# 1965: (iSPN_0, p635b801c, m6486ed26)
# 1966: (iSPN_0, pf721cf77, mc16840cd)
# 1987: (iSPN_0, p581376d6, md0f5647c)
# Saving figure to ../networks/lateral_onepop/figures/spike-raster.png

# %%
spr_no.plot_spike_histogram(label_text="no inhibition")
# Out:
# Saving figure ../networks/lateral_onepop/figures/spike-frequency-pop-units1.pdf
# <Axes: xlabel='Time (s)', ylabel='Frequency (Hz)'>

# %% [markdown]
# # Summarising difference in activity (with and without lateral inhibition)

# %%
ax = spr.plot_spike_histogram(label_text="lateral inhibition ", show_figure=False, save_figure=False, fig_size=(10,5))
spr_no.plot_spike_histogram(ax=ax, label_text="no inhibition ", show_figure=True, save_figure=True)
# Out:
# Saving figure ../networks/lateral_onepop/figures/spike-frequency-pop-units1.pdf
# <Axes: xlabel='Time (s)', ylabel='Frequency (Hz)'>

# %% [markdown]
# # Plot voltage in compartments

# %%
from snudda.plotting.plot_neuron_voltage import PlotNeuronVoltage

snudda_data = "../../../../../../BasalGangliaData/data/"

pnv = PlotNeuronVoltage(network_path=network_path,
                        network_file=network_path,
                        simulation_file=simulation_file_with_synapses,
                        snudda_data=snudda_data)

time_bins = [[0, 0.5], [0.5, 1], [1, 1.5], [1.5, 2], [2, 2.5], [2.5, 3], [3, 3.5], [3.5, 4], [4, 4.5], [4.5, 5], [5, 5.5]]


for neuron_id in range(0, 5):
    fig_name = os.path.join(network_path, "figures", f"dendritic_voltage-{neuron_id}-with-synapses.png")
    
    pnv.plot_binned_neuron_voltage(neuron_id=neuron_id, time_bins=time_bins, title="With synapses", 
                                   fig_name=fig_name, y_range=(-0.1, -0.05),
                                   fig_size=(10,10))
# Out:
# Loading network data ../networks/lateral_onepop
# Loading simulation data ../networks/lateral_onepop/simulation/output-with-synapses-volt.hdf5
# Loading ../networks/lateral_onepop/simulation/output-with-synapses-volt.hdf5
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var1.swc
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /home/hjorth/HBP/Snudda/venv/lib/python3.9/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology/WT-P270-20-15ak-cor-res3-var7.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology/WT-P270-20-15ak-cor-res3-var5.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology/WT-P270-20-15ak-cor-res3-var0.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology/WT-P270-20-15ak-cor-res3-var3.swc

# %%
from snudda.plotting.plot_neuron_voltage import PlotNeuronVoltage

snudda_data = "../../../../../../BasalGangliaData/data/"

pnv = PlotNeuronVoltage(network_path=network_path,
                        network_file=network_path,
                        simulation_file=simulation_file_no_synapses,
                        snudda_data=snudda_data)

time_bins = [[0, 0.5], [0.5, 1], [1, 1.5], [1.5, 2], [2, 2.5], [2.5, 3], [3, 3.5], [3.5, 4], [4, 4.5], [4.5, 5], [5, 5.5]]

for neuron_id in range(0, 5):

    fig_name = os.path.join(network_path, "figures", f"dendritic_voltage-{neuron_id}-no-synapses.png")

    pnv.plot_binned_neuron_voltage(neuron_id=neuron_id, time_bins=time_bins, title=f"No synapses", 
                                   fig_name=fig_name, y_range=(-0.1, -0.05),
                                   fig_size=(10,10))
# Out:
# Loading network data ../networks/lateral_onepop
# Loading simulation data ../networks/lateral_onepop/simulation/output-no-synapses-volt.hdf5
# Loading ../networks/lateral_onepop/simulation/output-no-synapses-volt.hdf5
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var1.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology/WT-P270-20-15ak-cor-res3-var7.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology/WT-P270-20-15ak-cor-res3-var5.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology/WT-P270-20-15ak-cor-res3-var0.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c10_D1-mWT-P270-20-v20211026/morphology/WT-P270-20-15ak-cor-res3-var3.swc
