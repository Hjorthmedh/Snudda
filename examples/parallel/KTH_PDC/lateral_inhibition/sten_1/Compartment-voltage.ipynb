# %%
# %matplotlib inline

import os
network_path = os.path.join("..", "networks", "sten_1")
network_file = os.path.join(network_path, "network-synapses-minimal.hdf5")
simulation_file_with_synapses = os.path.join(network_path, "simulation", "output-with-synapses-sten_1-A.hdf5")
simulation_file_no_synapses = os.path.join(network_path, "simulation", "output-no-synapses-sten_1-A.hdf5")
duration = 18

# %%
from snudda.plotting.plot_neuron_voltage import PlotNeuronVoltage

snudda_data = "../../../../../../BasalGangliaData/data/"

pnv = PlotNeuronVoltage(network_path=network_path,
                        network_file=network_file,
                        simulation_file=simulation_file_with_synapses,
                        snudda_data=snudda_data)
# Out:
# Loading network data ../networks/sten_1/network-synapses-minimal.hdf5
# Loading simulation data ../networks/sten_1/simulation/output-with-synapses-sten_1-A.hdf5
# Loading ../networks/sten_1/simulation/output-with-synapses-sten_1-A.hdf5

# %%
time_bins = [[2, 3], [5, 6], [8, 9], [11, 12], [14, 15], [17, 18]]

# neuron_id_list = pnv.network_loader.get_neuron_id(include_virtual=False)[:10]
neuron_id_list = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500]

for neuron_id in neuron_id_list[:5]:
    fig_name = os.path.join(network_path, "figures", f"dendritic_voltage-{neuron_id}-with-synapses-sten-1A.png")
    
    pnv.plot_binned_neuron_voltage(neuron_id=neuron_id, time_bins=time_bins, title="With synapses ", 
                                   fig_name=fig_name, y_range=(-0.1, -0.03),
                                   fig_size=(10,10))
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var0.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e160118_c10_D2-m46-3-DE-v20211026/morphology/46-3-DE-cor-rep-ax-res3-var1.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c9_D1-mWT-1215MSN03-v20211026/morphology/WT-1215MSN03-cor-rep-ax-res3-var8.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e160118_c10_D2-m46-3-DE-v20211026/morphology/46-3-DE-cor-rep-ax-res3-var6.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c9_D1-mWT-1215MSN03-v20211026/morphology/WT-1215MSN03-cor-rep-ax-res3-var0.swc

# %%
from snudda.plotting.plot_neuron_voltage import PlotNeuronVoltage

snudda_data = "../../../../../../BasalGangliaData/data/"

pnv2 = PlotNeuronVoltage(network_path=network_path,
                         network_file=network_file,
                         simulation_file=simulation_file_no_synapses,
                         snudda_data=snudda_data)
# Out:
# Loading network data ../networks/sten_1/network-synapses-minimal.hdf5
# Loading simulation data ../networks/sten_1/simulation/output-no-synapses-sten_1-A.hdf5
# Loading ../networks/sten_1/simulation/output-no-synapses-sten_1-A.hdf5

# %%
time_bins = [[2, 3], [5, 6], [8, 9], [11, 12], [14, 15], [17, 18]]

# neuron_id_list2 = pnv2.network_loader.get_neuron_id(include_virtual=False)[:10]
neuron_id_list2 = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500]

for neuron_id in neuron_id_list2[:5]:

    fig_name = os.path.join(network_path, "figures", f"dendritic_voltage-{neuron_id}-no-synapses-sten-1A.png")

    pnv2.plot_binned_neuron_voltage(neuron_id=neuron_id, time_bins=time_bins, title=f"No synapses", 
                                    fig_name=fig_name, y_range=(-0.1, -0.04),
                                    fig_size=(10,10))
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var0.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e160118_c10_D2-m46-3-DE-v20211026/morphology/46-3-DE-cor-rep-ax-res3-var1.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c9_D1-mWT-1215MSN03-v20211026/morphology/WT-1215MSN03-cor-rep-ax-res3-var8.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/ispn/str-ispn-e160118_c10_D2-m46-3-DE-v20211026/morphology/46-3-DE-cor-rep-ax-res3-var6.swc
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150917_c9_D1-mWT-1215MSN03-v20211026/morphology/WT-1215MSN03-cor-rep-ax-res3-var0.swc

# %%
pop_id1 = pnv.network_loader.get_population_unit_members(population_unit=1, random_permute=True)

neuron_id=pop_id1[0]

pnv.list_all_section_dist(neuron_id=neuron_id)
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var0.swc
# Section 0, center dist 19 um, length 32 um
# Section 1, center dist 93 um, length 115 um
# Section 2, center dist 91 um, length 112 um
# Section 3, center dist 12 um, length 17 um
# Section 4, center dist 81 um, length 122 um
# Section 5, center dist 72 um, length 104 um
# Section 6, center dist 11 um, length 15 um
# Section 7, center dist 82 um, length 126 um
# Section 8, center dist 70 um, length 102 um
# Section 9, center dist 10 um, length 13 um
# Section 10, center dist 21 um, length 9 um
# Section 11, center dist 25 um, length 0 um
# Section 12, center dist 57 um, length 63 um
# Section 13, center dist 107 um, length 37 um
# Section 14, center dist 126 um, length 74 um
# Section 15, center dist 34 um, length 18 um
# Section 16, center dist 98 um, length 109 um
# Section 17, center dist 87 um, length 88 um
# Section 18, center dist 102 um, length 154 um
# Section 19, center dist 22 um, length 11 um
# Section 20, center dist 115 um, length 175 um
# Section 21, center dist 43 um, length 31 um
# Section 22, center dist 71 um, length 25 um
# Section 23, center dist 106 um, length 95 um
# Section 24, center dist 10 um, length 13 um
# Section 25, center dist 21 um, length 8 um
# Section 26, center dist 41 um, length 32 um
# Section 27, center dist 83 um, length 52 um
# Section 28, center dist 73 um, length 32 um
# Section 29, center dist 30 um, length 9 um
# Section 30, center dist 80 um, length 93 um
# Section 31, center dist 96 um, length 125 um
# Section 32, center dist 28 um, length 22 um
# Section 33, center dist 89 um, length 99 um
# Section 34, center dist 99 um, length 120 um
# Section 35, center dist 9 um, length 10 um
# Section 36, center dist 14 um, length 1 um
# Section 37, center dist 86 um, length 144 um
# Section 38, center dist 20 um, length 12 um
# Section 39, center dist 98 um, length 144 um
# Section 40, center dist 42 um, length 30 um
# Section 41, center dist 108 um, length 103 um
# Section 42, center dist 87 um, length 61 um
# Section 43, center dist 16 um, length 5 um
# Section 44, center dist 87 um, length 138 um
# Section 45, center dist 21 um, length 6 um
# Section 46, center dist 72 um, length 97 um
# Section 47, center dist 37 um, length 27 um
# Section 48, center dist 89 um, length 76 um
# Section 49, center dist 104 um, length 106 um
# Section 50, center dist 7 um, length 5 um
# Section 51, center dist 13 um, length 7 um
# Section 52, center dist 60 um, length 86 um
# Section 53, center dist 30 um, length 25 um
# Section 54, center dist 65 um, length 46 um
# Section 55, center dist 65 um, length 46 um
# Section 56, center dist 115 um, length 54 um
# Section 57, center dist 101 um, length 26 um
# Section 58, center dist 74 um, length 128 um
# Section 59, center dist 14 um, length 20 um
# Section 60, center dist 47 um, length 47 um
# Section 61, center dist 94 um, length 47 um
# Section 62, center dist 73 um, length 4 um
# Section 63, center dist 81 um, length 12 um
# Section 64, center dist 80 um, length 10 um
# Section 65, center dist 99 um, length 149 um

# %%
section_id = [-1, 2, 28, 49, 61]
pnv.plot_neuron_voltage(neuron_id=neuron_id,section_id=section_id, sliding_window_size=50, title="With synapses", fig_size=(10,5))
pnv2.plot_neuron_voltage(neuron_id=neuron_id,section_id=section_id, sliding_window_size=50, title="No synapses", fig_size=(10,5))
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var0.swc
# Volt size (1801, 7)
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var0.swc
# Volt size (1801, 7)
# <Axes: title={'center': 'No synapses - dSPN_0 (0) - sliding window 50'}>

# %%
pop_id2 = pnv.network_loader.get_population_unit_members(population_unit=1, random_permute=True)
neuron_id=pop_id2[0]
pnv.list_all_section_dist(neuron_id=neuron_id)
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var0.swc
# Section 0, center dist 19 um, length 32 um
# Section 1, center dist 93 um, length 115 um
# Section 2, center dist 91 um, length 112 um
# Section 3, center dist 12 um, length 17 um
# Section 4, center dist 81 um, length 122 um
# Section 5, center dist 72 um, length 104 um
# Section 6, center dist 11 um, length 15 um
# Section 7, center dist 82 um, length 126 um
# Section 8, center dist 70 um, length 102 um
# Section 9, center dist 10 um, length 13 um
# Section 10, center dist 21 um, length 9 um
# Section 11, center dist 25 um, length 0 um
# Section 12, center dist 57 um, length 63 um
# Section 13, center dist 107 um, length 37 um
# Section 14, center dist 126 um, length 74 um
# Section 15, center dist 34 um, length 18 um
# Section 16, center dist 98 um, length 109 um
# Section 17, center dist 87 um, length 88 um
# Section 18, center dist 102 um, length 154 um
# Section 19, center dist 22 um, length 11 um
# Section 20, center dist 115 um, length 175 um
# Section 21, center dist 43 um, length 31 um
# Section 22, center dist 71 um, length 25 um
# Section 23, center dist 106 um, length 95 um
# Section 24, center dist 10 um, length 13 um
# Section 25, center dist 21 um, length 8 um
# Section 26, center dist 41 um, length 32 um
# Section 27, center dist 83 um, length 52 um
# Section 28, center dist 73 um, length 32 um
# Section 29, center dist 30 um, length 9 um
# Section 30, center dist 80 um, length 93 um
# Section 31, center dist 96 um, length 125 um
# Section 32, center dist 28 um, length 22 um
# Section 33, center dist 89 um, length 99 um
# Section 34, center dist 99 um, length 120 um
# Section 35, center dist 9 um, length 10 um
# Section 36, center dist 14 um, length 1 um
# Section 37, center dist 86 um, length 144 um
# Section 38, center dist 20 um, length 12 um
# Section 39, center dist 98 um, length 144 um
# Section 40, center dist 42 um, length 30 um
# Section 41, center dist 108 um, length 103 um
# Section 42, center dist 87 um, length 61 um
# Section 43, center dist 16 um, length 5 um
# Section 44, center dist 87 um, length 138 um
# Section 45, center dist 21 um, length 6 um
# Section 46, center dist 72 um, length 97 um
# Section 47, center dist 37 um, length 27 um
# Section 48, center dist 89 um, length 76 um
# Section 49, center dist 104 um, length 106 um
# Section 50, center dist 7 um, length 5 um
# Section 51, center dist 13 um, length 7 um
# Section 52, center dist 60 um, length 86 um
# Section 53, center dist 30 um, length 25 um
# Section 54, center dist 65 um, length 46 um
# Section 55, center dist 65 um, length 46 um
# Section 56, center dist 115 um, length 54 um
# Section 57, center dist 101 um, length 26 um
# Section 58, center dist 74 um, length 128 um
# Section 59, center dist 14 um, length 20 um
# Section 60, center dist 47 um, length 47 um
# Section 61, center dist 94 um, length 47 um
# Section 62, center dist 73 um, length 4 um
# Section 63, center dist 81 um, length 12 um
# Section 64, center dist 80 um, length 10 um
# Section 65, center dist 99 um, length 149 um

# %%
section_id = [0, 9, 27, 47]
pnv.plot_neuron_voltage(neuron_id=neuron_id,section_id=section_id, sliding_window_size=10000, title="With synapses", fig_size=(10,5))
pnv2.plot_neuron_voltage(neuron_id=neuron_id,section_id=section_id, sliding_window_size=10000, title="No synapses", fig_ssize=(10,5))
# Out:
# Loading morphology: /home/hjorth/HBP/BasalGangliaData/data/neurons/striatum/dspn/str-dspn-e150602_c1_D1-mWT-0728MSN01-v20211026/morphology/WT-0728MSN01-cor-rep-ax-res3-var0.swc
# Volt size (1801, 4)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 section_id = [0, 9, 27, 47]
#       2 pnv.plot_neuron_voltage(neuron_id=neuron_id,section_id=section_id, sliding_window_size=10000, title="With synapses", fig_size=(10,5))
# ----> 3 pnv2.plot_neuron_voltage(neuron_id=neuron_id,section_id=section_id, sliding_window_size=10000, title="No synapses", fig_ssize=(10,5))
#
# TypeError: plot_neuron_voltage() got an unexpected keyword argument 'fig_ssize'
