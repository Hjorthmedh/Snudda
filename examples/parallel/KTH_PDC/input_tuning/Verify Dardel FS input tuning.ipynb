# %% [markdown]
# # Verification of the FS input tuning on Dardel

# %%
import os
from snudda.input.input_tuning import InputTuning

# Let's run FS for now, to do it faster
neuron_type = "fs"
input_type = "cortical"
network_path = os.path.join("networks", f"verify_input_{neuron_type}_{input_type}")

snudda_data = "../../../../../BasalGangliaData/data/"
os.environ["SNUDDA_DATA"] = snudda_data
assert os.path.isdir(os.getenv("SNUDDA_DATA")), f"You need to have BasalGangliaData installed for this example."

# %%
input_tuning = InputTuning(network_path)
# Out:
# Reading SNUDDA_DATA=../../../../../BasalGangliaData/data/ from environment variable $SNUDDA_DATA

# %%
input_tuning.plot_verify_frequency_distribution(input_type=input_type)
# Out:
# Loading networks/verify_input_fs_cortical/simulations/output.hdf5
# Frequency outliers: fs_str_fs_e16_p92705ff4_m15ae4048 (0) -- [ 0.2  0.   0.8 17.6 33.4 45.1] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_p92705ff4_m15ae4048 (1) -- [ 0.4  0.   0.1  4.5 13.  24.6] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_p6eb0c221_m2a6ab0d6 (260) -- [ 0.   1.1 10.7 22.4 34.7 42.3] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_p6eb0c221_m2a6ab0d6 (261) -- [ 0.   1.   9.5 21.  32.3 38.7] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_p563801bd_mf4ff6845 (518) -- [ 0.2  0.   0.   5.5 24.9 41.7] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_p6eb0c221_m2a6ab0d6 (264) -- [ 0.   0.5  8.5 21.6 30.8 37.5] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_p6eb0c221_m868d56db (272) -- [ 0.   0.4  3.  23.7 36.9 43.5] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_p6eb0c221_m868d56db (274) -- [ 0.9  0.   2.1 15.2 27.6 36.8] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_p6eb0c221_ma88f99b9 (281) -- [ 0.   0.1  6.7 24.6 32.7 40.9] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_p71c7354b_m85dd3778 (541) -- [ 0.3  0.   0.   6.5 19.5 36.7] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_pc047576c_m127c582f (31) -- [ 0.6  0.   0.8  5.7 17.7 33.2] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_pc047576c_m127c582f (32) -- [ 0.2  0.   1.1  7.6 19.6 40.3] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_p71c7354b_m85dd3778 (543) -- [ 0.   0.   0.3  3.7 11.1 31.5] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_pc047576c_m15ae4048 (37) -- [ 0.   0.   1.1 14.9 35.3 51.5] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_pc047576c_m15ae4048 (39) -- [ 0.   0.   0.   3.6 12.2 28.6] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_pc047576c_m4cd420e2 (41) -- [ 0.4  0.   1.   4.6 19.2 33.3] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_p3c04b779_md6cbd357 (466) -- [ 0.   0.   0.4  4.4 11.2 25. ] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_p71c7354b_md6cbd357 (556) -- [ 0.4  0.   0.4 10.6 30.9 39.7] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_pf86c86e4_m27aed108 (300) -- [ 0.   2.  15.4 26.1 33.3 40.8] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_pf86c86e4_m27aed108 (301) -- [ 0.1  1.2 14.4 25.  32.8 39.1] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_pf86c86e4_m27aed108 (302) -- [ 0.   3.5 15.5 27.9 35.4 41.9] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_pf86c86e4_m27aed108 (303) -- [ 0.1  1.4 12.9 24.6 31.2 38. ] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_pf86c86e4_m27aed108 (304) -- [ 0.1  2.3 15.7 26.  36.  40.2] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_pf86c86e4_m2a6ab0d6 (305) -- [ 0.   0.6 11.3 21.8 31.7 38.3] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_pf86c86e4_m2a6ab0d6 (307) -- [ 0.   0.2 11.1 22.  34.1 40.7] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_pf86c86e4_m2a6ab0d6 (308) -- [ 0.   0.5  9.4 21.8 29.7 36.6] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_pc047576c_m86da4874 (51) -- [ 0.   0.   0.   1.1  8.8 22.9] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_pc047576c_m86da4874 (54) -- [ 0.   0.   0.1  2.6 12.8 25.7] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_p3c04b779_md6cbd357 (468) -- [ 0.   0.   0.   3.6 10.5 30.9] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_pc047576c_m4fdebda2 (49) -- [ 0.   0.   1.6  9.4 28.3 47.7] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_p880b9295_m1a3fcdc5 (567) -- [ 0.   0.   0.1  4.7 20.6 25.7] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_
8] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161024_FS16-mDR-rat-Mar-13-08-1-536-R-v20210210
# Frequency outliers: fs_str_fs_e16_p563801bd_m1a3fcdc5 (479) -- [ 0.   0.   0.2  1.   9.2 28.8] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_pb1ef6b01_mb1b67bcc (736) -- [ 0.   0.   0.   4.4 10.6 28.2] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_p563801bd_m2353c9ea (484) -- [ 0.   0.   0.   2.2 10.9 29.2] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_p563801bd_m4839f17c (488) -- [ 0.   0.   0.   1.2 11.4 16.9] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_pb1ef6b01_mb1b67bcc (737) -- [ 0.   0.   1.5  9.2 32.7 48.1] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e160628_FS2-mMTC180800A-IDB-v20210210
# Frequency outliers: fs_str_fs_e16_p563801bd_m85dd3778 (498) -- [ 0.   0.   0.1  0.9 12.3 29.5] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209
# Frequency outliers: fs_str_fs_e16_p563801bd_mc8ef3a88 (506) -- [ 0.   0.   0.   1.3  9.2 31.8] Hz
# $SNUDDA_DATA/neurons/striatum/fs/str-fs-e161205_FS1-mBE104E-v20210209

# %%
input_tuning.plot_depolarisation_blocked_neurons()
# Out:
# Loading networks/verify_input_fs_cortical/simulations/output.hdf5

# %%
if False:
  from snudda.plotting import PlotInput
  input_file = os.path.join(network_path, "input.hdf5")
  spi = PlotInput(input_file)
  spi.plot_input_to_target(222)
  spi.plot_input_to_target(223)

# %%
from snudda.plotting import SnuddaPlotInputLocations
input_file = os.path.join(network_path, "input.hdf5")
spil = SnuddaPlotInputLocations(network_path=network_path, input_file=input_file, snudda_data=snudda_data,
                                plot_in_origo=True)

# %%
spil.plot_neuron_inputs(220, input_type="cortical")
spil.plot_neuron_inputs(221, input_type="cortical")
spil.plot_neuron_inputs(222, input_type="cortical")
spil.plot_neuron_inputs(223, input_type="cortical")
spil.plot_neuron_inputs(224, input_type="cortical")
# Out:
# Plotting 93 external synapses
# Figure written: networks/verify_input_fs_cortical/figures/input-to-220-fs_str_fs_e16_p31916918_m48f576bb-cortical-and-internal-synapses.png
# /home/hjorth/HBP/Snudda/snudda/plotting/plot_input_locations.py:158: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x_labels)
# /home/hjorth/HBP/Snudda/snudda/plotting/plot_input_locations.py:159: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(y_labels)
# /home/hjorth/HBP/Snudda/snudda/plotting/plot_input_locations.py:160: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_zticklabels(z_labels)
# Plotting 93 external synapses
# Figure written: networks/verify_input_fs_cortical/figures/input-to-221-fs_str_fs_e16_p31916918_m48f576bb-cortical-and-internal-synapses.png
# Plotting 93 external synapses
# Figure written: networks/verify_input_fs_cortical/figures/input-to-222-fs_str_fs_e16_p31916918_m48f576bb-cortical-and-internal-synapses.png
# Plotting 93 external synapses
# Figure written: networks/verify_input_fs_cortical/figures/input-to-223-fs_str_fs_e16_p31916918_m48f576bb-cortical-and-internal-synapses.png
# Plotting 93 external synapses
# Figure written: networks/verify_input_fs_cortical/figures/input-to-224-fs_str_fs_e16_p31916918_m48f576bb-cortical-and-internal-synapses.png
# <Axes3D: title={'center': 'cortical and internal input to fs_str_fs_e16_p31916918_m48f576bb (224)'}, xlabel='μm', ylabel='μm', zlabel='μm'>

# %%
n_bins=10
spil.plot_input_soma_distance(neuron_id=220, input_type="cortical", n_bins=n_bins)
spil.plot_input_soma_distance(neuron_id=221, input_type="cortical", n_bins=n_bins)
spil.plot_input_soma_distance(neuron_id=222, input_type="cortical", n_bins=n_bins)
spil.plot_input_soma_distance(neuron_id=223, input_type="cortical", n_bins=n_bins)
spil.plot_input_soma_distance(neuron_id=224, input_type="cortical", n_bins=n_bins)
